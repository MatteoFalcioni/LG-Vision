# %% [markdown]
# # Building up the pipeline to sample street views
#
# First, I want to see how Google APIs work and how i can combine them together.
#
# Specifically I want to check out:
#
# - Places API
# - StreetView API

# %% [markdown]
# I already got an API key and set it in my env file.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Global API key configuration
import os
API_KEY_GMP = os.getenv("GOOGLE_API_KEY")
assert API_KEY_GMP, "Missing GOOGLE_API_KEY in environment."

# %% [markdown]
# Call the places API in a radius around Bologna:

# %%
import os
import requests
import json

# Example request to Places API - Text Search restricted to Bologna
query = "Giardini Margherita"
url = "https://places.googleapis.com/v1/places:searchText"

headers = {
    "Content-Type": "application/json",
    "X-Goog-Api-Key": API_KEY_GMP,
    'X-Goog-FieldMask' : '*'   # many fields available, use '*' to get all
}

#useful: location contains lat and lon

# Bologna coordinates
bologna_lat = 44.4949
bologna_lng = 11.3426
radius_meters = 5000  # 5km radius

payload = {
    "textQuery": query,
    "locationBias": {
        "circle": {
            "center": {
                "latitude": bologna_lat,
                "longitude": bologna_lng
            },
            "radius": radius_meters
        }
    },
    "maxResultCount": 5  # Limit to 5 results
}

response = requests.post(url, headers=headers, json=payload)
data = response.json()

print("Status Code:", response.status_code)
print(f"\nSearching for '{query}' in Bologna (radius: {radius_meters}m)")
print(f"\nNumber of results: {len(data.get('places', []))}")
print("\nResponse:")
print(json.dumps(data, indent=2))
# Out:
# Status Code: 200
#
# Searching for 'Giardini Margherita' in Bologna (radius: 5000m)
#
# Number of results: 1
#
# Response:
# {
#   "places": [
#     {
#       "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0",
#       "id": "ChIJLwKOhMXUf0cRiLrCD6oTfS0",
#       "types": [
#         "tourist_attraction",
#         "hiking_area",
#         "park",
#         "sports_activity_location",
#         "point_of_interest",
#         "establishment"
#       ],
#       "nationalPhoneNumber": "051 203040",
#       "internationalPhoneNumber": "+39 051 203040",
#       "formattedAddress": "Viale Giovanni Gozzadini, 40136 Bologna BO, Italy",
#       "addressComponents": [
#         {
#           "longText": "Viale Giovanni Gozzadini",
#           "shortText": "Viale Giovanni Gozzadini",
#           "types": [
#             "route"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Bologna",
#           "shortText": "Bologna",
#           "types": [
#             "locality",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Bologna",
#           "shortText": "Bologna",
#           "types": [
#             "administrative_area_level_3",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Citt\u00e0 Metropolitana di Bologna",
#           "shortText": "BO",
#           "types": [
#             "administrative_area_level_2",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Emilia-Romagna",
#           "shortText": "Emilia-Romagna",
#           "types": [
#             "administrative_area_level_1",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Italy",
#           "shortText": "IT",
#           "types": [
#             "country",
#             "political"
#           ],
#           "languageCode": "en"
#         },
#         {
#           "longText": "40136",
#           "shortText": "40136",
#           "types": [
#             "postal_code"
#           ],
#           "languageCode": "en-US"
#         }
#       ],
#       "plusCode": {
#         "globalCode": "8FPHF9M2+3X",
#         "compoundCode": "F9M2+3X Bologna, Metropolitan City of Bologna, Italy"
#       },
#       "location": {
#         "latitude": 44.4827156,
#         "longitude": 11.3524117
#       },
#       "viewport": {
#         "low": {
#           "latitude": 44.48259271970851,
#           "longitude": 11.348590399999999
#         },
#         "high": {
#           "latitude": 44.4852906802915,
#           "longitude": 11.352411700000001
#         }
#       },
#       "rating": 4.6,
#       "googleMapsUri": "https://maps.google.com/?cid=3277797724925377160&g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#       "websiteUri": "http://www.comune.bologna.it/",
#       "regularOpeningHours": {
#         "openNow": true,
#         "periods": [
#           {
#             "open": {
#               "day": 0,
#               "hour": 0,
#               "minute": 0
#             }
#           }
#         ],
#         "weekdayDescriptions": [
#           "Monday: Open 24 hours",
#           "Tuesday: Open 24 hours",
#           "Wednesday: Open 24 hours",
#           "Thursday: Open 24 hours",
#           "Friday: Open 24 hours",
#           "Saturday: Open 24 hours",
#           "Sunday: Open 24 hours"
#         ]
#       },
#       "utcOffsetMinutes": 60,
#       "adrFormatAddress": "<span class=\"street-address\">Viale Giovanni Gozzadini</span>, <span class=\"postal-code\">40136</span> <span class=\"locality\">Bologna</span> <span class=\"region\">BO</span>, <span class=\"country-name\">Italy</span>",
#       "businessStatus": "OPERATIONAL",
#       "userRatingCount": 17288,
#       "iconMaskBaseUri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/tree_pinlet",
#       "iconBackgroundColor": "#4DB546",
#       "displayName": {
#         "text": "Giardini Margherita",
#         "languageCode": "en"
#       },
#       "primaryTypeDisplayName": {
#         "text": "Park",
#         "languageCode": "en-US"
#       },
#       "currentOpeningHours": {
#         "openNow": true,
#         "periods": [
#           {
#             "open": {
#               "day": 2,
#               "hour": 0,
#               "minute": 0,
#               "truncated": true,
#               "date": {
#                 "year": 2025,
#                 "month": 10,
#                 "day": 28
#               }
#             },
#             "close": {
#               "day": 1,
#               "hour": 23,
#               "minute": 59,
#               "truncated": true,
#               "date": {
#                 "year": 2025,
#                 "month": 11,
#                 "day": 3
#               }
#             }
#           }
#         ],
#         "weekdayDescriptions": [
#           "Monday: Open 24 hours",
#           "Tuesday: Open 24 hours",
#           "Wednesday: Open 24 hours",
#           "Thursday: Open 24 hours",
#           "Friday: Open 24 hours",
#           "Saturday: Open 24 hours",
#           "Sunday: Open 24 hours"
#         ]
#       },
#       "primaryType": "park",
#       "shortFormattedAddress": "Viale Giovanni Gozzadini, Bologna",
#       "editorialSummary": {
#         "text": "Popular public park with lots of trees, a lake & lawns, plus a jogging path & play areas for kids.",
#         "languageCode": "en"
#       },
#       "reviews": [
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/ChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE",
#           "relativePublishTimeDescription": "5 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Free of charge, easy access, designated areas for many choices from play grounds for kids to badminton for adults. Biking is allowed, too.\nGrab your picnic basket and spend the day here.\nOr bring your book and enjoy the resreshments/pastey at the caffea inside the park.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Free of charge, easy access, designated areas for many choices from play grounds for kids to badminton for adults. Biking is allowed, too.\nGrab your picnic basket and spend the day here.\nOr bring your book and enjoy the resreshments/pastey at the caffea inside the park.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Zuhal",
#             "uri": "https://www.google.com/maps/contrib/117843459985379991032/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWSs1QQ9P4X5_D0vCwFwIInIqTUffw7UZOM_BhqGnjSqTy3Dnpn=s128-c0x00000000-cc-rp-mo-ba4"
#           },
#           "publishTime": "2025-05-03T10:30:48.565848Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB",
#           "relativePublishTimeDescription": "3 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Giardini Margherita is Bologna\u2019s most beloved park\u2014a peaceful, green escape perfect for relaxing, walking, or picnicking. With tree-lined paths, a small lake, caf\u00e9s, and play areas, it\u2019s popular with locals and visitors alike. Ideal for a break from the city\u2019s bustle, especially on sunny days. Great for solo travelers, families, or anyone wanting a breath of fresh air in a beautiful setting.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Giardini Margherita is Bologna\u2019s most beloved park\u2014a peaceful, green escape perfect for relaxing, walking, or picnicking. With tree-lined paths, a small lake, caf\u00e9s, and play areas, it\u2019s popular with locals and visitors alike. Ideal for a break from the city\u2019s bustle, especially on sunny days. Great for solo travelers, families, or anyone wanting a breath of fresh air in a beautiful setting.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Dani Baal",
#             "uri": "https://www.google.com/maps/contrib/103357020897930875043/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXd5F4_0jTgLXfmVTKm-2qvHv52-mDsO2tP9IWzdgV09PasJeSo=s128-c0x00000000-cc-rp-mo-ba7"
#           },
#           "publishTime": "2025-07-28T12:37:34.868920783Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/ChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB",
#           "relativePublishTimeDescription": "7 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Beautiful green space easily accessible from the center of Bologna.  Some playgrounds, remote working space, walkways great for kids to ride bicycles on and some playgrounds. There are a few cafe\u2019s and bars as well and a very small go kart course with electric go karts and pedal karts.  It\u2019s a gem in this city and a must visit on a nice day.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Beautiful green space easily accessible from the center of Bologna.  Some playgrounds, remote working space, walkways great for kids to ride bicycles on and some playgrounds. There are a few cafe\u2019s and bars as well and a very small go kart course with electric go karts and pedal karts.  It\u2019s a gem in this city and a must visit on a nice day.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Aldo Pinotti",
#             "uri": "https://www.google.com/maps/contrib/101428219914666686008/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVcPEKbbFMj1FaxARFYvyiVYEGsWZBBiDVb8Ub98FPERNqYWwgEyw=s128-c0x00000000-cc-rp-mo-ba3"
#           },
#           "publishTime": "2025-03-24T15:48:07.497659Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB",
#           "relativePublishTimeDescription": "2 weeks ago",
#           "rating": 5,
#           "text": {
#             "text": "Very nice park with a lovely picnic / bar area at the back, near the botanical area.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Very nice park with a lovely picnic / bar area at the back, near the botanical area.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Holly Pope",
#             "uri": "https://www.google.com/maps/contrib/111127058743800932797/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWZOw83XmvpAxB6atDufAr8WzVQ0NMaWaPUrxUti9wkeVncdQK1=s128-c0x00000000-cc-rp-mo-ba3"
#           },
#           "publishTime": "2025-10-11T12:52:40.557526010Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB",
#           "relativePublishTimeDescription": "a week ago",
#           "rating": 5,
#           "text": {
#             "text": "One of the city's many green spaces. Beautiful and quiet!",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "One of the city's many green spaces. Beautiful and quiet!",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Desart Ajazi",
#             "uri": "https://www.google.com/maps/contrib/116110492896188753454/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVz6_AmSIYggCVaxgOqjgePmbiRDdj3I_c0wYfPXmsqsHGbcUe0Cw=s128-c0x00000000-cc-rp-mo-ba2"
#           },
#           "publishTime": "2025-10-16T21:03:11.109817558Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         }
#       ],
#       "photos": [
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU4HvFx9ZPTTa5fez6Z_KwG1qLNh1Xq3oMbVxFBzuFI_ezmAUsHcDGAfbrbp_0oY4u2ItAgAvHCryJGYftmta4b7Z5XcR_c50UYZxrGFv_f37W35fkp9yhGZ55eE4VaVy0zJKnwzHfl1PB0CecL-L6seh_JPuR__mjZE54wRvyix_T49y-suNOzsUjJuqkOMv5a4-boVXTNfSTrOh5X6FTSYRkI0-YHSAjylkMcPJ59pZIHGrn4q8MIhnmcDwjCOglLq7Fopoy-Mn_8lhoWeTELkTCg3F820-8kHKV6nCRnIkHn37WuKD_csOy_NVPtEmb1fVk39jYb9QOQ9RNvp1W-jHxcauXWyjFeNe6N8cJ42uohfImt2yAASxtpCxPAvG4uslFmL-CDYbGCN5L-1kBTUzIutzG2_Uf7-aKxxyIqhraWW",
#           "widthPx": 3024,
#           "heightPx": 4032,
#           "authorAttributions": [
#             {
#               "displayName": "Phanendra das",
#               "uri": "https://maps.google.com/maps/contrib/116022813752209071834",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVunoPhApjuMp4Jzb0pegqb8AXkpXP-YalBn3EIe8u5aRFM022k=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgID7-vrO1QE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgID7-vrO1QE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU7cNNgnUD-M3mnwXmUucUF5tLYdkZnkHzOy5_ErQV9KoSwaNf4MTeWTnPx9xXu3F-va8Zowhg0C3GtK_wQQ4Yiw7djj4Tx-LhshYUuzb5WlaWwhX5C24dKXLMQqfMYS_Oy5QqI_3SZ6KB8IqFQ7RSEsfazFZEiBslxRRMsjuXC8K4ezSCANEEDxqw112Pzd-Obly6LzvIgzxMZJNpJcsgdUSw4PJWr8ZNvyxtxWF6YDPv4ouayjcpGD7Ex0O5QTMx4-_pQWcmurAHR5yLQre9FjjsevQYoSIzDSaxKZE8hxBkYY4CW4-mqydFJvAOKmylQTNSnqoxF7h8RxpmfckIhnR1nKHCSP20LnWqAQwIcqa11sHYPsMD0LGJuOSWmmSczhh6Yehcs3Vja7YfGD4h8ddr3MnUuVPNl4DVlk0FIJCRhn",
#           "widthPx": 3600,
#           "heightPx": 4800,
#           "authorAttributions": [
#             {
#               "displayName": "Giorgio Fanigliulo",
#               "uri": "https://maps.google.com/maps/contrib/117481865498945288789",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocLkuf7-zukIxOywXFuHoa37kpEoKqtO38yaq0Zt1SF0SVWekA=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgID63fLgjwE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgID63fLgjwE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5bF_pmCZ1Ev4QJBgoQeWVx37vawd-2II6knZ3tNbiEz1sa66g2WEQApfiH-no2hb5eNrURxHxU2B5GQTXv7_GR430nOO6DBPBIX3HylEV232kDBokEZdREZ8r7wspnqYpgtwEVpZXBowbi-GSk4vSbwiJ2HU5ilZ5VRCDUUevfwmlSfCDXNodf0viLcVyiabepKe50drDKezA_YZeeTM_s1aB7MwKpXyN_R5yKxxJ_Nb717XA-RaL9af69aQVc1zdOyicEnNlA0bh3sb45ZrmU3e275yXz8sjkaouTXVjAbILqvG0eZn9HabU-woWMB2dtnG-IuU6JhJYpfKk7PQWB86x1c_I6N2OJx3MEucEXoeLtltjJY9vQWdYPftlA5vFh-DNKszjUn3ZQv-PiCRpl7te87IjcNgqOsb-DoPrekQ",
#           "widthPx": 3456,
#           "heightPx": 4608,
#           "authorAttributions": [
#             {
#               "displayName": "Giorgio Scarabelli",
#               "uri": "https://maps.google.com/maps/contrib/117147474204335919716",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVOKqJAVuxnwSYNOyRbCRTPzAgexBsZCf0oCkbNhdlYgABi9eG7=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEJyj89nwnPORCw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEJyj89nwnPORCw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU61OeI_U41u7RN7u4VrdV-2GHWHsSaNmWoKXYNg6I-TmMOS4ntfUYxUxuYZhWHz0POoaY3QJFUi-i1k2sTxFWusxIbKF7SNqkezYhjXMyHc0DKt8uA2SjWPOxDUUHDLWQ6I9BxwBnhfNhurrTlNlsBZauftoHq3-LL4Qs8JHnGHZjwO0RmDHaOAyPOmSghocZaasDiAKk_Bi2mugV9nPdm5_x-h8LdpwWcvzZojB_XoDsJ929qjXFNHt2YttU7tyI4CI0Ihk8Q5Tk5JOBMT6MO7hBVBWbzsSVFby6L_ik3JBW8MLiE3ajPJPIe0jr4WBib6xesRrZhsoURoRAzwSrnsyTc1ZrBWlOTyErAtuFp19fVYzoSgfSzaiFSv8D9aZ_VOBCAdHzadd03WcvNTvfrydiQwx3GmGXL3hejKy8yjFT5K",
#           "widthPx": 4032,
#           "heightPx": 3024,
#           "authorAttributions": [
#             {
#               "displayName": "Diana B",
#               "uri": "https://maps.google.com/maps/contrib/114064809743683456601",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVfheGMKzOKVjl0o1d2cjMqF-PTjdtooKQHpOJBhdXO4ln1cdYj=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICO3ZndwQE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICO3ZndwQE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU6conpieEAavGzSdUPfksjQ3WDTcC6nz5e_01cXhpu3oY1eRpQKGajKL84W0tYXZsDRB40-Pi0sIZB-L1r14_oK-UH2r72A6Voa4hzeMqtemUAgmR2v-oYEHm_xgsVdz47yICSvuREUwAufllw8naUa6nxcBW9jvKjzY9q6V5kMGrPQ4wfkzFRxud7xVIm_sS0lFG0qJDp-2H-Pf8kGDCZ4z-Qm_rdwuXlpoGSObE-Vy1Z_1BN0Y76TYR9_3vfJPwtjN6XLSFfAoOiQfjeVKbh76kSxPqcMl1ty04iyW6YKM8Yn30K9-69nHfFDxCjVsWVGoZ-9YofS7kMyN4aZe4f-hxK56NPZWZPxC-VynXtNI5M0rRetAWuzR1SHy6Io61A9JN29mq4ovmHfoc49jQy334F8g_tjDEVWVCB7tNsDBw",
#           "widthPx": 3000,
#           "heightPx": 4000,
#           "authorAttributions": [
#             {
#               "displayName": "Stefano Merighi",
#               "uri": "https://maps.google.com/maps/contrib/100902344886524646680",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVlok2JP0fUlKE37CfPP2q8qmjNDFhzV7i4-QQANRrvEK3BTZlYiA=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICmv_uRAQ&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICmv_uRAQ!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU72h4GQtr2RbGjNk3m6G7lMwGK6q8hB7G0SvYFBRLznC3oTU3hmd586EJF9kWC5cn1MxbIQ9ZrhYE_dWJtxMvBWZP7qzDTfmGW3LkJiQ_OGZr6kWZYPcDKBwDRukdnIxpK4sTKm2pXUbW9SMqjNzDmyUjQ2DL9Veam4k6n9E6D7Lhm0BKiEecjgjjSPCKREn1oEld_uosx015aH1spxjeL0ic4s8nLkV1JGmNHqoRi4BoQTxGwQNojSjPKE6d2MIXmZco4x1imz7mp6Q0ytGZpnc3zFn5R6OKIYLiJVczgKrQhgyEJQYvFDvzg7OVDd0HxFQRL7D-zhOqNd1CXzsEuuTiKlJ3CswlRPbVAtH6R6JXKIqZ-GU5uOtjVeGFND7qqOQqaasIUITdizaBty9e5S5_Yx81KE1xrK1cu5g9U",
#           "widthPx": 2272,
#           "heightPx": 1836,
#           "authorAttributions": [
#             {
#               "displayName": "Marco Mongitore",
#               "uri": "https://maps.google.com/maps/contrib/117247794346755004430",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocIenO4PrC7jbH9298glrWmPQRGsPnI2BnA0H3nAssp0ujjqlkfV=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDcj-22Hw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDcj-22Hw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU6_Nze1HzdP427o-Exkp5kfPZ26oAqPKB9lYd4dcOvkzNT8c84Uesknr6NGkP0s9xo_2AMiInhQzvYHLJoiulhjWJgK0M_qt8Zkw3ms5_637nG--VpT_aua1cxvwsnZhJ5gpCHD79tSGYD1SItQ2BVwQyUzrkZ_wRdimoI5eXHyyqVIWBHDA2yDwND0OkMo9_ptb_C6Bbe7sc9dbL6bTxBbnlTi4N5Xs22pmuOQmRFtBonlz2uOCwmeCQoYC595WszvarsfrRwsloqA6ieITsatsXD4ENDdSeXhNcaBHHLF30fnlZbqrBgc5HZzkY0fXtm44svjXR5GGa2dRoJkSfFL1sv8H2f5SaRYiTXtJ7Aun0_4DEJEWVD_e97H3NvE8awG_Gd0vrR7cceyoFdyk9jziceo9DXzt-Ec5VlwRi1F3dtw",
#           "widthPx": 4000,
#           "heightPx": 3000,
#           "authorAttributions": [
#             {
#               "displayName": "Cristina",
#               "uri": "https://maps.google.com/maps/contrib/109109969557698215870",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocI0_XUNiyglPjHsgBgMQk5FYUxrzN_OnKCNTNvXG_p0nEXYKQ=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICKgfiM9AE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICKgfiM9AE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU6iOnr2eUsahjh0yNb1Ma5YhTxOoZKCDHA4eogZz7abJHh7FjFA_InrbveZLidc65fLJ64QKeS_0Uga7aRTVp6FUgJVcbEOhLxW6tn0bZluKRc1ubBEpjBEfeNfHoCgth2N7ouz9r2nTW3sh62fd6VAcqeu7Wf5_9N3KZB2BPz0yk4w7s72Ma42d0PI9qX5UBEJ0rnVVggvC5fwkmbs-AbkN8BTfwYVJUwMb78BOavFqYRPO_6da6lfcj4SN2D9z83JN6ZVNbFLOveRFNtW1CEwtNpa5F3kZbgug8MfTAapPUtGgHO5R0FQ_WEHnxP_moP9k8jLMpwf79S7tYNm00DVYj_z9tcIcRlKzXkwbToPiF_v01un8byw3s21VF9jvNsjLueeQVJxrRByKundI6IGmYgsiOi51NZc0FiKZxo",
#           "widthPx": 3968,
#           "heightPx": 2976,
#           "authorAttributions": [
#             {
#               "displayName": "massimo forni",
#               "uri": "https://maps.google.com/maps/contrib/104350402342410590076",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWoJQaKQ7ujCnhtx6izg3Z-on_EccHRbc5hGnDni2IY3i9Y62h6=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDqvr-_Vg&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDqvr-_Vg!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5Hn-ROG4XXc7MnW2dzvKwo8NMRVTlmephHQR84Xa5kr2UeqZTda3bgt9jD9CY_GhqiqpClyYwLqLn0Aizg2RorDA7jDDh9-cpOpdhgJhcHRE3O5uKDwguXgCUZBvOK8WcHw1BvUQF_2J4PlN1G6NRz2pX08gDXBrAiqWW0dcX6PZWZwxTKtIYTEDxXLyS02-DuLE0Hp5cMcGMINGBQJzm0l_g0uHzaCT9xCSZh0OW_VFG_Sazr602MyPN6ruyqJGbky2xlIznSFQxu-Bc6Kxj1EXY-XP2z_i4XRUyQy3T69X8JWNKpdeqz4SaPzHF_hlxxR8XcCb-3Yid_zRtPg28I88Hf2uw9rmuoxsUi0oomlnBVxqKdijxIvJOxyRwyHGNO-9_sQ2WnFqHsCRz2EeumfOk3qOVdJ7GnoOvqFZIqAgwZ",
#           "widthPx": 3648,
#           "heightPx": 2736,
#           "authorAttributions": [
#             {
#               "displayName": "Marco Monti",
#               "uri": "https://maps.google.com/maps/contrib/117527048640464687964",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXaUVUApnk1gR10KDu36WgSAQvFub2qap2N4LSukdcu1eDRoZw3=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIC2joXNuQE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIC2joXNuQE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5TMfO-e_fH8XBvSV6yuI5PMeaAW3CaAzlpji6zyj4P5acWQ69WwTSu8LPPuzLM9mDp90ahRIdy19u2gfhrpwwd_olixoMGjEG-Bm4Qb4mlGyF8E1ZC_btPumxb4vyrviKbKz1U4lJXwzoXnd4sD8XOqA0gaV-IHZnl9YGDNAo9YfMRiaWcjdXc9fcSIcPzvKD6CWT41bLBuIZphPHoP4Esucrs2VF8rZBK4cmmEzGZcmLdgd0IDFCmwgaQRu1M1baPE5HSWPkTnDd1RKpkuF7K5K-NBgQBNiRFR4RathBAtfjvWuDTdtxxI2wydaGoLGsGS3nO98WMh8W6mNjzVP71HKjThP7bjYsxDZDZdZpbPD01KWM_DPqM-a6RZhaNnPg50UDJaejfHcTMfsrDeJS9tjulgkmW1gobjNf6ilbSUQ",
#           "widthPx": 4608,
#           "heightPx": 3456,
#           "authorAttributions": [
#             {
#               "displayName": "Mars Gofabeatz",
#               "uri": "https://maps.google.com/maps/contrib/116262144135072295136",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXBp-dEsKqjaOUNJt7wR525pL5f-3GZ0SrNNr86qEY0vSTgs1B-Vw=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDRlK7CNA&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDRlK7CNA!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         }
#       ],
#       "goodForChildren": true,
#       "allowsDogs": true,
#       "paymentOptions": {
#         "acceptsCreditCards": true,
#         "acceptsDebitCards": true,
#         "acceptsCashOnly": false
#       },
#       "accessibilityOptions": {
#         "wheelchairAccessibleParking": true,
#         "wheelchairAccessibleEntrance": true
#       },
#       "addressDescriptor": {
#         "landmarks": [
#           {
#             "name": "places/ChIJ8-EjLcTUf0cRHy_epY_lpPI",
#             "placeId": "ChIJ8-EjLcTUf0cRHy_epY_lpPI",
#             "displayName": {
#               "text": "Carrefour Express Porta Castiglione Store",
#               "languageCode": "en"
#             },
#             "types": [
#               "establishment",
#               "food",
#               "grocery_or_supermarket",
#               "health",
#               "point_of_interest",
#               "store",
#               "supermarket"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 31.259172,
#             "travelDistanceMeters": 32.876442
#           },
#           {
#             "name": "places/ChIJ396r0sXUf0cRtx-IP709mG8",
#             "placeId": "ChIJ396r0sXUf0cRtx-IP709mG8",
#             "displayName": {
#               "text": "Farmacia Dr. Max",
#               "languageCode": "it"
#             },
#             "types": [
#               "establishment",
#               "health",
#               "pharmacy",
#               "point_of_interest",
#               "store"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 29.39594,
#             "travelDistanceMeters": 15.978893
#           },
#           {
#             "name": "places/ChIJQ8QHycXUf0cRdnAeMobf1SM",
#             "placeId": "ChIJQ8QHycXUf0cRdnAeMobf1SM",
#             "displayName": {
#               "text": "Chiesa di Santa Maria della Misericordia",
#               "languageCode": "en"
#             },
#             "types": [
#               "church",
#               "establishment",
#               "place_of_worship",
#               "point_of_interest"
#             ],
#             "spatialRelationship": "DOWN_THE_ROAD",
#             "straightLineDistanceMeters": 77.96733,
#             "travelDistanceMeters": 71.19292
#           },
#           {
#             "name": "places/ChIJfxhFC8XUf0cR0Xo9dUoTA6s",
#             "placeId": "ChIJfxhFC8XUf0cR0Xo9dUoTA6s",
#             "displayName": {
#               "text": "Serre dei Giardini Margherita",
#               "languageCode": "en"
#             },
#             "types": [
#               "bar",
#               "establishment",
#               "food",
#               "point_of_interest",
#               "restaurant",
#               "school"
#             ],
#             "straightLineDistanceMeters": 216.12418,
#             "travelDistanceMeters": 231.01735
#           },
#           {
#             "name": "places/ChIJPf2OzsXUf0cRhB7p5uqjLII",
#             "placeId": "ChIJPf2OzsXUf0cRhB7p5uqjLII",
#             "displayName": {
#               "text": "B&B Al Parco Giardini Margherita Sconti Rizzoli e Villa Regina",
#               "languageCode": "en"
#             },
#             "types": [
#               "establishment",
#               "lodging",
#               "point_of_interest"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 22.453997,
#             "travelDistanceMeters": 20.678474
#           }
#         ],
#         "areas": [
#           {
#             "name": "places/ChIJLwKOhMXUf0cRSwyJnq_IU64",
#             "placeId": "ChIJLwKOhMXUf0cRSwyJnq_IU64",
#             "displayName": {
#               "text": "Giardini Margherita",
#               "languageCode": "en"
#             },
#             "containment": "NEAR"
#           },
#           {
#             "name": "places/ChIJn_75kpXUf0cRlcgftj_FyYI",
#             "placeId": "ChIJn_75kpXUf0cRlcgftj_FyYI",
#             "displayName": {
#               "text": "Old Town",
#               "languageCode": "en"
#             },
#             "containment": "OUTSKIRTS"
#           }
#         ]
#       },
#       "googleMapsLinks": {
#         "directionsUri": "https://www.google.com/maps/dir//''/data=!4m7!4m6!1m1!4e2!1m2!1m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!3e0?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "placeUri": "https://maps.google.com/?cid=3277797724925377160&g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "writeAReviewUri": "https://www.google.com/maps/place//data=!4m3!3m2!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!12e1?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "reviewsUri": "https://www.google.com/maps/place//data=!4m4!3m3!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!9m1!1b1?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "photosUri": "https://www.google.com/maps/place//data=!4m3!3m2!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!10e5?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA"
#       },
#       "timeZone": {
#         "id": "Europe/Rome"
#       },
#       "postalAddress": {
#         "regionCode": "IT",
#         "languageCode": "en-US",
#         "postalCode": "40136",
#         "administrativeArea": "Metropolitan City of Bologna",
#         "locality": "Bologna",
#         "addressLines": [
#           "Viale Giovanni Gozzadini"
#         ]
#       }
#     }
#   ],
#   "contextualContents": [
#     {
#       "photos": [
#         {
#           "name": "-kPe3d3SRGirGvIqHlfZVMDJzfdXolK1iy7-8LPzKxVgTm-R0wCNr0nSi6EFQDU6Xcq1e5z3SpS-g4zMdWCjWloFbNzo_QPyBO3T_EfppijWCKuczHA-BBQ8OklB-8v1DOG3vXYiUTXy9k0TP4A2bkvSZIRJxvy2-PKDKekDc7",
#           "widthPx": 4160,
#           "heightPx": 3120,
#           "authorAttributions": [
#             {
#               "displayName": "Stefano Dalzini",
#               "uri": "https://maps.google.com/maps/contrib/112388244312001538595",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjUNJHfLWK30qZ-kX3edFNT3j57FzK1BI5JWrwoHlAcZVtDPvzFO3g=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places&image_key=!1e10!2sCIHM0ogKEICAgIDUl5neCw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDUl5neCw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5-rST9viiAPT_m8IGwDbKvCZKUOVDdvfDKrNP2DBpY3MeMDP0kWBPiQr6yvbG0Sz_8xotJa8ZeP9gdNX3A4xhcgM_0PEsAd5EL2V3qKMGRMhbSAg9iOT2SIDvX68wSccLTpruKLbv5g6WjWFO1yWaj9EZzP0Y0gF_cDSQq6Mxfvsf-gSdgesDFF7TAtVpby-RtWblczUSrraX2WIcUA1qSH4rMwV49zXEv6o8pB6BTdQ72OxqO2F9zE_pwmMhCB0ksIZ-bgFMx3HZwtYvgBbywONuG-D22-_j_s1Pvw-2NbVgGObrUnB5f5NPj5BwHcByvdjR-AhdBCDjuKvqB43Qi6Phfztm2RadKz6ej7oXvtorRKbV1qE8bo0H_qJk6uxaXVR1U3tCIGsll9Tih",
#           "widthPx": 4032,
#           "heightPx": 3024,
#           "authorAttributions": [
#             {
#               "displayName": "Roberto Vanzetta",
#               "uri": "https://maps.google.com/maps/contrib/101286674699245687282",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjUKFn3PKwY9OpTsp6giY82MnPHhsyq4lTc7l5x3PpXUqJ0kzHiK=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places&image_key=!1e10!2sCIHM0ogKEICAgIC-7JSFdw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIC-7JSFdw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU6A8baHZ5Qzkf9TdZ6gWDLHAhMaFG9uskPthXtSoc4VIOCL_0sr7uaP5HDO2DjYUFLvAyx10htkTtMhJFVfj9MPvTy1hLLKbkJZ186ShNgo6AgBUWWu-X7ncdt7_HecDM4BfrBdjV6qmOwjtYraPVjouvtmhGzqmeEmk5uWJnAuR5DqsbZVmwUGWeRPG53_ouwncaUrv_AG_ZE9_wo6Annh-T9aLB2Z3mZTVudTubL80D1x61NIEaFFE2Cow4rlbMk5aSykxNJLNT3Lnnt6Al7isZ1ei-NX8xZpTA4Fbk4agL7C_HyDviwMZ_9-boz9IMn5Nx0Ry_gpnZxDD9aG9apv2FF2wNwOri8a-dqlIrOnoqDkYt0D7B0HEejNECXZxr3vAra_cIJVItqXHem5b-mx",
#           "widthPx": 3236,
#           "heightPx": 2427,
#           "authorAttributions": [
#             {
#               "displayName": "Federica Fini Zarri",
#               "uri": "https://maps.google.com/maps/contrib/117213070053376513693",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWie0JhCewkNri-_3dAuWp0X61bcAgtk0xw66mKLhUaWGVzTj-NMw=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places&image_key=!1e10!2sCIHM0ogKEICAgID4u8Gk_gE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgID4u8Gk_gE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU7we8qVCm-BUo-q-6_JGJcCNU0wCYuP_zdFq-RYaxkJK2TcjUoQGaGdUJruXuawBKGNppBA7Q0itg-stuUGULnc8hs5C4I_o3GuSgm5_7MF8V0ex_XD-M3N_sBaMyrM9xOmll09jhz2-sIQ4CwSCktx4yhaguh8Pt-XKzVDl8owTkc0jagGwx0k1K1A3aRe3z8_U_fm_pi372anuhO6zovMMQztI-F6zBy5SQOfgR0LzSgVcCUBMQLndyuMn_3U3FLg3AdX1qhLq1HO3VHxLj9XXCNAu6MZLweQNdUkt9P6RTj39kWt49dv3Q9MGKPZIt0hCb4FgCXRNlkR9XJt0uGR1EeYLa0nz7_FEs-6tBAAlZZ9WO8myDty0npld4DVCUg3NGtXp0NfC3IN8-ih",
#           "widthPx": 4608,
#           "heightPx": 3456,
#           "authorAttributions": [
#             {
#               "displayName": "Alex Bularu",
#               "uri": "https://maps.google.com/maps/contrib/100126913413494614382",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjW4iMaG_gfjxhJQrnpYltMzrDzBm6zCfJriVdgyxg32aK_eb8zf8A=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places&image_key=!1e10!2sCIHM0ogKEICAgICkmuLURQ&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICkmuLURQ!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU59crOelK3YFOj5l_N6P3jVydf6gqn0KvuxxjyIL8dFs7Ma3-_2W_r3wrl40OKiA6CB09KYhpWACaZp2lwc0k8LvFHUXOrAG2n6OVKeoK8R8YeLBjZpq18JvXXs5b3DElnGW4vq7yttFbG4orKvDQHKSWsgzT9vm18WvvGy-TV41BRv61_ZEts90052oi3oV5LpA2ejavJVZtewu4vhRb9X213oy7iuEd8boRl3JOmm9JQj-5X943xv_l_rmXCMaJ7--04OOn4LeZAzBz3IAsjSN1PAy4abi01C_n6WLA67LhW0x0Zpg209go8ujHKmka_yLby9SuQrm5yiL_GeFMQkME6H4FzW64tJ7gkUzSjc2h3uOrTEddZmppNKuwAs6kui8zMPvh__6RNHt8wb_rNJ",
#           "widthPx": 3008,
#           "heightPx": 3008,
#           "authorAttributions": [
#             {
#               "displayName": "Paolo Mazzoni",
#               "uri": "https://maps.google.com/maps/contrib/114421506459150145050",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocLzBQO0Hxd_Ge4RMufMLgNrZzN9hyr_FwXd0XSHhNXxvPSCrA=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places&image_key=!1e10!2sCIHM0ogKEICAgICqnMvxpAE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICqnMvxpAE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         }
#       ],
#       "justifications": [
#         {}
#       ]
#     }
#   ],
#   "searchUri": "https://www.google.com/maps/search/Giardini+Margherita"
# }

# %% [markdown]
# Return only needed fields: for example location, which contains lat & lon

# %%
import os
import requests
import json

# Example request to Places API - Text Search restricted to Bologna
query = "Giardini Margherita"
url = "https://places.googleapis.com/v1/places:searchText"

headers = {
    "Content-Type": "application/json",
    "X-Goog-Api-Key": API_KEY_GMP,
    'X-Goog-FieldMask' : 'places'   # many fields available, use '*' to get all
}

#useful: location contains lat and lon

# Bologna coordinates
bologna_lat = 44.4949
bologna_lng = 11.3426
radius_meters = 5000  # 5km radius

payload = {
    "textQuery": query,
    "locationBias": {
        "circle": {
            "center": {
                "latitude": bologna_lat,
                "longitude": bologna_lng
            },
            "radius": radius_meters
        }
    },
    "maxResultCount": 5  # Limit to 5 results
}

response = requests.post(url, headers=headers, json=payload)
data = response.json()

print("Status Code:", response.status_code)
print(f"\nSearching for '{query}' in Bologna (radius: {radius_meters}m)")
print(f"\nNumber of results: {len(data.get('places', []))}")
print("\nResponse:")
print(json.dumps(data, indent=2))
print("="*60)
print(data.get('places', [])[0].get('location', {}))
# Out:
# Status Code: 200
#
# Searching for 'Giardini Margherita' in Bologna (radius: 5000m)
#
# Number of results: 1
#
# Response:
# {
#   "places": [
#     {
#       "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0",
#       "id": "ChIJLwKOhMXUf0cRiLrCD6oTfS0",
#       "types": [
#         "tourist_attraction",
#         "hiking_area",
#         "sports_activity_location",
#         "park",
#         "point_of_interest",
#         "establishment"
#       ],
#       "nationalPhoneNumber": "051 203040",
#       "internationalPhoneNumber": "+39 051 203040",
#       "formattedAddress": "Viale Giovanni Gozzadini, 40136 Bologna BO, Italy",
#       "addressComponents": [
#         {
#           "longText": "Viale Giovanni Gozzadini",
#           "shortText": "Viale Giovanni Gozzadini",
#           "types": [
#             "route"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Bologna",
#           "shortText": "Bologna",
#           "types": [
#             "locality",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Bologna",
#           "shortText": "Bologna",
#           "types": [
#             "administrative_area_level_3",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Citt\u00e0 Metropolitana di Bologna",
#           "shortText": "BO",
#           "types": [
#             "administrative_area_level_2",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Emilia-Romagna",
#           "shortText": "Emilia-Romagna",
#           "types": [
#             "administrative_area_level_1",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Italy",
#           "shortText": "IT",
#           "types": [
#             "country",
#             "political"
#           ],
#           "languageCode": "en"
#         },
#         {
#           "longText": "40136",
#           "shortText": "40136",
#           "types": [
#             "postal_code"
#           ],
#           "languageCode": "en-US"
#         }
#       ],
#       "plusCode": {
#         "globalCode": "8FPHF9M2+3X",
#         "compoundCode": "F9M2+3X Bologna, Metropolitan City of Bologna, Italy"
#       },
#       "location": {
#         "latitude": 44.4827156,
#         "longitude": 11.3524117
#       },
#       "viewport": {
#         "low": {
#           "latitude": 44.48259271970851,
#           "longitude": 11.348590399999999
#         },
#         "high": {
#           "latitude": 44.4852906802915,
#           "longitude": 11.352411700000001
#         }
#       },
#       "rating": 4.6,
#       "googleMapsUri": "https://maps.google.com/?cid=3277797724925377160&g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#       "websiteUri": "http://www.comune.bologna.it/",
#       "regularOpeningHours": {
#         "openNow": true,
#         "periods": [
#           {
#             "open": {
#               "day": 0,
#               "hour": 0,
#               "minute": 0
#             }
#           }
#         ],
#         "weekdayDescriptions": [
#           "Monday: Open 24 hours",
#           "Tuesday: Open 24 hours",
#           "Wednesday: Open 24 hours",
#           "Thursday: Open 24 hours",
#           "Friday: Open 24 hours",
#           "Saturday: Open 24 hours",
#           "Sunday: Open 24 hours"
#         ]
#       },
#       "utcOffsetMinutes": 60,
#       "adrFormatAddress": "<span class=\"street-address\">Viale Giovanni Gozzadini</span>, <span class=\"postal-code\">40136</span> <span class=\"locality\">Bologna</span> <span class=\"region\">BO</span>, <span class=\"country-name\">Italy</span>",
#       "businessStatus": "OPERATIONAL",
#       "userRatingCount": 17288,
#       "iconMaskBaseUri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/tree_pinlet",
#       "iconBackgroundColor": "#4DB546",
#       "displayName": {
#         "text": "Giardini Margherita",
#         "languageCode": "en"
#       },
#       "primaryTypeDisplayName": {
#         "text": "Park",
#         "languageCode": "en-US"
#       },
#       "currentOpeningHours": {
#         "openNow": true,
#         "periods": [
#           {
#             "open": {
#               "day": 2,
#               "hour": 0,
#               "minute": 0,
#               "truncated": true,
#               "date": {
#                 "year": 2025,
#                 "month": 10,
#                 "day": 28
#               }
#             },
#             "close": {
#               "day": 1,
#               "hour": 23,
#               "minute": 59,
#               "truncated": true,
#               "date": {
#                 "year": 2025,
#                 "month": 11,
#                 "day": 3
#               }
#             }
#           }
#         ],
#         "weekdayDescriptions": [
#           "Monday: Open 24 hours",
#           "Tuesday: Open 24 hours",
#           "Wednesday: Open 24 hours",
#           "Thursday: Open 24 hours",
#           "Friday: Open 24 hours",
#           "Saturday: Open 24 hours",
#           "Sunday: Open 24 hours"
#         ]
#       },
#       "primaryType": "park",
#       "shortFormattedAddress": "Viale Giovanni Gozzadini, Bologna",
#       "editorialSummary": {
#         "text": "Popular public park with lots of trees, a lake & lawns, plus a jogging path & play areas for kids.",
#         "languageCode": "en"
#       },
#       "reviews": [
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/ChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE",
#           "relativePublishTimeDescription": "5 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Free of charge, easy access, designated areas for many choices from play grounds for kids to badminton for adults. Biking is allowed, too.\nGrab your picnic basket and spend the day here.\nOr bring your book and enjoy the resreshments/pastey at the caffea inside the park.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Free of charge, easy access, designated areas for many choices from play grounds for kids to badminton for adults. Biking is allowed, too.\nGrab your picnic basket and spend the day here.\nOr bring your book and enjoy the resreshments/pastey at the caffea inside the park.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Zuhal",
#             "uri": "https://www.google.com/maps/contrib/117843459985379991032/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWSs1QQ9P4X5_D0vCwFwIInIqTUffw7UZOM_BhqGnjSqTy3Dnpn=s128-c0x00000000-cc-rp-mo-ba4"
#           },
#           "publishTime": "2025-05-03T10:30:48.565848Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB",
#           "relativePublishTimeDescription": "3 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Giardini Margherita is Bologna\u2019s most beloved park\u2014a peaceful, green escape perfect for relaxing, walking, or picnicking. With tree-lined paths, a small lake, caf\u00e9s, and play areas, it\u2019s popular with locals and visitors alike. Ideal for a break from the city\u2019s bustle, especially on sunny days. Great for solo travelers, families, or anyone wanting a breath of fresh air in a beautiful setting.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Giardini Margherita is Bologna\u2019s most beloved park\u2014a peaceful, green escape perfect for relaxing, walking, or picnicking. With tree-lined paths, a small lake, caf\u00e9s, and play areas, it\u2019s popular with locals and visitors alike. Ideal for a break from the city\u2019s bustle, especially on sunny days. Great for solo travelers, families, or anyone wanting a breath of fresh air in a beautiful setting.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Dani Baal",
#             "uri": "https://www.google.com/maps/contrib/103357020897930875043/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXd5F4_0jTgLXfmVTKm-2qvHv52-mDsO2tP9IWzdgV09PasJeSo=s128-c0x00000000-cc-rp-mo-ba7"
#           },
#           "publishTime": "2025-07-28T12:37:34.868920783Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/ChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB",
#           "relativePublishTimeDescription": "7 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Beautiful green space easily accessible from the center of Bologna.  Some playgrounds, remote working space, walkways great for kids to ride bicycles on and some playgrounds. There are a few cafe\u2019s and bars as well and a very small go kart course with electric go karts and pedal karts.  It\u2019s a gem in this city and a must visit on a nice day.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Beautiful green space easily accessible from the center of Bologna.  Some playgrounds, remote working space, walkways great for kids to ride bicycles on and some playgrounds. There are a few cafe\u2019s and bars as well and a very small go kart course with electric go karts and pedal karts.  It\u2019s a gem in this city and a must visit on a nice day.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Aldo Pinotti",
#             "uri": "https://www.google.com/maps/contrib/101428219914666686008/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVcPEKbbFMj1FaxARFYvyiVYEGsWZBBiDVb8Ub98FPERNqYWwgEyw=s128-c0x00000000-cc-rp-mo-ba3"
#           },
#           "publishTime": "2025-03-24T15:48:07.497659Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB",
#           "relativePublishTimeDescription": "2 weeks ago",
#           "rating": 5,
#           "text": {
#             "text": "Very nice park with a lovely picnic / bar area at the back, near the botanical area.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Very nice park with a lovely picnic / bar area at the back, near the botanical area.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Holly Pope",
#             "uri": "https://www.google.com/maps/contrib/111127058743800932797/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWZOw83XmvpAxB6atDufAr8WzVQ0NMaWaPUrxUti9wkeVncdQK1=s128-c0x00000000-cc-rp-mo-ba3"
#           },
#           "publishTime": "2025-10-11T12:52:40.557526010Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB",
#           "relativePublishTimeDescription": "a week ago",
#           "rating": 5,
#           "text": {
#             "text": "One of the city's many green spaces. Beautiful and quiet!",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "One of the city's many green spaces. Beautiful and quiet!",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Desart Ajazi",
#             "uri": "https://www.google.com/maps/contrib/116110492896188753454/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVz6_AmSIYggCVaxgOqjgePmbiRDdj3I_c0wYfPXmsqsHGbcUe0Cw=s128-c0x00000000-cc-rp-mo-ba2"
#           },
#           "publishTime": "2025-10-16T21:03:11.109817558Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         }
#       ],
#       "photos": [
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU7HdGOAsxdfrKqxwx9CcGfhZB5euOuI5YB2Mw3fgBGX2I_P1WlFdbWoqj3UZXPCOPWek1jzkfjLXA3feJryTCGeSJ7iQRhEJ4KzyJ0qU56CPsug8WoxM7E81pG6huEGVM8zLRilNFbpBjLXSE4cajAZzIDzrW9K3VJQ05mcMjLNrVxYBhPZO5IRWBakdv3AQkRraIdIslEE2NCHuyPgj7a2BW1YaiBQu9VAIl8NP4aLwH0G2hztDf4_gQMv87CAac3cvhco33cACcCnkUSEy5NHlNSxyQITn4l7XM8h6Fnv2NFHpOvpHrBPMVes0kKsV2Q1Ve6aefB4wx2lZwk9cXh4WcAKZt4CNrkeBW8fDiANDpr865Q66wTXkMJj6FlT7otYQ-GAPQNHwMZ9plnYuz1-N_2MjKAJpQHYxZV3deNXQGj0",
#           "widthPx": 3024,
#           "heightPx": 4032,
#           "authorAttributions": [
#             {
#               "displayName": "Phanendra das",
#               "uri": "https://maps.google.com/maps/contrib/116022813752209071834",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVunoPhApjuMp4Jzb0pegqb8AXkpXP-YalBn3EIe8u5aRFM022k=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgID7-vrO1QE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgID7-vrO1QE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU7EjKGRQqogHQGUa1zJP3u9AGS7NWrCcguWUU7arAXEGOjgaKhGzNjY-iqa5ado8qrjKuc9piMBHSjgEoxC2FTfQpfXsQtu3b2C_GMcGCiXgHLqlb6n0jBgsL6p6JqxMs5H87P8foZlDl17l_q3eqaxjneWATKix6W3nH_2pcp2G2eqhmglfS93L06aLmkRi9yqbMhM7UAaoUW-7UMMJV4nsMS6p_lo9wiVG0oURVSlyP2ycB5vC_GAC5W72OY6RTnxDJUS0nE6BQXEWFx-XoRuvJpFBFh_CAKPsn3zMTXvw7uDqv5f6f87gYXVWqKCHG8aTZcPC9dypF85M1tavSG_Cyfj-e4kyMU6_rs1NuQF8eINpXKRmjr99NCrn6HUXbIGt_M4vmt92HT3ZanxXTb3WnKpkQ5mPW-5mylmpLkn_Jmd",
#           "widthPx": 3600,
#           "heightPx": 4800,
#           "authorAttributions": [
#             {
#               "displayName": "Giorgio Fanigliulo",
#               "uri": "https://maps.google.com/maps/contrib/117481865498945288789",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocLkuf7-zukIxOywXFuHoa37kpEoKqtO38yaq0Zt1SF0SVWekA=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgID63fLgjwE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgID63fLgjwE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU742RwyxiT8XoyPs5SQaBEXgppwCRGWqohArYlRuI0v1GG5AOxKQVijlDiF3MNYzPwAtUWaNVl372iv6CjrXV9Ryz192dHDz-lFGVkaMIM8EcDQiQ6OFF07FFdnXIxXiJq0klNg7CKnVaxvibfYkrgTCF9NE2NcApNbVn3zvIiOD7ZMuHvpdCCpC8t3uNCUYqed6A3xjZKxTLxcOnHeS9QS2r4Fto710lgrlwfs2C-3XaBM9z6cIb7S19DOCRA0ypSUJxRUhnQO-M14Sgo0kqkFCU9ptR98JT5SFA2RKEYJwIamf1A30dslImBfAKNxgSNvc8nO1rHZJukR4WgPlwqb_tHE1DUo45z5ntMZKwRLyjCjtWS-JhzfT70KttzMZnDcS10fa8PDdbj3_KrMhx6WkYzaDsKW0wY0shW3CR-pDA",
#           "widthPx": 3456,
#           "heightPx": 4608,
#           "authorAttributions": [
#             {
#               "displayName": "Giorgio Scarabelli",
#               "uri": "https://maps.google.com/maps/contrib/117147474204335919716",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVOKqJAVuxnwSYNOyRbCRTPzAgexBsZCf0oCkbNhdlYgABi9eG7=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEJyj89nwnPORCw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEJyj89nwnPORCw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5AL1l2wd7b4Zh66RsTYM9lJsoaU4LXbRXWuBSmrDCqZiR1xrvNvSpWa9yQAQMWTo01A7ZR83B0MXGJLtxCCoFWR64DNDR7PGkNBp6SemDuGUaJcsoz0WwfQSdsfUjue4nYKJg07f4PY667id3eKOBEWFCdLJh1qZEs1_NhDLvsfR90pVgeEGk8HzRdVoHgw4ndQXl9QYLCybuIRzFdN1hEdGPq6IOa8X25wmQavzey1P9P9KS--qronI0C3PDmuJcgsWtdqSIgaMyYKudBGRtpAT1GR1VK_DWvHxaXQ6MMfI0Lk4SMLX7hNd3nMzA-V_FyaHe8WSI8_Z1WkUBaKMd5PjpbSnNzEvdXi_NU-r-v6MkXuWE3S3aum3u-99rG1fwYXWiZ7Q_zmT3UJKbODLNuCQ0n1rLdkOb60i_MLCSLnNEP",
#           "widthPx": 4032,
#           "heightPx": 3024,
#           "authorAttributions": [
#             {
#               "displayName": "Diana B",
#               "uri": "https://maps.google.com/maps/contrib/114064809743683456601",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVfheGMKzOKVjl0o1d2cjMqF-PTjdtooKQHpOJBhdXO4ln1cdYj=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICO3ZndwQE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICO3ZndwQE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU61Z8xMzO5GFvLMarYifsMhfgGWv_WQjhwcInJAlXKD60mnijpXpbmsa3HHCWlhy53t4IeOSNNaWeFHUVy-5nf8iQwiZAxUimGb93Nbcz1hgp-hCwzSYj_PXhHE5hmHJgP8lvtBo_4odi0GiBYEU2O3AsHe72XPpZmUNgPtztgDOI3x9ZCFtnShdP1SA3OOv3FlKMPvghnLP9LC1PCnxEXg3rjyhw56ZTM5MQRA8qmsy524sigy7YayIN0JG4e6lHpxbjt4eW22swpb11hX6o8oHm1nge1GARsHOhfKX1cbkvGl4LMyjbBlvH9GVAC3rkQpeLtzuG9ykiPA3EQTV4ekH9w0nZk3_2P5MEFM4U3xmP860uMTMqqvMagrOBtBNClmwAuTcn611Y9VaR1Nb9i6mGjsSLtNrSfmkdCachU9_w",
#           "widthPx": 3000,
#           "heightPx": 4000,
#           "authorAttributions": [
#             {
#               "displayName": "Stefano Merighi",
#               "uri": "https://maps.google.com/maps/contrib/100902344886524646680",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVlok2JP0fUlKE37CfPP2q8qmjNDFhzV7i4-QQANRrvEK3BTZlYiA=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICmv_uRAQ&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICmv_uRAQ!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5DGqmn1PQZ1mKWyDPJUMLrJTKHoBbNsxdGS75bLblIQQ9suo7jIIUsQqdplgGbh0QDIdd-T1BCb-_uuNs1P0qIpkxfYDv7LTsIjDlqqanqXvTbSx5-WQ7a5-I5QO_pfzKt6i9G1nunPQe2mKaXvsVZ0JWQCQC37MGRc2AL9OxbLkgLTAaZpEhSuB84fUh02cvHm_0W0AYKAjPgEE-9tlF2DUnpPP5tmLgVzrZGXyg4c_VjKbB1zPX9OC6W16BzswzI_yhvdS4SI2zGhWmEwh0HtF4Sy4kpex_O1wdy_EbWXqhix4KGLxXIPgJqe0IlnyxUuwj9Yf5G1VHlhdTcGYcKVUmk_2PI_AP1p3lyc9mSs8Xl7Gs4PAI55W0rTjiC7C7teBtWFLD95sM2NSSlU-isXybsDk5sDBrY3ny2-aE",
#           "widthPx": 2272,
#           "heightPx": 1836,
#           "authorAttributions": [
#             {
#               "displayName": "Marco Mongitore",
#               "uri": "https://maps.google.com/maps/contrib/117247794346755004430",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocIenO4PrC7jbH9298glrWmPQRGsPnI2BnA0H3nAssp0ujjqlkfV=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDcj-22Hw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDcj-22Hw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU6rlr6Ezd10cj3noUWsl5R_Za9ZRVFQgMgUygpEs9dcP4K7oQSdwYcNMhNMPkb5jt3vPByHLcs7Fte-szJ6pfvH96TCEjct36TizPj6MnVZ9ZmMLGLoy39q0r0T7SzuWzxUCTmPBZwpOX9E4EM_ccZlSiBmkW6OUvVaxZiL5G45N6uqCiZyPXcMhBD4ySU0pVQE8MbGb7eJn2MMb5xaV_fzNo9gzmIVFnBTB4e7u8qvSsa-kbYXKC1DJWhNimA1FYS04kcCN_FAypBPqdtsJ4ST16UVschKMGwb3RPba5QXus_eyp7gQUvdmbjcwsGTNnXQwBiJZi2O1MWobOQIqpCu62QE8wgxQxOkdx8CQReRsPE11LwKLunmZkDBd_o7WjrvOx-Nkb5Te50k5PMtOId6arbtciaXBMQ11fD5ue6UAqzh",
#           "widthPx": 4000,
#           "heightPx": 3000,
#           "authorAttributions": [
#             {
#               "displayName": "Cristina",
#               "uri": "https://maps.google.com/maps/contrib/109109969557698215870",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocI0_XUNiyglPjHsgBgMQk5FYUxrzN_OnKCNTNvXG_p0nEXYKQ=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICKgfiM9AE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICKgfiM9AE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU54sHfeDwgyqZBTBDC0LlqEy3pSHkFY-Toe7lf2Hjf0GAubyK1dIaZjRK4vHzrhgyY5ANyg1lBV47XXb2I-Q8OixhHV0YUAcrGgN4SABwnVT0qKXxyNd_yxtf8p3vrDbWDszUYQtecT2x1_YQts7m0lusyGEZyeeLW5ffj31g5BdASXgpF1kCCxTNX3HIqWRhnee4eCNQkEpf284doTeG9h3_229qRHe1h6YQFq7VSCsKx2lje2O9-Z1Ez5kXBoReUQv9f57aUkcVD5DDxlndS70beriRz_tB2KZVMiV_bSSdPtuY16a27QSDsOxUTaZo8fPVgSWIejtGXzRqxaXBkk_ylz7G0EG2wVSwbeE41q1k499XVwilplXJWRDr07MkWDuqkhRHG0eysDMPNJEGF_gHkp09XIbUYZJSmmW3Q",
#           "widthPx": 3968,
#           "heightPx": 2976,
#           "authorAttributions": [
#             {
#               "displayName": "massimo forni",
#               "uri": "https://maps.google.com/maps/contrib/104350402342410590076",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWoJQaKQ7ujCnhtx6izg3Z-on_EccHRbc5hGnDni2IY3i9Y62h6=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDqvr-_Vg&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDqvr-_Vg!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU4L5fP_5HUypmUL_LwFc-bqy-2wEBkQzBQTCbm2vKnKij1-ka-gOsRoZA9x6_B5-0LCODhGfnqSZfb7n9KsXy3yBsghTtysJNrPJP-S0B6UqKxF3LL3_DkmSdaG7qwLyHVCiZGmtUw_BD6zG9at2O_xGDmtpjXlayhKKI9R_h-PYeV3co9t3JNRkjwtEUsDBx7yOs4gBqB7fpyNMsDOiXE2QDXYkKkrmHEryFzHWn7XL7oXyGsLIUuG5JFaFC5KW1H4g5d0JTFaMJGt_439aGWANIYuaa3862dc4Mt5xtdnbxC4Mh3sk3o4hx_EmXWPXG55MEAIuenOMIjfJ1s7yqVoXDw1Dk7L9R_C0806X9TlpYzxwFByLYg0Riayk26Sds4bbqdwxAl77o4TlPP_GsAGkN9_W4JgFji21HlV37Jdj2fm",
#           "widthPx": 3648,
#           "heightPx": 2736,
#           "authorAttributions": [
#             {
#               "displayName": "Marco Monti",
#               "uri": "https://maps.google.com/maps/contrib/117527048640464687964",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXaUVUApnk1gR10KDu36WgSAQvFub2qap2N4LSukdcu1eDRoZw3=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIC2joXNuQE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIC2joXNuQE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU6YA7xTIY7eKVjbvMocKIotYy3PXEAekZPbLXAHqCO4ohGpJuhxArv4Y-0vK4Eyk4sBihULsX6I2yYuICTO5ziGFiT3mKl35vMmsBz7sISuBotbtfPU01m_eZh4GTk2unZ7iJk59q39FwGibgoYJJbBAE1I-QrJK01cf5BwDOfbTS-r9zD-kBcSxDpeDIi_q4BVMcdfUtOyaPjXsQDDPOy7wcFSljY4gucXnOZbqnWtr1fZGS54qXPWTgJulkqIKOXqDGAmhJqHss7P497wyVS5BDBFQkGmssqJp8P82BTHsLell5Rf785dsXDY-COF5Pd5UvXb4pXrS8cgcJRFyFpvLGQKfF7PiqffkGcDFw6MIiVZy2pYOGjL3w8YqvQaMKO-gjIw4yjfumq24oA2p4TvCDquySVFy4uXLxALD94QlA",
#           "widthPx": 4608,
#           "heightPx": 3456,
#           "authorAttributions": [
#             {
#               "displayName": "Mars Gofabeatz",
#               "uri": "https://maps.google.com/maps/contrib/116262144135072295136",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXBp-dEsKqjaOUNJt7wR525pL5f-3GZ0SrNNr86qEY0vSTgs1B-Vw=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDRlK7CNA&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDRlK7CNA!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         }
#       ],
#       "goodForChildren": true,
#       "allowsDogs": true,
#       "paymentOptions": {
#         "acceptsCreditCards": true,
#         "acceptsDebitCards": true,
#         "acceptsCashOnly": false
#       },
#       "accessibilityOptions": {
#         "wheelchairAccessibleParking": true,
#         "wheelchairAccessibleEntrance": true
#       },
#       "addressDescriptor": {
#         "landmarks": [
#           {
#             "name": "places/ChIJ8-EjLcTUf0cRHy_epY_lpPI",
#             "placeId": "ChIJ8-EjLcTUf0cRHy_epY_lpPI",
#             "displayName": {
#               "text": "Carrefour Express Porta Castiglione Store",
#               "languageCode": "en"
#             },
#             "types": [
#               "establishment",
#               "food",
#               "grocery_or_supermarket",
#               "health",
#               "point_of_interest",
#               "store",
#               "supermarket"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 31.259172,
#             "travelDistanceMeters": 32.876442
#           },
#           {
#             "name": "places/ChIJ396r0sXUf0cRtx-IP709mG8",
#             "placeId": "ChIJ396r0sXUf0cRtx-IP709mG8",
#             "displayName": {
#               "text": "Farmacia Dr. Max",
#               "languageCode": "it"
#             },
#             "types": [
#               "establishment",
#               "health",
#               "pharmacy",
#               "point_of_interest",
#               "store"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 29.39594,
#             "travelDistanceMeters": 15.978893
#           },
#           {
#             "name": "places/ChIJQ8QHycXUf0cRdnAeMobf1SM",
#             "placeId": "ChIJQ8QHycXUf0cRdnAeMobf1SM",
#             "displayName": {
#               "text": "Chiesa di Santa Maria della Misericordia",
#               "languageCode": "en"
#             },
#             "types": [
#               "church",
#               "establishment",
#               "place_of_worship",
#               "point_of_interest"
#             ],
#             "spatialRelationship": "DOWN_THE_ROAD",
#             "straightLineDistanceMeters": 77.96733,
#             "travelDistanceMeters": 71.19292
#           },
#           {
#             "name": "places/ChIJfxhFC8XUf0cR0Xo9dUoTA6s",
#             "placeId": "ChIJfxhFC8XUf0cR0Xo9dUoTA6s",
#             "displayName": {
#               "text": "Serre dei Giardini Margherita",
#               "languageCode": "en"
#             },
#             "types": [
#               "bar",
#               "establishment",
#               "food",
#               "point_of_interest",
#               "restaurant",
#               "school"
#             ],
#             "straightLineDistanceMeters": 216.12418,
#             "travelDistanceMeters": 231.01735
#           },
#           {
#             "name": "places/ChIJPf2OzsXUf0cRhB7p5uqjLII",
#             "placeId": "ChIJPf2OzsXUf0cRhB7p5uqjLII",
#             "displayName": {
#               "text": "B&B Al Parco Giardini Margherita Sconti Rizzoli e Villa Regina",
#               "languageCode": "en"
#             },
#             "types": [
#               "establishment",
#               "lodging",
#               "point_of_interest"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 22.453997,
#             "travelDistanceMeters": 20.678474
#           }
#         ],
#         "areas": [
#           {
#             "name": "places/ChIJLwKOhMXUf0cRSwyJnq_IU64",
#             "placeId": "ChIJLwKOhMXUf0cRSwyJnq_IU64",
#             "displayName": {
#               "text": "Giardini Margherita",
#               "languageCode": "en"
#             },
#             "containment": "NEAR"
#           },
#           {
#             "name": "places/ChIJn_75kpXUf0cRlcgftj_FyYI",
#             "placeId": "ChIJn_75kpXUf0cRlcgftj_FyYI",
#             "displayName": {
#               "text": "Old Town",
#               "languageCode": "en"
#             },
#             "containment": "OUTSKIRTS"
#           }
#         ]
#       },
#       "googleMapsLinks": {
#         "directionsUri": "https://www.google.com/maps/dir//''/data=!4m7!4m6!1m1!4e2!1m2!1m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!3e0?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "placeUri": "https://maps.google.com/?cid=3277797724925377160&g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "writeAReviewUri": "https://www.google.com/maps/place//data=!4m3!3m2!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!12e1?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "reviewsUri": "https://www.google.com/maps/place//data=!4m4!3m3!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!9m1!1b1?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "photosUri": "https://www.google.com/maps/place//data=!4m3!3m2!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!10e5?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA"
#       },
#       "timeZone": {
#         "id": "Europe/Rome"
#       },
#       "postalAddress": {
#         "regionCode": "IT",
#         "languageCode": "en-US",
#         "postalCode": "40136",
#         "administrativeArea": "Metropolitan City of Bologna",
#         "locality": "Bologna",
#         "addressLines": [
#           "Viale Giovanni Gozzadini"
#         ]
#       }
#     }
#   ]
# }
# ============================================================
# {'latitude': 44.4827156, 'longitude': 11.3524117}

# %%
import os
import requests

# Street View Static API URL
url = "https://maps.googleapis.com/maps/api/streetview"

# Use Piazza Maggiore coordinates (city center - has Street View coverage)
lat = 44.4949
lng = 11.3426

params = {
    "location": f"{lat},{lng}",  # Required: lat,lng coordinates
    "size": "640x640",            # Required: image size (max 640x640)
    "heading": 0,                 # Optional: camera direction in degrees (0-360)
    "pitch": 0,                   # Optional: vertical angle (-90 to 90, 0 = level)
    "fov": 90,                    # Optional: zoom level (10-120, higher = zoomed in)
    "key": API_KEY_GMP
}

response = requests.get(url, params=params)

print("Status Code:", response.status_code)
if response.status_code == 200:
    # Save the image
    with open("street_view_test.jpg", "wb") as f:
        f.write(response.content)
    print("Image saved as 'street_view_test.jpg'")
else:
    print(f"Error: {response.text}")
# Out:
# Status Code: 200
# Image saved as 'street_view_test.jpg'

# %% [markdown]
# ## Build the pipeline
#
# We will write a function that samples `N` points around the radius `R` starting from a fixed location `center`.
#
# It will need to retry because we may encounter locations that do not have street views associated; we will implement this later on.

# %%
import random
import math

def sample_points_in_radius(center : tuple[float, float], radius : float, N : int) -> list[tuple[float, float]]:
    """
    Sample N points in a circle of radius R centered at center.

    Args:
        center: tuple of float, the center of the circle (lat, lon)
        radius: float, the radius of the circle in meters
        N: int, the number of points to sample

    Returns:
        list of tuples of float, the sampled points (lat, lon)
    """
    center_lat, center_lon = center
    points = []
    
    for _ in range(N):
        # Generate random angle and distance
        angle = random.uniform(0, 2 * math.pi)
        # Use square root for uniform distribution in circle
        distance = math.sqrt(random.uniform(0, 1)) * radius
        
        # Convert meters to approximate lat/lon offset
        # Rough approximation: 1 degree lat ≈ 111,000m, 1 degree lon ≈ 111,000m * cos(lat)
        lat_offset = distance / 111000
        lon_offset = distance / (111000 * math.cos(math.radians(center_lat)))
        
        # Calculate new coordinates
        new_lat = center_lat + lat_offset * math.cos(angle)
        new_lon = center_lon + lon_offset * math.sin(angle)
        
        points.append((new_lat, new_lon))
    
    return points

# %%
# Test the function
bologna_center = (44.4949, 11.3426)  # Piazza Maggiore
radius_meters = 1000  # 1km radius
n_points = 5

sampled_points = sample_points_in_radius(bologna_center, radius_meters, n_points)

print(f"Center: {bologna_center}")
print(f"Radius: {radius_meters}m")
print(f"Sampled {len(sampled_points)} points:")
for i, (lat, lon) in enumerate(sampled_points):
    print(f"  {i+1}: ({lat:.6f}, {lon:.6f})")
# Out:
# Center: (44.4949, 11.3426)
# Radius: 1000m
# Sampled 5 points:
#   1: (44.495616, 11.330674)
#   2: (44.502739, 11.346078)
#   3: (44.499131, 11.333339)
#   4: (44.502429, 11.344805)
#   5: (44.497327, 11.342983)

# %%
# Street View coverage validation
import os
import requests

API_KEY_GMP = os.getenv("GOOGLE_API_KEY")

# Funzione di Validazione con Street View Metadata API (Richiede l'API_KEY_GMP globale)
def validate_streetview_coverage(lat: float, lng: float):
    """
    Usa Street View Metadata per verificare se esiste un panorama per la location.
    Restituisce (has_coverage: bool, date: Optional[str], pano_id: Optional[str]).
    """
    global API_KEY_GMP

    metadata_url = (
        "https://maps.googleapis.com/maps/api/streetview/metadata?"
        f"location={lat},{lng}&"
        f"key={API_KEY_GMP}"
    )

    try:
        response = requests.get(metadata_url, timeout=5)
        response.raise_for_status()
        data = response.json()

        if data.get('status') == 'OK':
            date = data.get('date', None)
            pano_id = data.get('pano_id', None)
            return True, date, pano_id
        else:
            return False, None, None

    except requests.RequestException:
        return False, None, None

# %%
# Sample only points with Street View coverage (with retries)
import time
from typing import List, Tuple


def sample_points_with_coverage(center: tuple[float, float], radius_m: float, n_points: int,
                                max_attempts: int = 200, request_pause_s: float = 0.0) -> list[tuple[float, float]]:
    """
    Sample points uniformly within radius and keep only those with Street View coverage.
    Stops when n_points are found or max_attempts reached.
    """
    valid_points: List[Tuple[float, float]] = []
    attempts = 0

    while len(valid_points) < n_points and attempts < max_attempts:
        lat, lon = sample_points_in_radius(center, radius_m, 1)[0]
        has_cov, _, _ = validate_streetview_coverage(lat, lon)
        if has_cov:
            valid_points.append((lat, lon))
        attempts += 1
        if request_pause_s:
            time.sleep(request_pause_s)

    return valid_points

# %%
# Use the coverage-aware sampler
bologna_center = (44.4949, 11.3426)
radius_meters = 1000
n_points = 5

max_attempts = 100  # stop if we can't find N within this many attempts
sampled_points = sample_points_with_coverage(bologna_center, radius_meters, n_points,
                                            max_attempts=max_attempts, request_pause_s=0.0)

print(f"Requested {n_points} points; collected {len(sampled_points)} with Street View coverage.")
for i, (lat, lon) in enumerate(sampled_points):
    print(f"  {i+1}: ({lat:.6f}, {lon:.6f})")
# Out:
# Requested 5 points; collected 5 with Street View coverage.
#   1: (44.490150, 11.346975)
#   2: (44.487214, 11.342961)
#   3: (44.488098, 11.335104)
#   4: (44.497276, 11.336267)
#   5: (44.493867, 11.349124)

# %%
# Visualize with folium
import folium

# Create map centered on Bologna
m = folium.Map(location=bologna_center, zoom_start=13)

# Add the center point with a different marker
folium.Marker(
    bologna_center,
    popup='Center (Piazza Maggiore)',
    tooltip='Center',
    icon=folium.Icon(color='red', icon='flag')
).add_to(m)

# Add the sampled points
for i, (lat, lon) in enumerate(sampled_points):
    folium.Marker(
        [lat, lon],
        popup=f'Point {i+1}',
        tooltip=f'Point {i+1}',
        icon=folium.Icon(color='blue', icon='circle')
    ).add_to(m)

# Add a circle to show the radius
folium.Circle(
    location=bologna_center,
    radius=radius_meters,
    color='red',
    fill=False,
    weight=2,
    opacity=0.5
).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_531399066fc197375b417f1fd7f989a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_531399066fc197375b417f1fd7f989a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_531399066fc197375b417f1fd7f989a6 = L.map(
#                 &quot;map_531399066fc197375b417f1fd7f989a6&quot;,
#                 {
#                     center: [44.4949, 11.3426],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f62c0ec77dc0a206572d8eb5cc47a2f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f62c0ec77dc0a206572d8eb5cc47a2f.addTo(map_531399066fc197375b417f1fd7f989a6);
#
#
#             var marker_0c87faf3b7735ed753b82275c96c6290 = L.marker(
#                 [44.4949, 11.3426],
#                 {
# }
#             ).addTo(map_531399066fc197375b417f1fd7f989a6);
#
#
#             var icon_c3ea991f89e5cd736d95439365e011aa = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f3477ff9291bba84d9392286100c5ebb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7ed77000657b53a967ab7420f560b26 = $(`&lt;div id=&quot;html_a7ed77000657b53a967ab7420f560b26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Center (Piazza Maggiore)&lt;/div&gt;`)[0];
#                 popup_f3477ff9291bba84d9392286100c5ebb.setContent(html_a7ed77000657b53a967ab7420f560b26);
#
#
#
#         marker_0c87faf3b7735ed753b82275c96c6290.bindPopup(popup_f3477ff9291bba84d9392286100c5ebb)
#         ;
#
#
#
#
#             marker_0c87faf3b7735ed753b82275c96c6290.bindTooltip(
#                 `&lt;div&gt;
#                      Center
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_0c87faf3b7735ed753b82275c96c6290.setIcon(icon_c3ea991f89e5cd736d95439365e011aa);
#
#
#             var marker_aa622b176dd49163125f1424a2bdb01c = L.marker(
#                 [44.49015019313098, 11.346974736203409],
#                 {
# }
#             ).addTo(map_531399066fc197375b417f1fd7f989a6);
#
#
#             var icon_43d9e5651f288b32a40fed3df3ceed63 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;circle&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_cf00f98369354dad5475f0d22be19728 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8424875239deb6f93c56dad9630c7f1 = $(`&lt;div id=&quot;html_b8424875239deb6f93c56dad9630c7f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 1&lt;/div&gt;`)[0];
#                 popup_cf00f98369354dad5475f0d22be19728.setContent(html_b8424875239deb6f93c56dad9630c7f1);
#
#
#
#         marker_aa622b176dd49163125f1424a2bdb01c.bindPopup(popup_cf00f98369354dad5475f0d22be19728)
#         ;
#
#
#
#
#             marker_aa622b176dd49163125f1424a2bdb01c.bindTooltip(
#                 `&lt;div&gt;
#                      Point 1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_aa622b176dd49163125f1424a2bdb01c.setIcon(icon_43d9e5651f288b32a40fed3df3ceed63);
#
#
#             var marker_4131da95e325ad7b773f04b44f80fcf0 = L.marker(
#                 [44.487213818056404, 11.342960501438624],
#                 {
# }
#             ).addTo(map_531399066fc197375b417f1fd7f989a6);
#
#
#             var icon_3b93b4eeef5fb1ff0dc13ce1e18feb19 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;circle&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_07bd4fffd44a5ee76ff77c87f0a0e414 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e26a5400d4f5e3a41205e2034782621 = $(`&lt;div id=&quot;html_9e26a5400d4f5e3a41205e2034782621&quot; style=&quot;width: 100.0

# %%
# Build Street View URL entries and save to CSV (URLs without API key)
import os
import pandas as pd

# Configuration
size = "640x640"
fov = 90
headings = [0, 90, 180, 270]
pitches = [-45, 0, 45]
include_key_in_csv = False  # avoid exposing API key in the CSV

streetview_base = "https://maps.googleapis.com/maps/api/streetview"

rows = []
for point_idx, (lat, lon) in enumerate(sampled_points):
    for heading in headings:
        for pitch in pitches:
            # Skip rotating sky views - sky looks the same from all directions
            if pitch == 45 and heading != 0:
                continue
                
            params = {
                "size": size,
                "location": f"{lat},{lon}",
                "heading": heading,
                "pitch": pitch,
                "fov": fov,
            }
            # URL without the key (safe to store/share)
            url_no_key = (
                f"{streetview_base}?size={params['size']}&location={params['location']}"
                f"&heading={params['heading']}&pitch={params['pitch']}&fov={params['fov']}"
            )
            # Template with placeholder for key (for agents that can inject it)
            url_with_placeholder = url_no_key + "&key={API_KEY}"
            # Optionally materialize with your key (not recommended to persist)
            url_with_key = (
                url_no_key + f"&key={API_KEY_GMP}" if include_key_in_csv else None
            )

            rows.append({
                "point_index": point_idx,
                "lat": lat,
                "lon": lon,
                "heading": heading,
                "pitch": pitch,
                "fov": fov,
                "size": size,
                "url_template": url_with_placeholder,
                "url_no_key": url_no_key,
                "url_with_key": url_with_key,
            })

sv_df = pd.DataFrame(rows)
print(f"Generated {len(sv_df)} Street View entries for {len(sampled_points)} points.")
sv_df.head()
# Out:
# Generated 45 Street View entries for 5 points.
#    point_index       lat        lon  heading  pitch  fov     size  \
# 0            0  44.49015  11.346975        0    -45   90  640x640
# 1            0  44.49015  11.346975        0      0   90  640x640
# 2            0  44.49015  11.346975        0     45   90  640x640
# 3            0  44.49015  11.346975       90    -45   90  640x640
# 4            0  44.49015  11.346975       90      0   90  640x640
#
#                                         url_template  \
# 0  https://maps.googleapis.com/maps/api/streetvie...
# 1  https://maps.googleapis.com/maps/api/streetvie...
# 2  https://maps.googleapis.com/maps/api/streetvie...
# 3  https://maps.googleapis.com/maps/api/streetvie...
# 4  https://maps.googleapis.com/maps/api/streetvie...
#
#                                           url_no_key url_with_key
# 0  https://maps.googleapis.com/maps/api/streetvie...         None
# 1  https://maps.googleapis.com/maps/api/streetvie...         None
# 2  https://maps.googleapis.com/maps/api/streetvie...         None
# 3  https://maps.googleapis.com/maps/api/streetvie...         None
# 4  https://maps.googleapis.com/maps/api/streetvie...         None

# %%
# Save to CSV
out_csv = "streetview_samples.csv"
sv_df.to_csv(out_csv, index=False)
print(f"Saved {len(sv_df)} rows to {out_csv}")
# Out:
# Saved 45 rows to streetview_samples.csv

# %%
# Add layer column (ground/horizon/sky) and point_id, then save layered CSV

def classify_layer(pitch: float) -> str:
    if pitch <= -30:
        return "ground"
    if pitch >= 30:
        return "sky"
    return "horizon"

sv_df["layer"] = sv_df["pitch"].apply(classify_layer)
sv_df["point_id"] = sv_df["point_index"]

# Reorder columns for readability
cols = [
    "point_id", "point_index", "lat", "lon", "layer",
    "heading", "pitch", "fov", "size",
    "url_no_key", "url_template", "url_with_key",
]
sv_df = sv_df[cols]

layered_csv = "streetview_samples.csv"
sv_df.to_csv(layered_csv, index=False)
print(f"Saved layered CSV with {len(sv_df)} rows to {layered_csv}")
sv_df.head(10)
# Out:
# Saved layered CSV with 45 rows to streetview_samples.csv
#    point_id  point_index        lat        lon    layer  heading  pitch  fov  \
# 0         0            0  44.490150  11.346975   ground        0    -45   90
# 1         0            0  44.490150  11.346975  horizon        0      0   90
# 2         0            0  44.490150  11.346975      sky        0     45   90
# 3         0            0  44.490150  11.346975   ground       90    -45   90
# 4         0            0  44.490150  11.346975  horizon       90      0   90
# 5         0            0  44.490150  11.346975   ground      180    -45   90
# 6         0            0  44.490150  11.346975  horizon      180      0   90
# 7         0            0  44.490150  11.346975   ground      270    -45   90
# 8         0            0  44.490150  11.346975  horizon      270      0   90
# 9         1            1  44.487214  11.342961   ground        0    -45   90
#
#       size                                         url_no_key  \
# 0  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 1  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 2  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 3  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 4  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 5  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 6  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 7  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 8  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 9  640x640  https://maps.googleapis.com/maps/api/streetvie...
#
#                                         url_template url_with_key
# 0  https://maps.googleapis.com/maps/api/streetvie...         None
# 1  https://maps.googleapis.com/maps/api/streetvie...         None
# 2  https://maps.googleapis.com/maps/api/streetvie...         None
# 3  https://maps.googleapis.com/maps/api/streetvie...         None
# 4  https://maps.googleapis.com/maps/api/streetvie...         None
# 5  https://maps.googleapis.com/maps/api/streetvie...         None
# 6  https://maps.googleapis.com/maps/api/streetvie...         None
# 7  https://maps.googleapis.com/maps/api/streetvie...         None
# 8  https://maps.googleapis.com/maps/api/streetvie...         None
# 9  https://maps.googleapis.com/maps/api/streetvie...         None
