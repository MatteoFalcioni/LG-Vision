# %% [markdown]
# # Building up the pipeline to sample street views
#
# First, I want to see how Google APIs work and how i can combine them together.
#
# Specifically I want to check out:
#
# - Places API
# - StreetView API

# %% [markdown]
# I already got an API key and set it in my env file.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Global API key configuration
import os
API_KEY_GMP = os.getenv("GOOGLE_API_KEY")
assert API_KEY_GMP, "Missing GOOGLE_API_KEY in environment."

# %% [markdown]
# Call the places API in a radius around Bologna:

# %%
import os
import requests
import json

# Example request to Places API - Text Search restricted to Bologna
query = "Giardini Margherita"
url = "https://places.googleapis.com/v1/places:searchText"

headers = {
    "Content-Type": "application/json",
    "X-Goog-Api-Key": API_KEY_GMP,
    'X-Goog-FieldMask' : '*'   # many fields available, use '*' to get all
}

#useful: location contains lat and lon

# Bologna coordinates
bologna_lat = 44.4949
bologna_lng = 11.3426
radius_meters = 5000  # 5km radius

payload = {
    "textQuery": query,
    "locationBias": {
        "circle": {
            "center": {
                "latitude": bologna_lat,
                "longitude": bologna_lng
            },
            "radius": radius_meters
        }
    },
    "maxResultCount": 5  # Limit to 5 results
}

response = requests.post(url, headers=headers, json=payload)
data = response.json()

print("Status Code:", response.status_code)
print(f"\nSearching for '{query}' in Bologna (radius: {radius_meters}m)")
print(f"\nNumber of results: {len(data.get('places', []))}")
print("\nResponse:")
print(json.dumps(data, indent=2))
# Out:
# Status Code: 200
#
# Searching for 'Giardini Margherita' in Bologna (radius: 5000m)
#
# Number of results: 1
#
# Response:
# {
#   "places": [
#     {
#       "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0",
#       "id": "ChIJLwKOhMXUf0cRiLrCD6oTfS0",
#       "types": [
#         "hiking_area",
#         "tourist_attraction",
#         "park",
#         "sports_activity_location",
#         "point_of_interest",
#         "establishment"
#       ],
#       "nationalPhoneNumber": "051 203040",
#       "internationalPhoneNumber": "+39 051 203040",
#       "formattedAddress": "Viale Giovanni Gozzadini, 40136 Bologna BO, Italy",
#       "addressComponents": [
#         {
#           "longText": "Viale Giovanni Gozzadini",
#           "shortText": "Viale Giovanni Gozzadini",
#           "types": [
#             "route"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Bologna",
#           "shortText": "Bologna",
#           "types": [
#             "locality",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Bologna",
#           "shortText": "Bologna",
#           "types": [
#             "administrative_area_level_3",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Citt\u00e0 Metropolitana di Bologna",
#           "shortText": "BO",
#           "types": [
#             "administrative_area_level_2",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Emilia-Romagna",
#           "shortText": "Emilia-Romagna",
#           "types": [
#             "administrative_area_level_1",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Italy",
#           "shortText": "IT",
#           "types": [
#             "country",
#             "political"
#           ],
#           "languageCode": "en"
#         },
#         {
#           "longText": "40136",
#           "shortText": "40136",
#           "types": [
#             "postal_code"
#           ],
#           "languageCode": "en-US"
#         }
#       ],
#       "plusCode": {
#         "globalCode": "8FPHF9M2+3X",
#         "compoundCode": "F9M2+3X Bologna, Metropolitan City of Bologna, Italy"
#       },
#       "location": {
#         "latitude": 44.4827156,
#         "longitude": 11.3524117
#       },
#       "viewport": {
#         "low": {
#           "latitude": 44.48259271970851,
#           "longitude": 11.348590399999999
#         },
#         "high": {
#           "latitude": 44.4852906802915,
#           "longitude": 11.352411700000001
#         }
#       },
#       "rating": 4.6,
#       "googleMapsUri": "https://maps.google.com/?cid=3277797724925377160&g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#       "websiteUri": "http://www.comune.bologna.it/",
#       "regularOpeningHours": {
#         "openNow": true,
#         "periods": [
#           {
#             "open": {
#               "day": 0,
#               "hour": 0,
#               "minute": 0
#             }
#           }
#         ],
#         "weekdayDescriptions": [
#           "Monday: Open 24 hours",
#           "Tuesday: Open 24 hours",
#           "Wednesday: Open 24 hours",
#           "Thursday: Open 24 hours",
#           "Friday: Open 24 hours",
#           "Saturday: Open 24 hours",
#           "Sunday: Open 24 hours"
#         ]
#       },
#       "utcOffsetMinutes": 60,
#       "adrFormatAddress": "<span class=\"street-address\">Viale Giovanni Gozzadini</span>, <span class=\"postal-code\">40136</span> <span class=\"locality\">Bologna</span> <span class=\"region\">BO</span>, <span class=\"country-name\">Italy</span>",
#       "businessStatus": "OPERATIONAL",
#       "userRatingCount": 17288,
#       "iconMaskBaseUri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/tree_pinlet",
#       "iconBackgroundColor": "#4DB546",
#       "displayName": {
#         "text": "Giardini Margherita",
#         "languageCode": "en"
#       },
#       "primaryTypeDisplayName": {
#         "text": "Park",
#         "languageCode": "en-US"
#       },
#       "currentOpeningHours": {
#         "openNow": true,
#         "periods": [
#           {
#             "open": {
#               "day": 2,
#               "hour": 0,
#               "minute": 0,
#               "truncated": true,
#               "date": {
#                 "year": 2025,
#                 "month": 10,
#                 "day": 28
#               }
#             },
#             "close": {
#               "day": 1,
#               "hour": 23,
#               "minute": 59,
#               "truncated": true,
#               "date": {
#                 "year": 2025,
#                 "month": 11,
#                 "day": 3
#               }
#             }
#           }
#         ],
#         "weekdayDescriptions": [
#           "Monday: Open 24 hours",
#           "Tuesday: Open 24 hours",
#           "Wednesday: Open 24 hours",
#           "Thursday: Open 24 hours",
#           "Friday: Open 24 hours",
#           "Saturday: Open 24 hours",
#           "Sunday: Open 24 hours"
#         ]
#       },
#       "primaryType": "park",
#       "shortFormattedAddress": "Viale Giovanni Gozzadini, Bologna",
#       "editorialSummary": {
#         "text": "Popular public park with lots of trees, a lake & lawns, plus a jogging path & play areas for kids.",
#         "languageCode": "en"
#       },
#       "reviews": [
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/ChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE",
#           "relativePublishTimeDescription": "5 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Free of charge, easy access, designated areas for many choices from play grounds for kids to badminton for adults. Biking is allowed, too.\nGrab your picnic basket and spend the day here.\nOr bring your book and enjoy the resreshments/pastey at the caffea inside the park.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Free of charge, easy access, designated areas for many choices from play grounds for kids to badminton for adults. Biking is allowed, too.\nGrab your picnic basket and spend the day here.\nOr bring your book and enjoy the resreshments/pastey at the caffea inside the park.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Zuhal",
#             "uri": "https://www.google.com/maps/contrib/117843459985379991032/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWSs1QQ9P4X5_D0vCwFwIInIqTUffw7UZOM_BhqGnjSqTy3Dnpn=s128-c0x00000000-cc-rp-mo-ba4"
#           },
#           "publishTime": "2025-05-03T10:30:48.565848Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB",
#           "relativePublishTimeDescription": "3 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Giardini Margherita is Bologna\u2019s most beloved park\u2014a peaceful, green escape perfect for relaxing, walking, or picnicking. With tree-lined paths, a small lake, caf\u00e9s, and play areas, it\u2019s popular with locals and visitors alike. Ideal for a break from the city\u2019s bustle, especially on sunny days. Great for solo travelers, families, or anyone wanting a breath of fresh air in a beautiful setting.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Giardini Margherita is Bologna\u2019s most beloved park\u2014a peaceful, green escape perfect for relaxing, walking, or picnicking. With tree-lined paths, a small lake, caf\u00e9s, and play areas, it\u2019s popular with locals and visitors alike. Ideal for a break from the city\u2019s bustle, especially on sunny days. Great for solo travelers, families, or anyone wanting a breath of fresh air in a beautiful setting.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Dani Baal",
#             "uri": "https://www.google.com/maps/contrib/103357020897930875043/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXd5F4_0jTgLXfmVTKm-2qvHv52-mDsO2tP9IWzdgV09PasJeSo=s128-c0x00000000-cc-rp-mo-ba7"
#           },
#           "publishTime": "2025-07-28T12:37:34.868920783Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/ChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB",
#           "relativePublishTimeDescription": "7 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Beautiful green space easily accessible from the center of Bologna.  Some playgrounds, remote working space, walkways great for kids to ride bicycles on and some playgrounds. There are a few cafe\u2019s and bars as well and a very small go kart course with electric go karts and pedal karts.  It\u2019s a gem in this city and a must visit on a nice day.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Beautiful green space easily accessible from the center of Bologna.  Some playgrounds, remote working space, walkways great for kids to ride bicycles on and some playgrounds. There are a few cafe\u2019s and bars as well and a very small go kart course with electric go karts and pedal karts.  It\u2019s a gem in this city and a must visit on a nice day.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Aldo Pinotti",
#             "uri": "https://www.google.com/maps/contrib/101428219914666686008/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVcPEKbbFMj1FaxARFYvyiVYEGsWZBBiDVb8Ub98FPERNqYWwgEyw=s128-c0x00000000-cc-rp-mo-ba3"
#           },
#           "publishTime": "2025-03-24T15:48:07.497659Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB",
#           "relativePublishTimeDescription": "2 weeks ago",
#           "rating": 5,
#           "text": {
#             "text": "Very nice park with a lovely picnic / bar area at the back, near the botanical area.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Very nice park with a lovely picnic / bar area at the back, near the botanical area.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Holly Pope",
#             "uri": "https://www.google.com/maps/contrib/111127058743800932797/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWZOw83XmvpAxB6atDufAr8WzVQ0NMaWaPUrxUti9wkeVncdQK1=s128-c0x00000000-cc-rp-mo-ba3"
#           },
#           "publishTime": "2025-10-11T12:52:40.557526010Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB",
#           "relativePublishTimeDescription": "a week ago",
#           "rating": 5,
#           "text": {
#             "text": "One of the city's many green spaces. Beautiful and quiet!",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "One of the city's many green spaces. Beautiful and quiet!",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Desart Ajazi",
#             "uri": "https://www.google.com/maps/contrib/116110492896188753454/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVz6_AmSIYggCVaxgOqjgePmbiRDdj3I_c0wYfPXmsqsHGbcUe0Cw=s128-c0x00000000-cc-rp-mo-ba2"
#           },
#           "publishTime": "2025-10-16T21:03:11.109817558Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         }
#       ],
#       "photos": [
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU70EuxWYG_7GNVg9RFCLWp3HWyD_boOYHz9nxZHcqpX3PNlc5goY7EYfExT6UXRm-FthaQGmYqWsiXWpiQ7H_U3o59uT1PIPpGwRDB_mXkszGoThxIxr-Z_HJCBpNqEex4QFQ2Fo_-9H3SblLR8N85jpO2WGdC-jrroya4_kA1ZRFD_5qMX8SMunMk-YB3Sk5gDR56ygZgjkFa9A7zEsMklUpusWt8NzPWzyjqG7hK5rg7AC8Vp3rBO9sK2g6J3N8wJabNciAdwCamL3BIoCNVTPyCbL37dSD0_QXUALCJjETKUSEmTdTy2zJxRH5ncz4qsACC-JsHf5V0Ffj5e7bGIlNec-lYP6bDet51ciPeW8Tcqm0jBM3ulgqeI--WmTEHQHL0HODE1mMYGQFXiLHGZHNB-2RZ-ON8QBlENJTHt7FBZ",
#           "widthPx": 3024,
#           "heightPx": 4032,
#           "authorAttributions": [
#             {
#               "displayName": "Phanendra das",
#               "uri": "https://maps.google.com/maps/contrib/116022813752209071834",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVunoPhApjuMp4Jzb0pegqb8AXkpXP-YalBn3EIe8u5aRFM022k=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgID7-vrO1QE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgID7-vrO1QE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5-pS7eUrbp37CWod0fFdElUsL29sKj5ZUdkr5BLpG8O0ksdOGtxwImj0Zqb8vBtTzeH7Y8uLuP1VWvQ4B0IY5MqCsioUe56cwmj5E0B_MBktehpsMqSBj8xF5YxbSiWvSuUvvs6KfJYvjtpvmZUSonQIOVyjxIZZF9TKy66ffZcsxgYB_zhTB_4KVyzLr--RB9h5oGif3W78Gok8MSYpA9v9_TuSJFJWNAkKuOM_Rb2q2GtGuaGuamVn1T9o4asCkkqecyOlNmL-var1m5V4KOKxINxjRoiFJzD5zt34XB4TLRTV8FeOx54wbosU4NZf4CTkFsfZIBmsm-_xipK_LTEq1C0m9Y-0CQZsxyN1PXpOwi0Yt1meAX0Tw4Wqbpc3CamyOmDLvAbLkBWV3NLqGFTNts3QrdL_n4wM5GA1-SpMjB",
#           "widthPx": 3600,
#           "heightPx": 4800,
#           "authorAttributions": [
#             {
#               "displayName": "Giorgio Fanigliulo",
#               "uri": "https://maps.google.com/maps/contrib/117481865498945288789",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocLkuf7-zukIxOywXFuHoa37kpEoKqtO38yaq0Zt1SF0SVWekA=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgID63fLgjwE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgID63fLgjwE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU7hy5KTzxTCq_nikRPgKsZNDbny-rXsDpR8c-u7EGAv0r6oRceCjzibEMPW73onBOGVn59W1kab0lLqRVgGghC2N2a7fkgOM6o_R-2ZV1SM-BE7jy3cdvzWu7Q-l29Wze8w5MJ9NLp9N6atJV16dyUx9fOYUxCFoyMK45Fjefn6oXDgMUB494sDQb9wqxvPTj41xCeSpaXjzSES_pH18TXM6k17RCxvchpK0RxDMvw4y7SSMkvaLvw6BhVecUK843KqaXtUNvgd9cjV_qSOGgc5pX9a_Zb21LERXbrHcxy8YzOGMqvSUHngTxMJffBdvofyDti_9tvh_-HT06y4p1Aies5VDeNdzJoLz_MJOgzXm0LNffXHPTprtGM20oT5aT1Demr4_nMX3nVkKkWV2Jye0Tz32MRCuSuvRQ0t6EU3sg",
#           "widthPx": 3456,
#           "heightPx": 4608,
#           "authorAttributions": [
#             {
#               "displayName": "Giorgio Scarabelli",
#               "uri": "https://maps.google.com/maps/contrib/117147474204335919716",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVOKqJAVuxnwSYNOyRbCRTPzAgexBsZCf0oCkbNhdlYgABi9eG7=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEJyj89nwnPORCw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEJyj89nwnPORCw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5btl_68zN58hE8eskc2EGB-gOfw1-xm0CXOog2cSlHeDwYFUUk-HeK9dolV4nu8Cs_ouKYnLZPea6RYa_9OdvpO2eGY70BFw7OZ-WN84tmH_TP92vcvLhz6tZNYdyNBS_UTj6RhcdH2AGoRHuutSlNpDQRsrLZgvCgk82v7pIglkd5KjSI4aigx2cNB3khDiUTUVHkoojp8eGOf0Jg-joNkboAjsLMzItCgc8zjMP0pSTA6TmTym9DJNeED9MEikhIwhgVdqAjNtGiCoWV0ySZZ5w2uiGM0_OeHHJsAhchRqWl52CP1ijhU8k16D4qXTzcCBhBl8yskKxVZmVtXNo1sdm-8EI3ay1A1s_VdzCIGdUwNe6MHD5e6hHWo96IUKjO5IN__sqtpToxFsELYeyiRxiHMaDFcRNRWxj4FB49aYB_",
#           "widthPx": 4032,
#           "heightPx": 3024,
#           "authorAttributions": [
#             {
#               "displayName": "Diana B",
#               "uri": "https://maps.google.com/maps/contrib/114064809743683456601",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVfheGMKzOKVjl0o1d2cjMqF-PTjdtooKQHpOJBhdXO4ln1cdYj=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICO3ZndwQE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICO3ZndwQE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU6W6KUO28_Ne9Q8md6GbgJ3Oo3Xmwn93szmZbdCExGNILBwYKKTUHja-oWQrCcYSghdEspJCBPLg8QAm-IC6ZfeXJJfnjh8BDLmERIZVDzAKM0JHDc7pNjPc_uUPVrDIEM7f7UqV4HnszF_961ULhIxhxRe6cBkNDcCPF_iUNNWQtuyZ5Uc7wCSTczP8f2Q2tNSYmeb9ylXkMfxjKP4KfTkeeWya3nk6NZ45rgNxwynyArn-iKVszQywM4IOUaOzUWkuT21SyAczuUQio7eLxP6SMNx9N5GuRsdYhIbr5mLFFVVQWMGZ9jRVL2rK20kNsymHDmY9qKFGzNGJfd_GZrkQ2j6lZq103wrF_Ims3cRGSNy_IrQXXVp0rjCptDaYeSfi4USgK6hmZpzdnQzgqYeZnKS4rZoE6321e3tq03x5w",
#           "widthPx": 3000,
#           "heightPx": 4000,
#           "authorAttributions": [
#             {
#               "displayName": "Stefano Merighi",
#               "uri": "https://maps.google.com/maps/contrib/100902344886524646680",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVlok2JP0fUlKE37CfPP2q8qmjNDFhzV7i4-QQANRrvEK3BTZlYiA=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICmv_uRAQ&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICmv_uRAQ!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU6H5X8ElVzSZdzbXfFtJp9F96CoSnwtqR7H4Q4zBMvqVVFWmcHqjS7_saCTPdRjaMxjGad2U9OFjhkLpn1dszLFA4Vev7CsuHK9m9btjg-TdfSmIi9aWx_dTO-7rHMbG3LUCljpLXUHNH9er5J-CJ-DvpRZFFRoxykaNShtzHBjTG1vbQJvHmvhiCxNMMsItNJl82m6zvTtm-Dt_QkarWXeZJxZacHFir7CEmy3u9CZmvpUGuYEIgEROhdt9cCVcDbGisWvvpHbGXl9LW8inkF4BkVd3aroVPXW7KY8o2u13m-RmhuPdqgd6lIFGhiFUXu0BGphwk7u-JlxJlJWLucIXNgtH3CPusZ8oX94BkDVF_DPUyEmsOBx2asltATMXlYeIuu4Hb2s1OGBPVQj064Cjm4bd-ElUWBSp9P11Uo",
#           "widthPx": 2272,
#           "heightPx": 1836,
#           "authorAttributions": [
#             {
#               "displayName": "Marco Mongitore",
#               "uri": "https://maps.google.com/maps/contrib/117247794346755004430",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocIenO4PrC7jbH9298glrWmPQRGsPnI2BnA0H3nAssp0ujjqlkfV=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDcj-22Hw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDcj-22Hw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU54s8xBh7OvM50JBjaD6M0w4_3BxT4IOGvNjfKZfAICXhn1e0SuTYnbarr64v3A1fmPwa7F0gD3AfjD-BDuloZS9pE_6sPt2aXvhNmQWsXCLfj1g4Yx2QRDZUMPtXDXq-FyUgtoj4B6ryanM8WV_6kTzx2914kmSFdCvqTHqDCwcChHaUd6ko4g9dOfTHYeY1eRXhMOeoDHvfd6sco_7QEZNeEiSmsYEuYCGK_wYqYOSxV-SPn9BikHfxRcLc4CEPZ3YE5Avt6oXh4E1yPocSNvK0vV5ZsfmW1BbLw93p-Wq-cfj0WGFGF1RqguMdQPwmO81R7b0Czy5qa69mDzxai_cp-wmUrvTKpwCHKkT4GZEO2ZJ4JMzN6NAFQzPYLGfGtLUkQwVkUbdHbXngRfps3TuJaRhNNEiMWedFZ5wFIdduPL",
#           "widthPx": 4000,
#           "heightPx": 3000,
#           "authorAttributions": [
#             {
#               "displayName": "Cristina",
#               "uri": "https://maps.google.com/maps/contrib/109109969557698215870",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocI0_XUNiyglPjHsgBgMQk5FYUxrzN_OnKCNTNvXG_p0nEXYKQ=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICKgfiM9AE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICKgfiM9AE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU79aR8dltO4gAG68HbQOMldXwUnWK2B9jzgvvvelhb_Ac3hGpTBv1Ul0gRRsBZUJZkvA6xhOaOEidrIx79lltdRCTTv95OCnFzysEhBwmNbBK3IQ7snx1eYm0SOc_NeVnhJGMuU48PIixb7KGwTnTtMLWFJOnx1fduHPLxTWdKYkk296rEfBJI3fkOhbCSG-MINcA3FtlN8xV2Ue2PLIbc7HuGfdqb6Fp8NZ4EBgSDPlLXsGZ63Rou7gzdxqgJwUDwEKFQ7ds-WFLxRjHTIUogKibLHVx6pJ3-EI4c0tejq3T7Pf8h3w1bcecPrW_dgjskN50xzvKziWJQQbxe1dOsxDuDETPZ52aqhao9uDXC8h8d293vHmeEKat3zx467sh7eYdf0MCY0a0zJ1R2vuXjJlDxjikh6RguraHGGEOo",
#           "widthPx": 3968,
#           "heightPx": 2976,
#           "authorAttributions": [
#             {
#               "displayName": "massimo forni",
#               "uri": "https://maps.google.com/maps/contrib/104350402342410590076",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWoJQaKQ7ujCnhtx6izg3Z-on_EccHRbc5hGnDni2IY3i9Y62h6=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDqvr-_Vg&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDqvr-_Vg!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU4cWmHBKJ30V_R9Gnca56fPr0evmFGu9jYaReZw6_jpMl2dZ2soJmgWulhdI4wUNTR6WgW1zZf8rs0qztjYFr3R2Skt-IXW7BbnPa-bTX0SS25kY23un9-m4liG4Izd5bQoAa9IoS16zGYkoDV6Qv5IxBs-w9HVF3WzIUy8j9FkJEmvlhBRLS_fulvg04Qcc0JCuDUUO9fM2NWYmMphd_WQLWyGva5IAfRJPyfnqMnOVPxlw3xbE_8yp-_hWEZx5Y1waXxYavyT_6AiExtrbx6-OgebIRRQUaGfccrR322WWNu3ME0KwALljEV7basp6mdlDVBpUmrSRwEW1-WbVx5b37Y0Vzyc8g7-as6uT5u_jo2SQ-jjSBUE7Z4tPVwDpLLJu17_ia7D08kzZnCv3c1zCwZCSMXjRAwBptxGoRQXMVQq",
#           "widthPx": 3648,
#           "heightPx": 2736,
#           "authorAttributions": [
#             {
#               "displayName": "Marco Monti",
#               "uri": "https://maps.google.com/maps/contrib/117527048640464687964",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXaUVUApnk1gR10KDu36WgSAQvFub2qap2N4LSukdcu1eDRoZw3=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIC2joXNuQE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIC2joXNuQE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU48XbVX6IR615Pl3-mQo4VASMumtVjMF0SxKDMthOde2FweqdVZBEo8eY_9LYKhq-vlHOLGt-eTbb_r_ih-5i7TW0hmVRFOArAF-xxJdV7UFB7hG1JMmgjfqdtu-Ajq0uT6ubfFy-3sFhuW_iS3O_U5BsTHsXm2_tQ7py8Bc-CisD5dbo4dabXiUOUfyPYAeBFxSEbRJGrFyPmI1tSEzwWTKrCs7nk94Tz3tSIkgtJskZ5wxGEXmUvsbRkcnR0BtpixmupQh5RZz0rJrDaEUkkDhvcXyLIbaqQ4ymKMOGfZ8JwOvWlHwRLwynAVyj0_prhhiD8Ii0iDJ18tJ7h5nOTOt25-IuL3B-l5qYSLaoQo3XeRBei4Oy6uX4e9nPIFWBIlXaediamlxS4al8UJ06oGC4pZ8O9EXv4eEfEXF3UbPA",
#           "widthPx": 4608,
#           "heightPx": 3456,
#           "authorAttributions": [
#             {
#               "displayName": "Mars Gofabeatz",
#               "uri": "https://maps.google.com/maps/contrib/116262144135072295136",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXBp-dEsKqjaOUNJt7wR525pL5f-3GZ0SrNNr86qEY0vSTgs1B-Vw=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDRlK7CNA&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDRlK7CNA!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         }
#       ],
#       "goodForChildren": true,
#       "allowsDogs": true,
#       "paymentOptions": {
#         "acceptsCreditCards": true,
#         "acceptsDebitCards": true,
#         "acceptsCashOnly": false
#       },
#       "accessibilityOptions": {
#         "wheelchairAccessibleParking": true,
#         "wheelchairAccessibleEntrance": true
#       },
#       "addressDescriptor": {
#         "landmarks": [
#           {
#             "name": "places/ChIJ8-EjLcTUf0cRHy_epY_lpPI",
#             "placeId": "ChIJ8-EjLcTUf0cRHy_epY_lpPI",
#             "displayName": {
#               "text": "Carrefour Express Porta Castiglione Store",
#               "languageCode": "en"
#             },
#             "types": [
#               "establishment",
#               "food",
#               "grocery_or_supermarket",
#               "health",
#               "point_of_interest",
#               "store",
#               "supermarket"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 31.259172,
#             "travelDistanceMeters": 32.876442
#           },
#           {
#             "name": "places/ChIJ396r0sXUf0cRtx-IP709mG8",
#             "placeId": "ChIJ396r0sXUf0cRtx-IP709mG8",
#             "displayName": {
#               "text": "Farmacia Dr. Max",
#               "languageCode": "it"
#             },
#             "types": [
#               "establishment",
#               "health",
#               "pharmacy",
#               "point_of_interest",
#               "store"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 29.39594,
#             "travelDistanceMeters": 15.978893
#           },
#           {
#             "name": "places/ChIJQ8QHycXUf0cRdnAeMobf1SM",
#             "placeId": "ChIJQ8QHycXUf0cRdnAeMobf1SM",
#             "displayName": {
#               "text": "Chiesa di Santa Maria della Misericordia",
#               "languageCode": "en"
#             },
#             "types": [
#               "church",
#               "establishment",
#               "place_of_worship",
#               "point_of_interest"
#             ],
#             "spatialRelationship": "DOWN_THE_ROAD",
#             "straightLineDistanceMeters": 77.96733,
#             "travelDistanceMeters": 71.19292
#           },
#           {
#             "name": "places/ChIJfxhFC8XUf0cR0Xo9dUoTA6s",
#             "placeId": "ChIJfxhFC8XUf0cR0Xo9dUoTA6s",
#             "displayName": {
#               "text": "Serre dei Giardini Margherita",
#               "languageCode": "en"
#             },
#             "types": [
#               "bar",
#               "establishment",
#               "food",
#               "point_of_interest",
#               "restaurant",
#               "school"
#             ],
#             "straightLineDistanceMeters": 216.12418,
#             "travelDistanceMeters": 231.01735
#           },
#           {
#             "name": "places/ChIJPf2OzsXUf0cRhB7p5uqjLII",
#             "placeId": "ChIJPf2OzsXUf0cRhB7p5uqjLII",
#             "displayName": {
#               "text": "B&B Al Parco Giardini Margherita Sconti Rizzoli e Villa Regina",
#               "languageCode": "en"
#             },
#             "types": [
#               "establishment",
#               "lodging",
#               "point_of_interest"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 22.453997,
#             "travelDistanceMeters": 20.678474
#           }
#         ],
#         "areas": [
#           {
#             "name": "places/ChIJLwKOhMXUf0cRSwyJnq_IU64",
#             "placeId": "ChIJLwKOhMXUf0cRSwyJnq_IU64",
#             "displayName": {
#               "text": "Giardini Margherita",
#               "languageCode": "en"
#             },
#             "containment": "NEAR"
#           },
#           {
#             "name": "places/ChIJn_75kpXUf0cRlcgftj_FyYI",
#             "placeId": "ChIJn_75kpXUf0cRlcgftj_FyYI",
#             "displayName": {
#               "text": "Old Town",
#               "languageCode": "en"
#             },
#             "containment": "OUTSKIRTS"
#           }
#         ]
#       },
#       "googleMapsLinks": {
#         "directionsUri": "https://www.google.com/maps/dir//''/data=!4m7!4m6!1m1!4e2!1m2!1m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!3e0?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "placeUri": "https://maps.google.com/?cid=3277797724925377160&g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "writeAReviewUri": "https://www.google.com/maps/place//data=!4m3!3m2!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!12e1?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "reviewsUri": "https://www.google.com/maps/place//data=!4m4!3m3!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!9m1!1b1?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "photosUri": "https://www.google.com/maps/place//data=!4m3!3m2!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!10e5?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA"
#       },
#       "timeZone": {
#         "id": "Europe/Rome"
#       },
#       "postalAddress": {
#         "regionCode": "IT",
#         "languageCode": "en-US",
#         "postalCode": "40136",
#         "administrativeArea": "Metropolitan City of Bologna",
#         "locality": "Bologna",
#         "addressLines": [
#           "Viale Giovanni Gozzadini"
#         ]
#       }
#     }
#   ],
#   "contextualContents": [
#     {
#       "photos": [
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU76_YdOjxEomMoAylTB7zh2lXhiLCBycCagM4GT1fvR6SaxH7MwMJws17PT1e_bFWKOibO4ej5lptQkAdIdufGcc6b8apRJuj8dOrSf_tR9GA3bfAoiuuERY-5jt6mbWLZ5M-N0sVuW2vUpwAdqhkzWthnJj1HqVODGVtNUIpneFgb5Pn3M7-CLQEd0zvHi_M2oErdp-FQoMhs86oOMdQCClyFbA0Yh9RCLu6Oo1xV-g-g6SRrDZqdCZ1OlJYUGUJMDZAYpGVnWutAlMHj1AXJjOdJXjbe7nFwZkyjUopkbIyPZLG4RvemP5vXkhOpKxe01to1y3JiPPMupoQffyivhp2DR1d_MblN9gGlr4MEmpMveyYYmEb5eSrUTDaQgNGrcMrF0Kl0GxkH3-KTy",
#           "widthPx": 4160,
#           "heightPx": 3120,
#           "authorAttributions": [
#             {
#               "displayName": "Stefano Dalzini",
#               "uri": "https://maps.google.com/maps/contrib/112388244312001538595",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjUNJHfLWK30qZ-kX3edFNT3j57FzK1BI5JWrwoHlAcZVtDPvzFO3g=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places&image_key=!1e10!2sCIHM0ogKEICAgIDUl5neCw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDUl5neCw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5TPA5LIwxOQjN-3t1VT4YFw_mEmsY-bXvaRcjDyYz_PY0HAJ3JE58HYc4DxgxD0lQSJvO5PfDyM8swd5YUe-_9lUpOLYOmDwlXeVCua0pErfjx2_yFKb7gdNOomdtrHIkOfcGUOEY8FRTtxfvypkS_jCA6GBDxSnpr7Y4Nz8L3RfgqVV2MMus-m9ZycrsWktREfcXHGkm1ProYy3JlXO7D6eR0tycTB8yNtyairBlvVNeHLYNS-mGoYbsK1C5kL33GM8rTq8B10TwYVcYqLD4OmkhOiEKAVA6p66Di9-SqtTjq0JHNmTekXftcylkxU7akttthHhjcig4wiGfQse6QdgIo6ejjX2hvzjl5nHNeZiT5k1SAYNLp38-sxbZVxHzTUWjna0gL5PtJEfZy",
#           "widthPx": 4032,
#           "heightPx": 3024,
#           "authorAttributions": [
#             {
#               "displayName": "Roberto Vanzetta",
#               "uri": "https://maps.google.com/maps/contrib/101286674699245687282",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjUKFn3PKwY9OpTsp6giY82MnPHhsyq4lTc7l5x3PpXUqJ0kzHiK=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places&image_key=!1e10!2sCIHM0ogKEICAgIC-7JSFdw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIC-7JSFdw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5zhBo7J_i53yTEHEzrfBNAwKoNFnJp436Amkfuq1MRk1f8nC7-NsleCVbxbKPLHdOiL1libB-QoO7a9I3TxVW2Q6plHTUHKL8Zi5GHMWT-cpx2oz8cECwTneBBzkGDsC9slAZ7E1p2IeDpxsZSyOL3KqwFjKk7P57iJcm00HAKxeSOyQg6pVv0RC8AFnT4gnbPypG2buUEXoHdAqzAVVHi2zkmYfFf-k2Uf5QBE9GtFuEfgQkgNxWyeVwJ3aGIRt0XvLfqP3HnMWormF0PEJaWxd7Dj29Mwp0HauwqyAUgA89tbdLxUw6EbiPzI-pNwqTi1ZgUXDmWuC5nVAKng-PKBTPI2VsOX-Ze1B0aSczmxvqtBfgzOtWui6RyPpXaqu68RaX9dvrkD2p57Zw0g_Sv",
#           "widthPx": 3236,
#           "heightPx": 2427,
#           "authorAttributions": [
#             {
#               "displayName": "Federica Fini Zarri",
#               "uri": "https://maps.google.com/maps/contrib/117213070053376513693",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWie0JhCewkNri-_3dAuWp0X61bcAgtk0xw66mKLhUaWGVzTj-NMw=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places&image_key=!1e10!2sCIHM0ogKEICAgID4u8Gk_gE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgID4u8Gk_gE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU4FuSLt3ZmdbK5ADKeDeB1DFjpzYoZRgAfXGQV3j402nVtwLld8_HWO9Pykpvy0FLJhTDLDO--cUD1bfAscw8idlE2j2MN2az19VkfLD_12yc5qaw57B0WCNGRQaTOvfpfxTXBJOLVEYboiiqkalKw3_2fO94qxitvoq1aMYxSejUXVbBKFvJW9IeFzBvgi-D16rEsM0Gr0ApULhfYfjFYidv0izP-84BtOcJ31GECStbYHzLl6LYZ5tbrDegq4kXFa-uPU-r7NAE3kL2_xQOfD0yJGAGGIS7uzNg045oYayXFk-Wh1w1Ubv6ohPB-0HeJ3uFxljrV8W4JmMl3c3GyOiJAxhJDA5FMawAP3sG8X67MAfyJXX4N2ApV7HN8Ws2fXL0V_bG-1Qp7jKm01",
#           "widthPx": 4608,
#           "heightPx": 3456,
#           "authorAttributions": [
#             {
#               "displayName": "Alex Bularu",
#               "uri": "https://maps.google.com/maps/contrib/100126913413494614382",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjW4iMaG_gfjxhJQrnpYltMzrDzBm6zCfJriVdgyxg32aK_eb8zf8A=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places&image_key=!1e10!2sCIHM0ogKEICAgICkmuLURQ&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICkmuLURQ!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU7_6p9WE63Nj5BayV8qukpVElO5Y71OeorJv0MtbvUVtyiopQa4NLQZI77l3GaVHudvgXeLpPd60lH5uiQ917MtQLH6V98l84q16quDdh3Z1UU3lol4DRnj31sQFySPpVHZn3slMSl0BZC7urhZG4XOzr0K0n2U0bDqhyq94zUUt4xIfK_dA1nKz_rmiMXaV5JvJO48yi1GhjpH2JsRHZBfXfklNu7y1AzWn7PHcASc1_JIXKbr68C9fgbWCawX5Hzlk675QrmBbkEroL9iA5W-SHEUe-Yyib4PRU8f_W7dUfLruufL-N6uFQieYM6OcFLurWM5D10p1H39reJ_-la2LWRzdcYjBiuIuAMrBrvcsMf4eTS3Rg11A3YGi0yc-bsZ217m-udN828f_olWHW8w",
#           "widthPx": 3008,
#           "heightPx": 3008,
#           "authorAttributions": [
#             {
#               "displayName": "Paolo Mazzoni",
#               "uri": "https://maps.google.com/maps/contrib/114421506459150145050",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocLzBQO0Hxd_Ge4RMufMLgNrZzN9hyr_FwXd0XSHhNXxvPSCrA=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places&image_key=!1e10!2sCIHM0ogKEICAgICqnMvxpAE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICqnMvxpAE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         }
#       ],
#       "justifications": [
#         {}
#       ]
#     }
#   ],
#   "searchUri": "https://www.google.com/maps/search/Giardini+Margherita"
# }

# %% [markdown]
# Return only needed fields: for example location, which contains lat & lon

# %%
import os
import requests
import json

# Example request to Places API - Text Search restricted to Bologna
query = "Giardini Margherita"
url = "https://places.googleapis.com/v1/places:searchText"

headers = {
    "Content-Type": "application/json",
    "X-Goog-Api-Key": API_KEY_GMP,
    'X-Goog-FieldMask' : 'places'   # many fields available, use '*' to get all
}

#useful: location contains lat and lon

# Bologna coordinates
bologna_lat = 44.4949
bologna_lng = 11.3426
radius_meters = 5000  # 5km radius

payload = {
    "textQuery": query,
    "locationBias": {
        "circle": {
            "center": {
                "latitude": bologna_lat,
                "longitude": bologna_lng
            },
            "radius": radius_meters
        }
    },
    "maxResultCount": 5  # Limit to 5 results
}

response = requests.post(url, headers=headers, json=payload)
data = response.json()

print("Status Code:", response.status_code)
print(f"\nSearching for '{query}' in Bologna (radius: {radius_meters}m)")
print(f"\nNumber of results: {len(data.get('places', []))}")
print("\nResponse:")
print(json.dumps(data, indent=2))
print("="*60)
print(data.get('places', [])[0].get('location', {}))
# Out:
# Status Code: 200
#
# Searching for 'Giardini Margherita' in Bologna (radius: 5000m)
#
# Number of results: 1
#
# Response:
# {
#   "places": [
#     {
#       "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0",
#       "id": "ChIJLwKOhMXUf0cRiLrCD6oTfS0",
#       "types": [
#         "hiking_area",
#         "tourist_attraction",
#         "sports_activity_location",
#         "park",
#         "point_of_interest",
#         "establishment"
#       ],
#       "nationalPhoneNumber": "051 203040",
#       "internationalPhoneNumber": "+39 051 203040",
#       "formattedAddress": "Viale Giovanni Gozzadini, 40136 Bologna BO, Italy",
#       "addressComponents": [
#         {
#           "longText": "Viale Giovanni Gozzadini",
#           "shortText": "Viale Giovanni Gozzadini",
#           "types": [
#             "route"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Bologna",
#           "shortText": "Bologna",
#           "types": [
#             "locality",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Bologna",
#           "shortText": "Bologna",
#           "types": [
#             "administrative_area_level_3",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Citt\u00e0 Metropolitana di Bologna",
#           "shortText": "BO",
#           "types": [
#             "administrative_area_level_2",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Emilia-Romagna",
#           "shortText": "Emilia-Romagna",
#           "types": [
#             "administrative_area_level_1",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Italy",
#           "shortText": "IT",
#           "types": [
#             "country",
#             "political"
#           ],
#           "languageCode": "en"
#         },
#         {
#           "longText": "40136",
#           "shortText": "40136",
#           "types": [
#             "postal_code"
#           ],
#           "languageCode": "en-US"
#         }
#       ],
#       "plusCode": {
#         "globalCode": "8FPHF9M2+3X",
#         "compoundCode": "F9M2+3X Bologna, Metropolitan City of Bologna, Italy"
#       },
#       "location": {
#         "latitude": 44.4827156,
#         "longitude": 11.3524117
#       },
#       "viewport": {
#         "low": {
#           "latitude": 44.48259271970851,
#           "longitude": 11.348590399999999
#         },
#         "high": {
#           "latitude": 44.4852906802915,
#           "longitude": 11.352411700000001
#         }
#       },
#       "rating": 4.6,
#       "googleMapsUri": "https://maps.google.com/?cid=3277797724925377160&g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#       "websiteUri": "http://www.comune.bologna.it/",
#       "regularOpeningHours": {
#         "openNow": true,
#         "periods": [
#           {
#             "open": {
#               "day": 0,
#               "hour": 0,
#               "minute": 0
#             }
#           }
#         ],
#         "weekdayDescriptions": [
#           "Monday: Open 24 hours",
#           "Tuesday: Open 24 hours",
#           "Wednesday: Open 24 hours",
#           "Thursday: Open 24 hours",
#           "Friday: Open 24 hours",
#           "Saturday: Open 24 hours",
#           "Sunday: Open 24 hours"
#         ]
#       },
#       "utcOffsetMinutes": 60,
#       "adrFormatAddress": "<span class=\"street-address\">Viale Giovanni Gozzadini</span>, <span class=\"postal-code\">40136</span> <span class=\"locality\">Bologna</span> <span class=\"region\">BO</span>, <span class=\"country-name\">Italy</span>",
#       "businessStatus": "OPERATIONAL",
#       "userRatingCount": 17288,
#       "iconMaskBaseUri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/tree_pinlet",
#       "iconBackgroundColor": "#4DB546",
#       "displayName": {
#         "text": "Giardini Margherita",
#         "languageCode": "en"
#       },
#       "primaryTypeDisplayName": {
#         "text": "Park",
#         "languageCode": "en-US"
#       },
#       "currentOpeningHours": {
#         "openNow": true,
#         "periods": [
#           {
#             "open": {
#               "day": 2,
#               "hour": 0,
#               "minute": 0,
#               "truncated": true,
#               "date": {
#                 "year": 2025,
#                 "month": 10,
#                 "day": 28
#               }
#             },
#             "close": {
#               "day": 1,
#               "hour": 23,
#               "minute": 59,
#               "truncated": true,
#               "date": {
#                 "year": 2025,
#                 "month": 11,
#                 "day": 3
#               }
#             }
#           }
#         ],
#         "weekdayDescriptions": [
#           "Monday: Open 24 hours",
#           "Tuesday: Open 24 hours",
#           "Wednesday: Open 24 hours",
#           "Thursday: Open 24 hours",
#           "Friday: Open 24 hours",
#           "Saturday: Open 24 hours",
#           "Sunday: Open 24 hours"
#         ]
#       },
#       "primaryType": "park",
#       "shortFormattedAddress": "Viale Giovanni Gozzadini, Bologna",
#       "editorialSummary": {
#         "text": "Popular public park with lots of trees, a lake & lawns, plus a jogging path & play areas for kids.",
#         "languageCode": "en"
#       },
#       "reviews": [
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/ChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE",
#           "relativePublishTimeDescription": "5 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Free of charge, easy access, designated areas for many choices from play grounds for kids to badminton for adults. Biking is allowed, too.\nGrab your picnic basket and spend the day here.\nOr bring your book and enjoy the resreshments/pastey at the caffea inside the park.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Free of charge, easy access, designated areas for many choices from play grounds for kids to badminton for adults. Biking is allowed, too.\nGrab your picnic basket and spend the day here.\nOr bring your book and enjoy the resreshments/pastey at the caffea inside the park.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Zuhal",
#             "uri": "https://www.google.com/maps/contrib/117843459985379991032/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWSs1QQ9P4X5_D0vCwFwIInIqTUffw7UZOM_BhqGnjSqTy3Dnpn=s128-c0x00000000-cc-rp-mo-ba4"
#           },
#           "publishTime": "2025-05-03T10:30:48.565848Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB",
#           "relativePublishTimeDescription": "3 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Giardini Margherita is Bologna\u2019s most beloved park\u2014a peaceful, green escape perfect for relaxing, walking, or picnicking. With tree-lined paths, a small lake, caf\u00e9s, and play areas, it\u2019s popular with locals and visitors alike. Ideal for a break from the city\u2019s bustle, especially on sunny days. Great for solo travelers, families, or anyone wanting a breath of fresh air in a beautiful setting.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Giardini Margherita is Bologna\u2019s most beloved park\u2014a peaceful, green escape perfect for relaxing, walking, or picnicking. With tree-lined paths, a small lake, caf\u00e9s, and play areas, it\u2019s popular with locals and visitors alike. Ideal for a break from the city\u2019s bustle, especially on sunny days. Great for solo travelers, families, or anyone wanting a breath of fresh air in a beautiful setting.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Dani Baal",
#             "uri": "https://www.google.com/maps/contrib/103357020897930875043/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXd5F4_0jTgLXfmVTKm-2qvHv52-mDsO2tP9IWzdgV09PasJeSo=s128-c0x00000000-cc-rp-mo-ba7"
#           },
#           "publishTime": "2025-07-28T12:37:34.868920783Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/ChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB",
#           "relativePublishTimeDescription": "7 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Beautiful green space easily accessible from the center of Bologna.  Some playgrounds, remote working space, walkways great for kids to ride bicycles on and some playgrounds. There are a few cafe\u2019s and bars as well and a very small go kart course with electric go karts and pedal karts.  It\u2019s a gem in this city and a must visit on a nice day.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Beautiful green space easily accessible from the center of Bologna.  Some playgrounds, remote working space, walkways great for kids to ride bicycles on and some playgrounds. There are a few cafe\u2019s and bars as well and a very small go kart course with electric go karts and pedal karts.  It\u2019s a gem in this city and a must visit on a nice day.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Aldo Pinotti",
#             "uri": "https://www.google.com/maps/contrib/101428219914666686008/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVcPEKbbFMj1FaxARFYvyiVYEGsWZBBiDVb8Ub98FPERNqYWwgEyw=s128-c0x00000000-cc-rp-mo-ba3"
#           },
#           "publishTime": "2025-03-24T15:48:07.497659Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB",
#           "relativePublishTimeDescription": "2 weeks ago",
#           "rating": 5,
#           "text": {
#             "text": "Very nice park with a lovely picnic / bar area at the back, near the botanical area.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Very nice park with a lovely picnic / bar area at the back, near the botanical area.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Holly Pope",
#             "uri": "https://www.google.com/maps/contrib/111127058743800932797/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWZOw83XmvpAxB6atDufAr8WzVQ0NMaWaPUrxUti9wkeVncdQK1=s128-c0x00000000-cc-rp-mo-ba3"
#           },
#           "publishTime": "2025-10-11T12:52:40.557526010Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB",
#           "relativePublishTimeDescription": "a week ago",
#           "rating": 5,
#           "text": {
#             "text": "One of the city's many green spaces. Beautiful and quiet!",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "One of the city's many green spaces. Beautiful and quiet!",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Desart Ajazi",
#             "uri": "https://www.google.com/maps/contrib/116110492896188753454/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVz6_AmSIYggCVaxgOqjgePmbiRDdj3I_c0wYfPXmsqsHGbcUe0Cw=s128-c0x00000000-cc-rp-mo-ba2"
#           },
#           "publishTime": "2025-10-16T21:03:11.109817558Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         }
#       ],
#       "photos": [
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU4441A4hVwMRLPNBOOfyYAGW9dnzmdriSR2m7-d8-UORpxoGDyqL2RsRZKvE7521wjNQqQtUxiIcTW2Zg9tPucPt-6Sc2orgl34HJ_fUoaBxsmx2pXijOW-1PYzZ5lrIqebP4ZhQ4tiNFDBJzdn7qIyXEHvyejdEu4ObwVDw5_PKIcFZ0coiS1eqcPvledAenCDxJqJCPnGXhbwFGxhK8FMyUiL5VX_FZ-eZ3y9RtxSdYIXQvSbVpU175G4IMyFHuU5esjJ5lMC6WV6EDpPUWwpR43Fa_ZK5LJY7b9LJyuS91vgEfnsF41sT7BUB3h4IedxcIoymwHRMSl1mwTxmzFwe1z0-yrl4Ude9kW130ZCuEWk06af2ogBG2soqeYMzwDIlgHDvyZCVirgbZ3c1R7nVthYfO4VHcl8OAbjcQQpjsbj",
#           "widthPx": 3024,
#           "heightPx": 4032,
#           "authorAttributions": [
#             {
#               "displayName": "Phanendra das",
#               "uri": "https://maps.google.com/maps/contrib/116022813752209071834",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVunoPhApjuMp4Jzb0pegqb8AXkpXP-YalBn3EIe8u5aRFM022k=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgID7-vrO1QE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgID7-vrO1QE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU4MtEmZ7XTuinKcQXG3ZAAedT_tcIZR0EjkmNnrUjwI8U0JKUYGTMvNOwW1IwFJ0NYLiy4QCOdyRyjjk49m7ekSDI8BZGz9c0aV8-7xeZOMrSysHi_rGsSwQypdMsh9L_cTCJ1uSkQPXEsQ_NJiIYwhH7V0pjL7UfQrEjqHoW8yfFXm-qqToKBpNYBPIuxU_lkYUqMTEBI_asMTxEvu6xCC22T0yAuc_hzjXMd14qT4-EuTls3kKBPdneSEIvCV2GK248-BOiKmCD1O65hXHgHVis9xkE_XyOqhmJp0Ml70mvNYPYuR6lHlshaFsrv08eNW40uEDedHyabhHd1ddlD70zKSVuOdO_HqyjOSieUGmhmMjUNGMhxGFG_Qz8v0agwbRlRJZOM10KUcts1do0mAOP_Ugf46_Sk-XDOeo0zvuUIA",
#           "widthPx": 3600,
#           "heightPx": 4800,
#           "authorAttributions": [
#             {
#               "displayName": "Giorgio Fanigliulo",
#               "uri": "https://maps.google.com/maps/contrib/117481865498945288789",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocLkuf7-zukIxOywXFuHoa37kpEoKqtO38yaq0Zt1SF0SVWekA=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgID63fLgjwE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgID63fLgjwE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU75zZQPfLNx816kPeoj_XFLnqv4PWrcaEKmkBt9Ez1Hv57OpIGXNidHKRnB4R9stN6lwBGcjWSLUNRXGXkKZeMrNc1FSx-o9vjYR4AlySrJRaFMf4WiHXybFxesxkS-IJMiNROoYrn39LqnUyiJPe4Biemml65haRBkPu9jtuRZR3qVk6nwGr4g-kw_AwLOXhPWT2jU7uhRGUPgGEvGQY9yEC94yA0M34fCXZy-Ct3VwcsLttsjmUh6uSpXCpN_1kufymkb_nrJnjHTdDfq-L73Ccr7rQVKmsp1jixXsw9qX4sOXfkoWudbAJ9NT0wFBmuYWfbmnq2hcUR62199livpbeWAdVE2OchZ3A0kKFE1jPLnd1Yb0pkHCUQA0m46eax1R5phoqUZCKUT0d1Z5WPcpa-sOWx_m8XyOstCFojF4Q",
#           "widthPx": 3456,
#           "heightPx": 4608,
#           "authorAttributions": [
#             {
#               "displayName": "Giorgio Scarabelli",
#               "uri": "https://maps.google.com/maps/contrib/117147474204335919716",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVOKqJAVuxnwSYNOyRbCRTPzAgexBsZCf0oCkbNhdlYgABi9eG7=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEJyj89nwnPORCw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEJyj89nwnPORCw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5Z7_LBMWtsBtQS0Ovcwghx3bRbnR4N7hNUq2VXk49ST8A96Ucy5Dc3sGR-mIbVv8zzT59_16ecoyM7Pu8kGJ_DISKXvyi5L-647jK7NAtUpMndV7Xb35Ebc6A3AV6JP6x75svFV7deaG-Xkg3ETQF5TErbPmXh85MZYYwfRdMV_94VUdEhA_j3gphsu5x48Nc-dBSs9nYznjs_E8BQMpp3W0JO6KdN1uy-xkEReNoKC_JwRa4ctzPFsVF1eNPvWPoD4hmZKw7RDZO_PCt-P6NfpZoTqQLP-zrjMAL-rAik6xLeSXo_PqWOayAe4-niSXPDzmgSx5fGb9SydscxOKwVewVtr_v-vNGopf9ttXj4ShBrkLPUKBiE1seU_IsnHfFbo77o4n3RpznGTXUI2wC72TAQAIXvSHH-P8XzRcJ1AZeA",
#           "widthPx": 4032,
#           "heightPx": 3024,
#           "authorAttributions": [
#             {
#               "displayName": "Diana B",
#               "uri": "https://maps.google.com/maps/contrib/114064809743683456601",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVfheGMKzOKVjl0o1d2cjMqF-PTjdtooKQHpOJBhdXO4ln1cdYj=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICO3ZndwQE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICO3ZndwQE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU6pA0JFpO57xbGRmvTooYEDZLJhRqM1CfbeLRmKTPFgaPe9tXmdF63DC7NgmYFsrKP8egshz_83I29TUTjHbXqcJOotRj-Pw9AppK91d1KTYDtihBPOWJuQhon217nwnNoFV2jlDAHBLw3dP80NfbQ3CR6Jy5WQR1UjXW_0pKKbobEsfO27Jh3riuINoNhcgUHre1OIHwxbt7Rxv_1bu1XreBksdZF9ibnyDQHASM5-4qG97dkS_VudjGhAZwzXsBzrqyxuvK1PkE5XuHqiLBVDMIoL1pb_FoDZOsEWHeXdH5_yU7WNEqgaaZ2TIDkARw5jlUbpwF_cwUPFI1q4WmMh0mn6FbKuMFMa4-wFow1vhiBHg1CRw5VgtCkwVI4fLsFYSeISEtKSw_aG6HQJpXare9veRQ7OfuclqouaMcgvKg",
#           "widthPx": 3000,
#           "heightPx": 4000,
#           "authorAttributions": [
#             {
#               "displayName": "Stefano Merighi",
#               "uri": "https://maps.google.com/maps/contrib/100902344886524646680",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVlok2JP0fUlKE37CfPP2q8qmjNDFhzV7i4-QQANRrvEK3BTZlYiA=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICmv_uRAQ&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICmv_uRAQ!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU47ccDpu9FhM-Ln5G3yHVeUwcj-IXQ2ojLj9RjYsb5R8zJ1Ui5jgZomccmi4h7B_NxDKaG27zQAdzas6GhHsG9KvrNLaj3AFSVpBtDqRMtre-DHuGbngBZg2bQeEYjMARSZcMdg5lRA3fciV_ZIW0U0LBYS9qQNQ4jibwHIh77E9HbqDmMXJptDannJLKhAoVGrvemLzlv1mRA9EAv9KI2eNdbftgI3m3SldEUWQqYqFtP6rVumcUO7pRTQk0PT0Und6sJUdNfhLEoiMgLo24861VZ9FCm2nKf_nBwEFkA49LtcMcy1GbKJQmwfNz-Xj8mlHs75PrVBhXTlLtWcWnRp8O7fqIalwjYAQc63ESbVD5w4nbkVXqhuZ_ZmweM3wih03qgUKuIbuK-Oz5_xZm7W77xDklR_k-4UpMFBd2Y",
#           "widthPx": 2272,
#           "heightPx": 1836,
#           "authorAttributions": [
#             {
#               "displayName": "Marco Mongitore",
#               "uri": "https://maps.google.com/maps/contrib/117247794346755004430",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocIenO4PrC7jbH9298glrWmPQRGsPnI2BnA0H3nAssp0ujjqlkfV=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDcj-22Hw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDcj-22Hw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5ql17Famz2H5uQsGuSmYZCaA9t_5qTmNIz-X1M2yQUVbJOVf4u7mLpTHtCgrWZ7SDaypsiCc8XPmfjyM6BaOgJF1rB8K9MwMyfYKw-OPIbeu18HlaAg0VAMgwEpKOUpwvRHIrYBpscH3cBD-zVHM0MfFWFvi59oo8loJCryGcvpPuTPZIxQ8n4Dnt-FvGgPue_MJQYZTWLyO3gf-30BintvQpNydnuoPQlrR7liaDumi4dTLpO8WoRk7Nl4nZxzxCv4Y-cEd9MBoLjQSU3_biZzOfBOK1N46t-RziX-r4emPU7WxuxEqMbVnyrW7KXs_rXmzp92UrzQguEvbrPvJ8D1IKl-zxgRgPdLbmpd4XmzEit3Db1C_hihqsAJ4TZgCudvMKKAfhMfzH7lXy7HrDh9Sdt9FHGDHGSgV4PXi2GKTPk",
#           "widthPx": 4000,
#           "heightPx": 3000,
#           "authorAttributions": [
#             {
#               "displayName": "Cristina",
#               "uri": "https://maps.google.com/maps/contrib/109109969557698215870",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocI0_XUNiyglPjHsgBgMQk5FYUxrzN_OnKCNTNvXG_p0nEXYKQ=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICKgfiM9AE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICKgfiM9AE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU4uodiP0kJKJybyXkXfXFRBi26G03YDtiKHnz_kad3lM8gluxuev-oJuoJyULkxp1qjL4C3zUjD2Lti8kOLIMMJGnlfyHHIu2kKt_AOgEfvjMLpSoRqya2KWtIeRwfgzSv55ovU0oDCemFG_ijybg5wNiEH2-StEQVvXs-iwuzUaL0wyEb-YyT17nNLU_YDxXvlAkqmxY9jLRP-4HWGBBzJ2RGS7a9Gz10SCaTf3QRfefifFkoRffa4DrasL1_kU4dM6hO3mWl9__l_qDHBU_CVloju4mVB-hmCySwdWJPeEF0ylYXeTA1ZdK79I5rpYdeq-JF_2aJsfcYxLj3CNxFsTizndvm-Qp9zHjbCXVYlIGHOqsmzt-bv2wQUbfAtTSvIPd1ESq3s9_GfEXptokYrnyWAnao8p3PHjMHHsFU",
#           "widthPx": 3968,
#           "heightPx": 2976,
#           "authorAttributions": [
#             {
#               "displayName": "massimo forni",
#               "uri": "https://maps.google.com/maps/contrib/104350402342410590076",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWoJQaKQ7ujCnhtx6izg3Z-on_EccHRbc5hGnDni2IY3i9Y62h6=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDqvr-_Vg&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDqvr-_Vg!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU7ME6I4jWmKHyUY5ESmYIav5J0xFXgbAQpy4lUuZ9Rdn5zFeNI2g-uZPT71Eu-eov1gYliQgE-0kaL6K_vuD5k_EoL88ppnPCk_6cEK87jPBKn--1sV9UfizdmPfekltYnCgNhyQHxckNLZrEwoxRbd94m-WH6-WGpBjeoQvFwS4NFu-xo3qdcOM8sWzHxz8hdwKELXMKhFoN5TFIjpxmQi4mHuKMGlynsHXYtrAn1-7nKBGAnBIzexB0utJ1nOGTp-Bdw9vUabLC23GtlfikmoGSYpLFxgniiRO8k1AJB8YGwJE5M_I_ztSUDk6uR_xQnLB6G9AA7laCT-BVrk4-gu1HClxpTtoRfl9ZQCxZJW0HaQjkmoc8JoGAfXMfgFKtz4NueemoER7ttO7s3-_9sNfk5-48vCE0NdhD5rPQrJmz7t",
#           "widthPx": 3648,
#           "heightPx": 2736,
#           "authorAttributions": [
#             {
#               "displayName": "Marco Monti",
#               "uri": "https://maps.google.com/maps/contrib/117527048640464687964",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXaUVUApnk1gR10KDu36WgSAQvFub2qap2N4LSukdcu1eDRoZw3=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIC2joXNuQE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIC2joXNuQE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU6s9PR8Ow6xNcrRiIxOUpzNoqdIU6LDnCe4y4XPVYjTfqR_7c9mcYz6eqo_3aPnF8YIOxPoC0os1Q3qd1FjnKIeYQg_PldhGJ--EoovehaioEmgWNmVuS7tzwECWj2JOfWzKgpFXH1Qp1xOUdlVn2l18bMKKc7ICgBwgXUXOh6beRKXL-GyKDQMla9CSPP-D51U9vW3E-Tb5OviE59xSjuCqfxRfpLwZyKUKqx_ty6se__Rw84HRVhyb4aXxoV9IO2GKPxNzSG1DKC62K1qkYnpEj3yHDgL3kUKui_IHIe9NN1eUsVWa7S35rp09pSoBRtnDMVc2vjj0LHuKTntH2X_tsn0mB9yS4WvO841GtXYbUgbEv7ovUSHZgTYhZdfkF2EyZ8-qfvnY6pbh3ZWM7btRHG6A7Nn40HaArdIik2v6A",
#           "widthPx": 4608,
#           "heightPx": 3456,
#           "authorAttributions": [
#             {
#               "displayName": "Mars Gofabeatz",
#               "uri": "https://maps.google.com/maps/contrib/116262144135072295136",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXBp-dEsKqjaOUNJt7wR525pL5f-3GZ0SrNNr86qEY0vSTgs1B-Vw=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDRlK7CNA&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDRlK7CNA!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         }
#       ],
#       "goodForChildren": true,
#       "allowsDogs": true,
#       "paymentOptions": {
#         "acceptsCreditCards": true,
#         "acceptsDebitCards": true,
#         "acceptsCashOnly": false
#       },
#       "accessibilityOptions": {
#         "wheelchairAccessibleParking": true,
#         "wheelchairAccessibleEntrance": true
#       },
#       "addressDescriptor": {
#         "landmarks": [
#           {
#             "name": "places/ChIJ8-EjLcTUf0cRHy_epY_lpPI",
#             "placeId": "ChIJ8-EjLcTUf0cRHy_epY_lpPI",
#             "displayName": {
#               "text": "Carrefour Express Porta Castiglione Store",
#               "languageCode": "en"
#             },
#             "types": [
#               "establishment",
#               "food",
#               "grocery_or_supermarket",
#               "health",
#               "point_of_interest",
#               "store",
#               "supermarket"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 31.259172,
#             "travelDistanceMeters": 32.876442
#           },
#           {
#             "name": "places/ChIJ396r0sXUf0cRtx-IP709mG8",
#             "placeId": "ChIJ396r0sXUf0cRtx-IP709mG8",
#             "displayName": {
#               "text": "Farmacia Dr. Max",
#               "languageCode": "it"
#             },
#             "types": [
#               "establishment",
#               "health",
#               "pharmacy",
#               "point_of_interest",
#               "store"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 29.39594,
#             "travelDistanceMeters": 15.978893
#           },
#           {
#             "name": "places/ChIJQ8QHycXUf0cRdnAeMobf1SM",
#             "placeId": "ChIJQ8QHycXUf0cRdnAeMobf1SM",
#             "displayName": {
#               "text": "Chiesa di Santa Maria della Misericordia",
#               "languageCode": "en"
#             },
#             "types": [
#               "church",
#               "establishment",
#               "place_of_worship",
#               "point_of_interest"
#             ],
#             "spatialRelationship": "DOWN_THE_ROAD",
#             "straightLineDistanceMeters": 77.96733,
#             "travelDistanceMeters": 71.19292
#           },
#           {
#             "name": "places/ChIJfxhFC8XUf0cR0Xo9dUoTA6s",
#             "placeId": "ChIJfxhFC8XUf0cR0Xo9dUoTA6s",
#             "displayName": {
#               "text": "Serre dei Giardini Margherita",
#               "languageCode": "en"
#             },
#             "types": [
#               "bar",
#               "establishment",
#               "food",
#               "point_of_interest",
#               "restaurant",
#               "school"
#             ],
#             "straightLineDistanceMeters": 216.12418,
#             "travelDistanceMeters": 231.01735
#           },
#           {
#             "name": "places/ChIJPf2OzsXUf0cRhB7p5uqjLII",
#             "placeId": "ChIJPf2OzsXUf0cRhB7p5uqjLII",
#             "displayName": {
#               "text": "B&B Al Parco Giardini Margherita Sconti Rizzoli e Villa Regina",
#               "languageCode": "en"
#             },
#             "types": [
#               "establishment",
#               "lodging",
#               "point_of_interest"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 22.453997,
#             "travelDistanceMeters": 20.678474
#           }
#         ],
#         "areas": [
#           {
#             "name": "places/ChIJLwKOhMXUf0cRSwyJnq_IU64",
#             "placeId": "ChIJLwKOhMXUf0cRSwyJnq_IU64",
#             "displayName": {
#               "text": "Giardini Margherita",
#               "languageCode": "en"
#             },
#             "containment": "NEAR"
#           },
#           {
#             "name": "places/ChIJn_75kpXUf0cRlcgftj_FyYI",
#             "placeId": "ChIJn_75kpXUf0cRlcgftj_FyYI",
#             "displayName": {
#               "text": "Old Town",
#               "languageCode": "en"
#             },
#             "containment": "OUTSKIRTS"
#           }
#         ]
#       },
#       "googleMapsLinks": {
#         "directionsUri": "https://www.google.com/maps/dir//''/data=!4m7!4m6!1m1!4e2!1m2!1m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!3e0?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "placeUri": "https://maps.google.com/?cid=3277797724925377160&g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "writeAReviewUri": "https://www.google.com/maps/place//data=!4m3!3m2!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!12e1?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "reviewsUri": "https://www.google.com/maps/place//data=!4m4!3m3!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!9m1!1b1?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "photosUri": "https://www.google.com/maps/place//data=!4m3!3m2!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!10e5?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA"
#       },
#       "timeZone": {
#         "id": "Europe/Rome"
#       },
#       "postalAddress": {
#         "regionCode": "IT",
#         "languageCode": "en-US",
#         "postalCode": "40136",
#         "administrativeArea": "Metropolitan City of Bologna",
#         "locality": "Bologna",
#         "addressLines": [
#           "Viale Giovanni Gozzadini"
#         ]
#       }
#     }
#   ]
# }
# ============================================================
# {'latitude': 44.4827156, 'longitude': 11.3524117}

# %%
import os
import requests

# Street View Static API URL
url = "https://maps.googleapis.com/maps/api/streetview"

# Use Piazza Maggiore coordinates (city center - has Street View coverage)
lat = 44.4949
lng = 11.3426

params = {
    "location": f"{lat},{lng}",  # Required: lat,lng coordinates
    "size": "640x640",            # Required: image size (max 640x640)
    "heading": 0,                 # Optional: camera direction in degrees (0-360)
    "pitch": 0,                   # Optional: vertical angle (-90 to 90, 0 = level)
    "fov": 90,                    # Optional: zoom level (10-120, higher = zoomed in)
    "key": API_KEY_GMP
}

response = requests.get(url, params=params)

print("Status Code:", response.status_code)
if response.status_code == 200:
    # Save the image
    with open("street_view_test.jpg", "wb") as f:
        f.write(response.content)
    print("Image saved as 'street_view_test.jpg'")
else:
    print(f"Error: {response.text}")
# Out:
# Status Code: 200
# Image saved as 'street_view_test.jpg'

# %% [markdown]
# ## Build the pipeline
#
# We will write a function that samples `N` points around the radius `R` starting from a fixed location `center`.
#
# It will need to retry because we may encounter locations that do not have street views associated; we will implement this later on.

# %%
import random
import math

def sample_points_in_radius(center : tuple[float, float], radius : float, N : int) -> list[tuple[float, float]]:
    """
    Sample N points in a circle of radius R centered at center.

    Args:
        center: tuple of float, the center of the circle (lat, lon)
        radius: float, the radius of the circle in meters
        N: int, the number of points to sample

    Returns:
        list of tuples of float, the sampled points (lat, lon)
    """
    center_lat, center_lon = center
    points = []
    
    for _ in range(N):
        # Generate random angle and distance
        angle = random.uniform(0, 2 * math.pi)
        # Use square root for uniform distribution in circle
        distance = math.sqrt(random.uniform(0, 1)) * radius
        
        # Convert meters to approximate lat/lon offset
        # Rough approximation: 1 degree lat ≈ 111,000m, 1 degree lon ≈ 111,000m * cos(lat)
        lat_offset = distance / 111000
        lon_offset = distance / (111000 * math.cos(math.radians(center_lat)))
        
        # Calculate new coordinates
        new_lat = center_lat + lat_offset * math.cos(angle)
        new_lon = center_lon + lon_offset * math.sin(angle)
        
        points.append((new_lat, new_lon))
    
    return points

# %%
# Test the function
bologna_center = (44.4949, 11.3426)  # Piazza Maggiore
radius_meters = 1000  # 1km radius
n_points = 5

sampled_points = sample_points_in_radius(bologna_center, radius_meters, n_points)

print(f"Center: {bologna_center}")
print(f"Radius: {radius_meters}m")
print(f"Sampled {len(sampled_points)} points:")
for i, (lat, lon) in enumerate(sampled_points):
    print(f"  {i+1}: ({lat:.6f}, {lon:.6f})")
# Out:
# Center: (44.4949, 11.3426)
# Radius: 1000m
# Sampled 5 points:
#   1: (44.494676, 11.340528)
#   2: (44.491109, 11.346437)
#   3: (44.488079, 11.342738)
#   4: (44.496688, 11.339742)
#   5: (44.492671, 11.338319)

# %%
# Street View coverage validation
import os
import requests

API_KEY_GMP = os.getenv("GOOGLE_API_KEY")

# Funzione di Validazione con Street View Metadata API (Richiede l'API_KEY_GMP globale)
def validate_streetview_coverage(lat: float, lng: float):
    """
    Usa Street View Metadata per verificare se esiste un panorama per la location.
    Restituisce (has_coverage: bool, date: Optional[str], pano_id: Optional[str]).
    """
    global API_KEY_GMP

    metadata_url = (
        "https://maps.googleapis.com/maps/api/streetview/metadata?"
        f"location={lat},{lng}&"
        f"key={API_KEY_GMP}"
    )

    try:
        response = requests.get(metadata_url, timeout=5)
        response.raise_for_status()
        data = response.json()

        if data.get('status') == 'OK':
            date = data.get('date', None)
            pano_id = data.get('pano_id', None)
            return True, date, pano_id
        else:
            return False, None, None

    except requests.RequestException:
        return False, None, None

# %%
# Sample only points with Street View coverage (with retries)
import time
from typing import List, Tuple


def sample_points_with_coverage(center: tuple[float, float], radius_m: float, n_points: int,
                                max_attempts: int = 200, request_pause_s: float = 0.0) -> list[tuple[float, float]]:
    """
    Sample points uniformly within radius and keep only those with Street View coverage.
    Stops when n_points are found or max_attempts reached.
    """
    valid_points: List[Tuple[float, float]] = []
    attempts = 0

    while len(valid_points) < n_points and attempts < max_attempts:
        lat, lon = sample_points_in_radius(center, radius_m, 1)[0]
        has_cov, _, _ = validate_streetview_coverage(lat, lon)
        if has_cov:
            valid_points.append((lat, lon))
        attempts += 1
        if request_pause_s:
            time.sleep(request_pause_s)

    return valid_points

# %%
# Use the coverage-aware sampler
bologna_center = (44.4949, 11.3426)
radius_meters = 1000
n_points = 5

max_attempts = 100  # stop if we can't find N within this many attempts
sampled_points = sample_points_with_coverage(bologna_center, radius_meters, n_points,
                                            max_attempts=max_attempts, request_pause_s=0.0)

print(f"Requested {n_points} points; collected {len(sampled_points)} with Street View coverage.")
for i, (lat, lon) in enumerate(sampled_points):
    print(f"  {i+1}: ({lat:.6f}, {lon:.6f})")
# Out:
# Requested 5 points; collected 5 with Street View coverage.
#   1: (44.493020, 11.343376)
#   2: (44.495383, 11.352613)
#   3: (44.486900, 11.345838)
#   4: (44.491449, 11.338826)
#   5: (44.490663, 11.341285)

# %%
# Visualize with folium
import folium

# Create map centered on Bologna
m = folium.Map(location=bologna_center, zoom_start=13)

# Add the center point with a different marker
folium.Marker(
    bologna_center,
    popup='Center (Piazza Maggiore)',
    tooltip='Center',
    icon=folium.Icon(color='red', icon='flag')
).add_to(m)

# Add the sampled points
for i, (lat, lon) in enumerate(sampled_points):
    folium.Marker(
        [lat, lon],
        popup=f'Point {i+1}',
        tooltip=f'Point {i+1}',
        icon=folium.Icon(color='blue', icon='circle')
    ).add_to(m)

# Add a circle to show the radius
folium.Circle(
    location=bologna_center,
    radius=radius_meters,
    color='red',
    fill=False,
    weight=2,
    opacity=0.5
).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88aa1e2cb5eac83add0095aaed8665c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88aa1e2cb5eac83add0095aaed8665c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88aa1e2cb5eac83add0095aaed8665c7 = L.map(
#                 &quot;map_88aa1e2cb5eac83add0095aaed8665c7&quot;,
#                 {
#                     center: [44.4949, 11.3426],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc94a59e355783eee852ef7875d059e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cc94a59e355783eee852ef7875d059e7.addTo(map_88aa1e2cb5eac83add0095aaed8665c7);
#
#
#             var marker_c6ee0247d6350575cd5a8a4374b41531 = L.marker(
#                 [44.4949, 11.3426],
#                 {
# }
#             ).addTo(map_88aa1e2cb5eac83add0095aaed8665c7);
#
#
#             var icon_32450eb2f42e3380866a3efa2c77f362 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ee85d35e4ea27c246d5925ee26a14c73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_934826900f1dd26eb7d731e175f95272 = $(`&lt;div id=&quot;html_934826900f1dd26eb7d731e175f95272&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Center (Piazza Maggiore)&lt;/div&gt;`)[0];
#                 popup_ee85d35e4ea27c246d5925ee26a14c73.setContent(html_934826900f1dd26eb7d731e175f95272);
#
#
#
#         marker_c6ee0247d6350575cd5a8a4374b41531.bindPopup(popup_ee85d35e4ea27c246d5925ee26a14c73)
#         ;
#
#
#
#
#             marker_c6ee0247d6350575cd5a8a4374b41531.bindTooltip(
#                 `&lt;div&gt;
#                      Center
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_c6ee0247d6350575cd5a8a4374b41531.setIcon(icon_32450eb2f42e3380866a3efa2c77f362);
#
#
#             var marker_33440e710d22dfb578d6f61753a3e3b3 = L.marker(
#                 [44.49301965951461, 11.343376400522459],
#                 {
# }
#             ).addTo(map_88aa1e2cb5eac83add0095aaed8665c7);
#
#
#             var icon_91d4f14ecc22de11b38d142d647f92a1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;circle&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b49c19a7514282694c66eddbc7503e16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b68c1f54212f81dde88a340498a7b5a = $(`&lt;div id=&quot;html_1b68c1f54212f81dde88a340498a7b5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 1&lt;/div&gt;`)[0];
#                 popup_b49c19a7514282694c66eddbc7503e16.setContent(html_1b68c1f54212f81dde88a340498a7b5a);
#
#
#
#         marker_33440e710d22dfb578d6f61753a3e3b3.bindPopup(popup_b49c19a7514282694c66eddbc7503e16)
#         ;
#
#
#
#
#             marker_33440e710d22dfb578d6f61753a3e3b3.bindTooltip(
#                 `&lt;div&gt;
#                      Point 1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_33440e710d22dfb578d6f61753a3e3b3.setIcon(icon_91d4f14ecc22de11b38d142d647f92a1);
#
#
#             var marker_7420b1b2e6d923e107552f8dcb323669 = L.marker(
#                 [44.49538309159849, 11.352612894749594],
#                 {
# }
#             ).addTo(map_88aa1e2cb5eac83add0095aaed8665c7);
#
#
#             var icon_ff539ddc307f50514a3e33bc1180b908 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;circle&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8045c20ae4679b7f9c06f6145f3818cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_284c7b6e473b8452c777ed55cb4c2152 = $(`&lt;div id=&quot;html_284c7b6e473b8452c777ed55cb4c2152&quot; style=&quot;width: 100.0%

# %%
# Build Street View URL entries and save to CSV (URLs without API key)
import os
import pandas as pd

# Configuration
size = "640x640"
fov = 90
headings = [0, 90, 180, 270]
pitches = [-45, 0, 45]
include_key_in_csv = False  # avoid exposing API key in the CSV

streetview_base = "https://maps.googleapis.com/maps/api/streetview"

rows = []
for point_idx, (lat, lon) in enumerate(sampled_points):
    for heading in headings:
        for pitch in pitches:
            # Skip rotating sky views - sky looks the same from all directions
            if pitch == 45 and heading != 0:
                continue
                
            params = {
                "size": size,
                "location": f"{lat},{lon}",
                "heading": heading,
                "pitch": pitch,
                "fov": fov,
            }
            # URL without the key (safe to store/share)
            url_no_key = (
                f"{streetview_base}?size={params['size']}&location={params['location']}"
                f"&heading={params['heading']}&pitch={params['pitch']}&fov={params['fov']}"
            )
            # Template with placeholder for key (for agents that can inject it)
            url_with_placeholder = url_no_key + "&key={API_KEY}"
            # Optionally materialize with your key (not recommended to persist)
            url_with_key = (
                url_no_key + f"&key={API_KEY_GMP}" if include_key_in_csv else None
            )

            rows.append({
                "point_index": point_idx,
                "lat": lat,
                "lon": lon,
                "heading": heading,
                "pitch": pitch,
                "fov": fov,
                "size": size,
                "url_template": url_with_placeholder,
                "url_no_key": url_no_key,
                "url_with_key": url_with_key,
            })

sv_df = pd.DataFrame(rows)
print(f"Generated {len(sv_df)} Street View entries for {len(sampled_points)} points.")
sv_df.head()
# Out:
# Generated 45 Street View entries for 5 points.
#    point_index       lat        lon  heading  pitch  fov     size  \
# 0            0  44.49302  11.343376        0    -45   90  640x640
# 1            0  44.49302  11.343376        0      0   90  640x640
# 2            0  44.49302  11.343376        0     45   90  640x640
# 3            0  44.49302  11.343376       90    -45   90  640x640
# 4            0  44.49302  11.343376       90      0   90  640x640
#
#                                         url_template  \
# 0  https://maps.googleapis.com/maps/api/streetvie...
# 1  https://maps.googleapis.com/maps/api/streetvie...
# 2  https://maps.googleapis.com/maps/api/streetvie...
# 3  https://maps.googleapis.com/maps/api/streetvie...
# 4  https://maps.googleapis.com/maps/api/streetvie...
#
#                                           url_no_key url_with_key
# 0  https://maps.googleapis.com/maps/api/streetvie...         None
# 1  https://maps.googleapis.com/maps/api/streetvie...         None
# 2  https://maps.googleapis.com/maps/api/streetvie...         None
# 3  https://maps.googleapis.com/maps/api/streetvie...         None
# 4  https://maps.googleapis.com/maps/api/streetvie...         None

# %%
# Save to CSV
out_csv = "streetview_samples.csv"
sv_df.to_csv(out_csv, index=False)
print(f"Saved {len(sv_df)} rows to {out_csv}")
# Out:
# Saved 45 rows to streetview_samples.csv

# %%
# Add layer column (ground/horizon/sky) and point_id, then save layered CSV

def classify_layer(pitch: float) -> str:
    if pitch <= -30:
        return "ground"
    if pitch >= 30:
        return "sky"
    return "horizon"

sv_df["layer"] = sv_df["pitch"].apply(classify_layer)
sv_df["point_id"] = sv_df["point_index"]

# Reorder columns for readability
cols = [
    "point_id", "point_index", "lat", "lon", "layer",
    "heading", "pitch", "fov", "size",
    "url_no_key", "url_template", "url_with_key",
]
sv_df = sv_df[cols]

layered_csv = "streetview_samples.csv"
sv_df.to_csv(layered_csv, index=False)
print(f"Saved layered CSV with {len(sv_df)} rows to {layered_csv}")
sv_df.head(10)
# Out:
# Saved layered CSV with 45 rows to streetview_samples.csv
#    point_id  point_index        lat        lon    layer  heading  pitch  fov  \
# 0         0            0  44.493020  11.343376   ground        0    -45   90
# 1         0            0  44.493020  11.343376  horizon        0      0   90
# 2         0            0  44.493020  11.343376      sky        0     45   90
# 3         0            0  44.493020  11.343376   ground       90    -45   90
# 4         0            0  44.493020  11.343376  horizon       90      0   90
# 5         0            0  44.493020  11.343376   ground      180    -45   90
# 6         0            0  44.493020  11.343376  horizon      180      0   90
# 7         0            0  44.493020  11.343376   ground      270    -45   90
# 8         0            0  44.493020  11.343376  horizon      270      0   90
# 9         1            1  44.495383  11.352613   ground        0    -45   90
#
#       size                                         url_no_key  \
# 0  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 1  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 2  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 3  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 4  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 5  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 6  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 7  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 8  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 9  640x640  https://maps.googleapis.com/maps/api/streetvie...
#
#                                         url_template url_with_key
# 0  https://maps.googleapis.com/maps/api/streetvie...         None
# 1  https://maps.googleapis.com/maps/api/streetvie...         None
# 2  https://maps.googleapis.com/maps/api/streetvie...         None
# 3  https://maps.googleapis.com/maps/api/streetvie...         None
# 4  https://maps.googleapis.com/maps/api/streetvie...         None
# 5  https://maps.googleapis.com/maps/api/streetvie...         None
# 6  https://maps.googleapis.com/maps/api/streetvie...         None
# 7  https://maps.googleapis.com/maps/api/streetvie...         None
# 8  https://maps.googleapis.com/maps/api/streetvie...         None
# 9  https://maps.googleapis.com/maps/api/streetvie...         None
