# %% [markdown]
# # Building up the pipeline to sample street views
#
# First, I want to see how Google APIs work and how i can combine them together.
#
# Specifically I want to check out:
#
# - Places API
# - StreetView API

# %% [markdown]
# I already got an API key and set it in my env file.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Global API key configuration
import os
API_KEY_GMP = os.getenv("GOOGLE_API_KEY")
assert API_KEY_GMP, "Missing GOOGLE_API_KEY in environment."

# %% [markdown]
# Call the places API in a radius around Bologna:

# %%
import os
import requests
import json

# Example request to Places API - Text Search restricted to Bologna
query = "Giardini Margherita"
url = "https://places.googleapis.com/v1/places:searchText"

headers = {
    "Content-Type": "application/json",
    "X-Goog-Api-Key": API_KEY_GMP,
    'X-Goog-FieldMask' : '*'   # many fields available, use '*' to get all
}

#useful: location contains lat and lon

# Bologna coordinates
bologna_lat = 44.4949
bologna_lng = 11.3426
radius_meters = 5000  # 5km radius

payload = {
    "textQuery": query,
    "locationBias": {
        "circle": {
            "center": {
                "latitude": bologna_lat,
                "longitude": bologna_lng
            },
            "radius": radius_meters
        }
    },
    "maxResultCount": 5  # Limit to 5 results
}

response = requests.post(url, headers=headers, json=payload)
data = response.json()

print("Status Code:", response.status_code)
print(f"\nSearching for '{query}' in Bologna (radius: {radius_meters}m)")
print(f"\nNumber of results: {len(data.get('places', []))}")
print("\nResponse:")
print(json.dumps(data, indent=2))
# Out:
# Status Code: 200
#
# Searching for 'Giardini Margherita' in Bologna (radius: 5000m)
#
# Number of results: 1
#
# Response:
# {
#   "places": [
#     {
#       "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0",
#       "id": "ChIJLwKOhMXUf0cRiLrCD6oTfS0",
#       "types": [
#         "hiking_area",
#         "tourist_attraction",
#         "park",
#         "sports_activity_location",
#         "point_of_interest",
#         "establishment"
#       ],
#       "nationalPhoneNumber": "051 203040",
#       "internationalPhoneNumber": "+39 051 203040",
#       "formattedAddress": "Viale Giovanni Gozzadini, 40136 Bologna BO, Italy",
#       "addressComponents": [
#         {
#           "longText": "Viale Giovanni Gozzadini",
#           "shortText": "Viale Giovanni Gozzadini",
#           "types": [
#             "route"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Bologna",
#           "shortText": "Bologna",
#           "types": [
#             "locality",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Bologna",
#           "shortText": "Bologna",
#           "types": [
#             "administrative_area_level_3",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Citt\u00e0 Metropolitana di Bologna",
#           "shortText": "BO",
#           "types": [
#             "administrative_area_level_2",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Emilia-Romagna",
#           "shortText": "Emilia-Romagna",
#           "types": [
#             "administrative_area_level_1",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Italy",
#           "shortText": "IT",
#           "types": [
#             "country",
#             "political"
#           ],
#           "languageCode": "en"
#         },
#         {
#           "longText": "40136",
#           "shortText": "40136",
#           "types": [
#             "postal_code"
#           ],
#           "languageCode": "en-US"
#         }
#       ],
#       "plusCode": {
#         "globalCode": "8FPHF9M2+3X",
#         "compoundCode": "F9M2+3X Bologna, Metropolitan City of Bologna, Italy"
#       },
#       "location": {
#         "latitude": 44.4827156,
#         "longitude": 11.3524117
#       },
#       "viewport": {
#         "low": {
#           "latitude": 44.48259271970851,
#           "longitude": 11.348590399999999
#         },
#         "high": {
#           "latitude": 44.4852906802915,
#           "longitude": 11.352411700000001
#         }
#       },
#       "rating": 4.6,
#       "googleMapsUri": "https://maps.google.com/?cid=3277797724925377160&g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#       "websiteUri": "http://www.comune.bologna.it/",
#       "regularOpeningHours": {
#         "openNow": true,
#         "periods": [
#           {
#             "open": {
#               "day": 0,
#               "hour": 0,
#               "minute": 0
#             }
#           }
#         ],
#         "weekdayDescriptions": [
#           "Monday: Open 24 hours",
#           "Tuesday: Open 24 hours",
#           "Wednesday: Open 24 hours",
#           "Thursday: Open 24 hours",
#           "Friday: Open 24 hours",
#           "Saturday: Open 24 hours",
#           "Sunday: Open 24 hours"
#         ]
#       },
#       "utcOffsetMinutes": 60,
#       "adrFormatAddress": "<span class=\"street-address\">Viale Giovanni Gozzadini</span>, <span class=\"postal-code\">40136</span> <span class=\"locality\">Bologna</span> <span class=\"region\">BO</span>, <span class=\"country-name\">Italy</span>",
#       "businessStatus": "OPERATIONAL",
#       "userRatingCount": 17288,
#       "iconMaskBaseUri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/tree_pinlet",
#       "iconBackgroundColor": "#4DB546",
#       "displayName": {
#         "text": "Giardini Margherita",
#         "languageCode": "en"
#       },
#       "primaryTypeDisplayName": {
#         "text": "Park",
#         "languageCode": "en-US"
#       },
#       "currentOpeningHours": {
#         "openNow": true,
#         "periods": [
#           {
#             "open": {
#               "day": 2,
#               "hour": 0,
#               "minute": 0,
#               "truncated": true,
#               "date": {
#                 "year": 2025,
#                 "month": 10,
#                 "day": 28
#               }
#             },
#             "close": {
#               "day": 1,
#               "hour": 23,
#               "minute": 59,
#               "truncated": true,
#               "date": {
#                 "year": 2025,
#                 "month": 11,
#                 "day": 3
#               }
#             }
#           }
#         ],
#         "weekdayDescriptions": [
#           "Monday: Open 24 hours",
#           "Tuesday: Open 24 hours",
#           "Wednesday: Open 24 hours",
#           "Thursday: Open 24 hours",
#           "Friday: Open 24 hours",
#           "Saturday: Open 24 hours",
#           "Sunday: Open 24 hours"
#         ]
#       },
#       "primaryType": "park",
#       "shortFormattedAddress": "Viale Giovanni Gozzadini, Bologna",
#       "editorialSummary": {
#         "text": "Popular public park with lots of trees, a lake & lawns, plus a jogging path & play areas for kids.",
#         "languageCode": "en"
#       },
#       "reviews": [
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/ChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE",
#           "relativePublishTimeDescription": "5 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Free of charge, easy access, designated areas for many choices from play grounds for kids to badminton for adults. Biking is allowed, too.\nGrab your picnic basket and spend the day here.\nOr bring your book and enjoy the resreshments/pastey at the caffea inside the park.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Free of charge, easy access, designated areas for many choices from play grounds for kids to badminton for adults. Biking is allowed, too.\nGrab your picnic basket and spend the day here.\nOr bring your book and enjoy the resreshments/pastey at the caffea inside the park.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Zuhal",
#             "uri": "https://www.google.com/maps/contrib/117843459985379991032/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWSs1QQ9P4X5_D0vCwFwIInIqTUffw7UZOM_BhqGnjSqTy3Dnpn=s128-c0x00000000-cc-rp-mo-ba4"
#           },
#           "publishTime": "2025-05-03T10:30:48.565848Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB",
#           "relativePublishTimeDescription": "3 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Giardini Margherita is Bologna\u2019s most beloved park\u2014a peaceful, green escape perfect for relaxing, walking, or picnicking. With tree-lined paths, a small lake, caf\u00e9s, and play areas, it\u2019s popular with locals and visitors alike. Ideal for a break from the city\u2019s bustle, especially on sunny days. Great for solo travelers, families, or anyone wanting a breath of fresh air in a beautiful setting.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Giardini Margherita is Bologna\u2019s most beloved park\u2014a peaceful, green escape perfect for relaxing, walking, or picnicking. With tree-lined paths, a small lake, caf\u00e9s, and play areas, it\u2019s popular with locals and visitors alike. Ideal for a break from the city\u2019s bustle, especially on sunny days. Great for solo travelers, families, or anyone wanting a breath of fresh air in a beautiful setting.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Dani Baal",
#             "uri": "https://www.google.com/maps/contrib/103357020897930875043/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXd5F4_0jTgLXfmVTKm-2qvHv52-mDsO2tP9IWzdgV09PasJeSo=s128-c0x00000000-cc-rp-mo-ba7"
#           },
#           "publishTime": "2025-07-28T12:37:34.868920783Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/ChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB",
#           "relativePublishTimeDescription": "7 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Beautiful green space easily accessible from the center of Bologna.  Some playgrounds, remote working space, walkways great for kids to ride bicycles on and some playgrounds. There are a few cafe\u2019s and bars as well and a very small go kart course with electric go karts and pedal karts.  It\u2019s a gem in this city and a must visit on a nice day.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Beautiful green space easily accessible from the center of Bologna.  Some playgrounds, remote working space, walkways great for kids to ride bicycles on and some playgrounds. There are a few cafe\u2019s and bars as well and a very small go kart course with electric go karts and pedal karts.  It\u2019s a gem in this city and a must visit on a nice day.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Aldo Pinotti",
#             "uri": "https://www.google.com/maps/contrib/101428219914666686008/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVcPEKbbFMj1FaxARFYvyiVYEGsWZBBiDVb8Ub98FPERNqYWwgEyw=s128-c0x00000000-cc-rp-mo-ba3"
#           },
#           "publishTime": "2025-03-24T15:48:07.497659Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB",
#           "relativePublishTimeDescription": "2 weeks ago",
#           "rating": 5,
#           "text": {
#             "text": "Very nice park with a lovely picnic / bar area at the back, near the botanical area.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Very nice park with a lovely picnic / bar area at the back, near the botanical area.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Holly Pope",
#             "uri": "https://www.google.com/maps/contrib/111127058743800932797/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWZOw83XmvpAxB6atDufAr8WzVQ0NMaWaPUrxUti9wkeVncdQK1=s128-c0x00000000-cc-rp-mo-ba3"
#           },
#           "publishTime": "2025-10-11T12:52:40.557526010Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB",
#           "relativePublishTimeDescription": "a week ago",
#           "rating": 5,
#           "text": {
#             "text": "One of the city's many green spaces. Beautiful and quiet!",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "One of the city's many green spaces. Beautiful and quiet!",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Desart Ajazi",
#             "uri": "https://www.google.com/maps/contrib/116110492896188753454/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVz6_AmSIYggCVaxgOqjgePmbiRDdj3I_c0wYfPXmsqsHGbcUe0Cw=s128-c0x00000000-cc-rp-mo-ba2"
#           },
#           "publishTime": "2025-10-16T21:03:11.109817558Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         }
#       ],
#       "photos": [
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU6eD0VEJOB6OjTZwm85Ry8b5b8luIazHknpCfhphzSuh-kFMXnZ-ZXk-MHAK0NHQWt1qgu7UtIpJsic-fwFivNQIZ4ggb1hyqYx5-hJZqYcgFEbD5OnoMz6n3eixCAsD_4NT59YMZN6c87NzXB_enfz7JpJb4d5BPZvHPeVuFPH-5PW7uCGknsunANH-qoWJu6DRg5yu1PsJ7pD_KZ5vhUr2gScLkQ2qhWK149-SWbSt_yJY8dTEgQX8OEEJ_qCZM4iNdkyDc6O_xTPCt2s2B2OjYbWkq1OmNuw-zHDkvrGDyvBK4AUWsmQKFsKhIiPTCytjU9-kBtwOh44DKop_bx8dsW3XPq0-6q9FxN9_F2VFQxS4i8Z_yvf8Ur-OtVwpkS99lXtdKb8BKf-kj2Di-fvL6wzOvwTBP7Xdvui-SdEvaqc",
#           "widthPx": 3024,
#           "heightPx": 4032,
#           "authorAttributions": [
#             {
#               "displayName": "Phanendra das",
#               "uri": "https://maps.google.com/maps/contrib/116022813752209071834",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVunoPhApjuMp4Jzb0pegqb8AXkpXP-YalBn3EIe8u5aRFM022k=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgID7-vrO1QE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgID7-vrO1QE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5TOr8MrdqzFGs-qh5esTn-WnB-_e6ePd6_CvMsuCyUrbdcC8EdvZqYLAX-FjsuuVXEz1R1MjKsg1Al60iUT-F1RXQqns3wem0PFoNF0hvOVzWZeVwScm8vs8hCJ46zvvNe2Ok_WzqNTKIoPqSynV-5So_IF5Wb_DxEYNHNH_D3Hren1Lcmov5KmPFN9e62E70N9GtC0Cd7obQDV9V2-3sRxioWGqpDy9Oyl6vryz9dOgHAaNp-OVyO9_cP4qIcMfnod1ObwevLTmSGBqdkU6KJA3UTdzqI6Reg0MXxVaeq4m5LT9y7rmY9nnb5U2HWLZnOxvyMvy_-vCKyNX8Ge6fQRkUt43iOxmuG_GXDDcSnBHjpar535oW7bwRuF1blwUXrOzwNt2sW8g5qTxDiBblbTUsrWmpUsk_0Tti3y5SEsAdl",
#           "widthPx": 3600,
#           "heightPx": 4800,
#           "authorAttributions": [
#             {
#               "displayName": "Giorgio Fanigliulo",
#               "uri": "https://maps.google.com/maps/contrib/117481865498945288789",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocLkuf7-zukIxOywXFuHoa37kpEoKqtO38yaq0Zt1SF0SVWekA=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgID63fLgjwE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgID63fLgjwE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5akE2M0XoPinL3iZojTYIzEAqRI95iP8ZCz_nSpK2vLZOxCtVUyPLnAc7Nt31Qt5Q_qEU-f4Ob9_c7VvaUut6eb8lnopFbolXQ26_bQE0hQz9DgYO1F-ANcVreBTij7DGtWrimyi8S9FqnLluPa5jjiWV8JE0ccKokiKxGShHO6oSaihbSXYfCVc-a1bN3flFk_6WepjPX0XsWLjPJiOfgLsA82mq8sl4ILTt9lI5zJ2U_xDyG6MP30HK4yCeFk2bKwMcrqKpCl4EtElV8pKAx2sR8sTt7l5VLPBmlhGhk_YrkRty3gmxkyGDr-HE6TihigEdE1pYPpeFNYUCjMvK74TROlOzwQzPwFFkWS6HHTWP5FXuzCWScq3Hqcujr8wT6LvjdqLCGmBvMxx5UixDPH_WCVFl2ENEla9zZXsYOLw",
#           "widthPx": 3456,
#           "heightPx": 4608,
#           "authorAttributions": [
#             {
#               "displayName": "Giorgio Scarabelli",
#               "uri": "https://maps.google.com/maps/contrib/117147474204335919716",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVOKqJAVuxnwSYNOyRbCRTPzAgexBsZCf0oCkbNhdlYgABi9eG7=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEJyj89nwnPORCw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEJyj89nwnPORCw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU56jjZozoGO9OT51AxzPPVp6PoGipsSJR4AXuPTmF4PKsSqj4qGqr3pyQOddgR-8uDDMsa3xqShM-lj2g415D_k8npxx5v7n43VuFbnDg35Uq-glTP8Ynxnhw6TkBKfyT_hn-BkrbjyE3H0riO7uTNQMBTKdnwl5p3BQ8KZ1apCKwUdO6Gq6nSJF6Sfj0eQDIWCf9gzn8U2Jtg-ST_auSPr1AqQwuWWMt0sPYApiscsH1Zsz1bDbzOHUZhJd7kpS0ifvyopW3uc20knhekSsu4gOshaXCMg3UiikV-Q4G6KCEyn4bLp6e9GU8DKNnLKOWIAbiDmPnf7Ivwlu12aFLgegHoImLOf6mJQBux6-JLdyLB6hE4FCB5LxcdbLFb1xZeegJa7uKUzI2AIHNKTXq3XzR5nvjB3VC2b1Fxb2pZHhPN-",
#           "widthPx": 4032,
#           "heightPx": 3024,
#           "authorAttributions": [
#             {
#               "displayName": "Diana B",
#               "uri": "https://maps.google.com/maps/contrib/114064809743683456601",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVfheGMKzOKVjl0o1d2cjMqF-PTjdtooKQHpOJBhdXO4ln1cdYj=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICO3ZndwQE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICO3ZndwQE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU7gsKa0Znsd7A0GXPx5h6zovpt1LZ_-Pp9h7mzYdqrQ5KxOmI9IYmvZoUk-TBal-MthUj3awhQ6Lwsu1SbTrbtH70ylnxk0g4xYrhuOS4YgA5BKF3cTCjI2EE927vB9_kavKHetNWPT8FWxmR8hj1GLS3kRxRwTb96U-ROpYwqekEqXnWd5h2VPJvKUaEukjg-95ZVt1CYbeVxOmEyJYIjo6PHAXIchxnICMUfKcir1WH_SSyuSKkzfGq7vXdYLF-N7OuNKil9jEDnnY1vv3fv-ihlIBKJyN0YdsAPGCxbVpp3okCch9AVixkByIhGKlVhobMUoH_56f3ExWD2e03AyF69ZDzKZtNIgAQPRrre6sK_ra-q41hzsKU5VxJZkVUkczJU_ecZQkIvyHI4hrVuFa3e4EHeazXKb_rduLApDZw",
#           "widthPx": 3000,
#           "heightPx": 4000,
#           "authorAttributions": [
#             {
#               "displayName": "Stefano Merighi",
#               "uri": "https://maps.google.com/maps/contrib/100902344886524646680",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVlok2JP0fUlKE37CfPP2q8qmjNDFhzV7i4-QQANRrvEK3BTZlYiA=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICmv_uRAQ&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICmv_uRAQ!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU7DACBCSuYusMxJ_OqRxY1CZrFbZKRr4O_QoQ1FklH0xLJKUQvk97zMY5cMe8ZjVpTppdV-_TRJ1UtrXRZ69VpY2AIMk7KSl73NGFaIL8Ki98gi77lr679cZFOTS9nLSMOuFyHCBTIaNIziFOQWQ5zjaFAlDiFmK9P5Lry2KuLfJxBlOFvLwl1teo32j32gedHzBN29rwI1X1Oi3ivPGiy-_o9nH4NVbZi2NTh59fVIOOIH65fmPmNKQ_x4Yk3V9ookhnaOIF34jW9GS4_MOmDeWNnZzu-9vHE2LCGQIknO8W3sywpx7PN2PU94UQ8XZMms6JEhLaqPtRYfu6EWqOxr8kNWCnuDwbu-DWXpXvxsYBH7C90mJ-2mL55-i9o5nXLYo94tuOQJ0t27XxL7GL4bbBvogYvw8ygotd2ngoc",
#           "widthPx": 2272,
#           "heightPx": 1836,
#           "authorAttributions": [
#             {
#               "displayName": "Marco Mongitore",
#               "uri": "https://maps.google.com/maps/contrib/117247794346755004430",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocIenO4PrC7jbH9298glrWmPQRGsPnI2BnA0H3nAssp0ujjqlkfV=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDcj-22Hw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDcj-22Hw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU6VerXsWwLCKHxuKOLIyOPHn2H2sYlYCOvIeql4huMl2mZF0G_lkQFDyXsihX4SRCfFjtMahbqo17QJz_GRNhujJwoqmx74-NqFhXKCSJZ8j88tRqdkMsDKPDXQkNhlOl61EO37FzIkdrB2FjfJka8p83T2CJgFlm6kFbSoLKbtlaT2e0oAOPpX7OQDgldquvSn7_QQjVQpO6Lc-2nrSaEXKqN1LZATcQPKr6sD5ErfegGrMwd2zkaaUEYqhsmZCvTSReq0-1QzFiGZlJPlkvKSU6qtWQTtKE4mmLaKA6NBxmf_wZRsjaW3aGD9o8Kt9xVj1fzuUR-J4IzUOSs2s-sTXJSR2Gw_UPcqEnoK3yb9FemadZ17KgPRhjhuz14RbmMSdtSDmVGdU9b9ygPogARPwt6VuSDmmFt_2T40Pt2uYSQN",
#           "widthPx": 4000,
#           "heightPx": 3000,
#           "authorAttributions": [
#             {
#               "displayName": "Cristina",
#               "uri": "https://maps.google.com/maps/contrib/109109969557698215870",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocI0_XUNiyglPjHsgBgMQk5FYUxrzN_OnKCNTNvXG_p0nEXYKQ=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICKgfiM9AE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICKgfiM9AE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5gvLHfe5-dyz1N09WAuAvoyDgUXjRywIUsiaOFrOk0Eh9EwU5d86KENm6WQ_39SOCLhsVGyHoLlBRpRP39PzYhxKtPeWKKZDdaSUjZhpd4lz84QTAe5_AfAP7G610r2E0K_ACsYnwe59E6EsDa61jVV4jhlKVcOyiHod1vFsoH6ovcx6DjBbEaztrCZZnMULw1oJvDsDQLqRiGjcLVjBnroiFVgKQFX6lVX-cVnkeuywow7lr0vJowjED5688qGETHDpDpu7oNyXM1xj1UvXzSHmiJfCcsBfzEndA-ILnTp04nWSGsnitiyLiuTpaisBbppzO1BpopvgMyl2-ZWs4C35W6izhuApPAvEuQ_uHFtnP5AZhbYg_kvK6MRFg-4PuJeZRPCqOWeGB0Iwj7fm4fzKiDMpiIrNImv_Gxbd8",
#           "widthPx": 3968,
#           "heightPx": 2976,
#           "authorAttributions": [
#             {
#               "displayName": "massimo forni",
#               "uri": "https://maps.google.com/maps/contrib/104350402342410590076",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWoJQaKQ7ujCnhtx6izg3Z-on_EccHRbc5hGnDni2IY3i9Y62h6=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDqvr-_Vg&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDqvr-_Vg!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU6MeAMNNDLDnMdc1kuHLdl8BEPYay0_j_vF-RHDzU-omfhzhFa6VazMoCL8yCWvZm6IyTI71APPM4TwKqqATEadJykyr4mZgt3ZsWaTTrWX0xH4AbuGB5mr-SwtSQO7JIDHqVTiP6MmH73HmeUQYNLHwLs41nLI4nHAlkDoGKaRYEVpsaZk8uZ6RX6XUBhR85U4iinHeDaHZroIixDJPcxc_ahVFU_JKVVDp69RcRH1fZuJg8nsgrCZHZQtIfazAC1-vya0wR79s1QGxCRjscwLYAUF6uo2XV75P-HzyV2oR-_krT6GQfFPDDq5iHg6fLfjkbGGZtZ8JZx-M1wMlKOi3sjPj0VHMtqrDVLPctlsr35ktI8alhhtkpkZK1kBoKilPxhI93Bkf9ylGXnYTOYo4OCqtTQrZQBY34fiAb6Zgdfv",
#           "widthPx": 3648,
#           "heightPx": 2736,
#           "authorAttributions": [
#             {
#               "displayName": "Marco Monti",
#               "uri": "https://maps.google.com/maps/contrib/117527048640464687964",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXaUVUApnk1gR10KDu36WgSAQvFub2qap2N4LSukdcu1eDRoZw3=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIC2joXNuQE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIC2joXNuQE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU7-h2pa3UfJ9J0c5Y3SF0UTFDml0_6f3xlbEfgeu61npcTRhzSl8dN3fVLEs6PehgJzYtE1sMWJrMtn9Szz3oB5L2N3UmDOSvEzjbAnk_FT6cfdggYemvEAk9Vvq-6g2jz8rUIhyT9BTuzU8yJQ9F5YmUxecnpF93VWEOpYZqeV9_YAKfmPkoZXEDSP63yo4-qmgGBH5Okiv2_w3nzSHOeEbxM6VXN4irpUCBuD5Zio8wAbbhif2RHi7jWwLkLgjihGYHF4P68FL3v_RMGJFw8qNU2wtMvwLEfyWCLUaF7M0dII8ZvGw77C3ss_52YTL3II-eaecuKBwE2pugsgOk2fn5iaFmR7pdCvCgjF0sbWwUT8uokvC_YGlvVxShJl0P5pJrhZT1uWVGxhIBrbCclzfm1Q0cUeEq0ckrnonMVY6Q",
#           "widthPx": 4608,
#           "heightPx": 3456,
#           "authorAttributions": [
#             {
#               "displayName": "Mars Gofabeatz",
#               "uri": "https://maps.google.com/maps/contrib/116262144135072295136",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXBp-dEsKqjaOUNJt7wR525pL5f-3GZ0SrNNr86qEY0vSTgs1B-Vw=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDRlK7CNA&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDRlK7CNA!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         }
#       ],
#       "goodForChildren": true,
#       "allowsDogs": true,
#       "paymentOptions": {
#         "acceptsCreditCards": true,
#         "acceptsDebitCards": true,
#         "acceptsCashOnly": false
#       },
#       "accessibilityOptions": {
#         "wheelchairAccessibleParking": true,
#         "wheelchairAccessibleEntrance": true
#       },
#       "addressDescriptor": {
#         "landmarks": [
#           {
#             "name": "places/ChIJ8-EjLcTUf0cRHy_epY_lpPI",
#             "placeId": "ChIJ8-EjLcTUf0cRHy_epY_lpPI",
#             "displayName": {
#               "text": "Carrefour Express Porta Castiglione Store",
#               "languageCode": "en"
#             },
#             "types": [
#               "establishment",
#               "food",
#               "grocery_or_supermarket",
#               "health",
#               "point_of_interest",
#               "store",
#               "supermarket"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 31.259172,
#             "travelDistanceMeters": 32.876442
#           },
#           {
#             "name": "places/ChIJ396r0sXUf0cRtx-IP709mG8",
#             "placeId": "ChIJ396r0sXUf0cRtx-IP709mG8",
#             "displayName": {
#               "text": "Farmacia Dr. Max",
#               "languageCode": "it"
#             },
#             "types": [
#               "establishment",
#               "health",
#               "pharmacy",
#               "point_of_interest",
#               "store"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 29.39594,
#             "travelDistanceMeters": 15.978893
#           },
#           {
#             "name": "places/ChIJQ8QHycXUf0cRdnAeMobf1SM",
#             "placeId": "ChIJQ8QHycXUf0cRdnAeMobf1SM",
#             "displayName": {
#               "text": "Chiesa di Santa Maria della Misericordia",
#               "languageCode": "en"
#             },
#             "types": [
#               "church",
#               "establishment",
#               "place_of_worship",
#               "point_of_interest"
#             ],
#             "spatialRelationship": "DOWN_THE_ROAD",
#             "straightLineDistanceMeters": 77.96733,
#             "travelDistanceMeters": 71.19292
#           },
#           {
#             "name": "places/ChIJfxhFC8XUf0cR0Xo9dUoTA6s",
#             "placeId": "ChIJfxhFC8XUf0cR0Xo9dUoTA6s",
#             "displayName": {
#               "text": "Serre dei Giardini Margherita",
#               "languageCode": "en"
#             },
#             "types": [
#               "bar",
#               "establishment",
#               "food",
#               "point_of_interest",
#               "restaurant",
#               "school"
#             ],
#             "straightLineDistanceMeters": 216.12418,
#             "travelDistanceMeters": 231.01735
#           },
#           {
#             "name": "places/ChIJPf2OzsXUf0cRhB7p5uqjLII",
#             "placeId": "ChIJPf2OzsXUf0cRhB7p5uqjLII",
#             "displayName": {
#               "text": "B&B Al Parco Giardini Margherita Sconti Rizzoli e Villa Regina",
#               "languageCode": "en"
#             },
#             "types": [
#               "establishment",
#               "lodging",
#               "point_of_interest"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 22.453997,
#             "travelDistanceMeters": 20.678474
#           }
#         ],
#         "areas": [
#           {
#             "name": "places/ChIJLwKOhMXUf0cRSwyJnq_IU64",
#             "placeId": "ChIJLwKOhMXUf0cRSwyJnq_IU64",
#             "displayName": {
#               "text": "Giardini Margherita",
#               "languageCode": "en"
#             },
#             "containment": "NEAR"
#           },
#           {
#             "name": "places/ChIJn_75kpXUf0cRlcgftj_FyYI",
#             "placeId": "ChIJn_75kpXUf0cRlcgftj_FyYI",
#             "displayName": {
#               "text": "Old Town",
#               "languageCode": "en"
#             },
#             "containment": "OUTSKIRTS"
#           }
#         ]
#       },
#       "googleMapsLinks": {
#         "directionsUri": "https://www.google.com/maps/dir//''/data=!4m7!4m6!1m1!4e2!1m2!1m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!3e0?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "placeUri": "https://maps.google.com/?cid=3277797724925377160&g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "writeAReviewUri": "https://www.google.com/maps/place//data=!4m3!3m2!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!12e1?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "reviewsUri": "https://www.google.com/maps/place//data=!4m4!3m3!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!9m1!1b1?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "photosUri": "https://www.google.com/maps/place//data=!4m3!3m2!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!10e5?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA"
#       },
#       "timeZone": {
#         "id": "Europe/Rome"
#       },
#       "postalAddress": {
#         "regionCode": "IT",
#         "languageCode": "en-US",
#         "postalCode": "40136",
#         "administrativeArea": "Metropolitan City of Bologna",
#         "locality": "Bologna",
#         "addressLines": [
#           "Viale Giovanni Gozzadini"
#         ]
#       }
#     }
#   ],
#   "contextualContents": [
#     {
#       "photos": [
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5pJYyfIUujKqzGeOU7s0L1YRDd7YFYbIY5I4i9C8ew2PIiCXh57GJtSnWeinC1B2536QsGTjM8lom6ZFRUoB3zIp7_Xg-BGEb-MDnfw4s42HzOc30Mm-UvzvImENjLGzCHPKvq8PcBHqnU_rAFidTjaFLAXaA9GRc54Rl2gQybXxHB2sHm-VDI0syzKJEGsxVp_DVXOLBv5fb4cPgD6SlmAOI6hsMbsM_C6QZSfTDmjJNt4VqYNQyGEcn3QdqTXs11spW6ZkfhM2gtdJZFnfWXPQHb8AJIY5yU9AjKLYguNBZ0kHaPxjiEkw0a-m6SXF3rb9mjBIXe1ZROSDfmBxpkzhSQPtt8quVIUBZi6bUfBRET5R_DZW6wMnyySSRnPn-YV-9ceaeoQRi-umR1",
#           "widthPx": 4160,
#           "heightPx": 3120,
#           "authorAttributions": [
#             {
#               "displayName": "Stefano Dalzini",
#               "uri": "https://maps.google.com/maps/contrib/112388244312001538595",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjUNJHfLWK30qZ-kX3edFNT3j57FzK1BI5JWrwoHlAcZVtDPvzFO3g=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places&image_key=!1e10!2sCIHM0ogKEICAgIDUl5neCw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDUl5neCw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU6JDqNFqQZOKdfP24gIDVzYMHUIAIEl9JGZ3Tdx7LbGHr1kGAfWKKA7Bv672um-RzUlObyjk9Bwi-i9n_cQ6lLTclRxIH5Gc1s13FMrkt4IZVdreov-u-qLXOenelkB7NEBEfe94IBKxvIq0h18uipK9lMCQwKMovSIpF4z8E127BobrmnpLM8KqCk0MWD1roLXGuQ-42EelRYOlipI7cC50t9rNyBrU3BUURKC5kUBC6oDtQCmhedqQa8dVw8eHuXimEwFiQ218DEQfMzg25Ibnq-pOSymGRroo2WtKvGRbbkPbIkjaMURvBntJm4W-9AWVbKAUCzT_0iiRIC2qupAb3wGdO9jBGekEie99ncLw6sXNOVic81DZHul9Vz0IFipTSOuvev-cwr6sa1u",
#           "widthPx": 4032,
#           "heightPx": 3024,
#           "authorAttributions": [
#             {
#               "displayName": "Roberto Vanzetta",
#               "uri": "https://maps.google.com/maps/contrib/101286674699245687282",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjUKFn3PKwY9OpTsp6giY82MnPHhsyq4lTc7l5x3PpXUqJ0kzHiK=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places&image_key=!1e10!2sCIHM0ogKEICAgIC-7JSFdw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIC-7JSFdw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU4BKNDhQp2UZ-W6h1vSzAoPEG867a14xPYWj6WURRwvEMhELfcwxVW-2DMTkztDmP6QpC2qhzoWDzX9QXNvadqlaKdBKLrmAnqgJ2ROgLtmbH0hJO17x042C-yuTFb-1V1QjPJ7P8oE_u5zJgsXpYK7xzV8xFHsO0CrMN2jMd3I_HDSDFF6-Ph5-JxhM1hOw21dcTbA1S_sYbd6SgSbD5owzSGsDLURGvjT5SZi-7BKIZsHk89kgNtOJs6MRSToPAYbgiABbQFqpJ3oJjta_wHZCEdIK42Qu76w0DRQEDpoG-deMs2lFJx45keJLFzoe6nuqoTSvfuB-43VB94n2At72FyHHjSKDg-7eoJiO1pSToIcz2sFG_8d81xtrTy_6fDmmeqJgyPmRkAkXse4vFkY",
#           "widthPx": 3236,
#           "heightPx": 2427,
#           "authorAttributions": [
#             {
#               "displayName": "Federica Fini Zarri",
#               "uri": "https://maps.google.com/maps/contrib/117213070053376513693",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWie0JhCewkNri-_3dAuWp0X61bcAgtk0xw66mKLhUaWGVzTj-NMw=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places&image_key=!1e10!2sCIHM0ogKEICAgID4u8Gk_gE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgID4u8Gk_gE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU6o0EOqs_cicNaNIdyQDgd90s98bHmKuPTRn-A-yD8xTtmUnWKxprmm5W-Bsw2Bb3oAM8bxw90IWrq9eFB7ZMgKD50H3Uw-GSU8az0hvJHxI9VtAoc0jOJL1XRdCZGdenG9e2JJpoYEFE1rZDzLCGjHn1Ag_JxGVjotN-DYULACVXOdu9wVQDHxV0_g_koWmweGLdoz-RkS1ISvkXBdoLe9L2gn7_Aaw-3MkHi6eRf40TNmU1U7CO5fcOlyotDNk0Y5VmZEaQZcavFSwUWH1OyJ8z4ijvKMFxFVquAOJOuvNtqbOPhWisFL5G2aBuCnoJ5lZtmbrPyJYaCYGGsEmNHX7aP5aJ46YuDXZv4SLHeX4mg0p1ZH3B5jOzx-tQdoXuiZPObywbFka8gXlXDB",
#           "widthPx": 4608,
#           "heightPx": 3456,
#           "authorAttributions": [
#             {
#               "displayName": "Alex Bularu",
#               "uri": "https://maps.google.com/maps/contrib/100126913413494614382",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjW4iMaG_gfjxhJQrnpYltMzrDzBm6zCfJriVdgyxg32aK_eb8zf8A=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places&image_key=!1e10!2sCIHM0ogKEICAgICkmuLURQ&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICkmuLURQ!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU7EhWzs3VSzLaR-1kTZq1yNX4YHhvQSJIGuLkoeGZ32JTAyUO23yw6PJjdTNepYSoPHPD4rEPZES-9QDv_DqHI2Jcdg_9ocwjNyYUUno-25ng9zDomeDZPO9s15z4LVfaxpOAYLHfHY4-17JKlgBD_laO_mdfSnS4X74pPHkR84MWTvddVoi-9Eaj8Tr0OPjziXBTbTT1Qcc3oss_NBuoFJW1FQs6dAsxbRNYwBz_j0_aSKOBsvuhHxPaydtlrwGSqI3ZkmpgeEZ898yPDNSzsdwPDytws0wXUVyowSryqJzTtq29VYuvcJHcKmzTieM1ZjDWyKoxlC_tYJTMlYVPoxNO9ZlPfyv4Q3MvghAuTcX2k7eXFZqpQ9W3q8bOLlBxvjlp_XsLuGHq0ENwVerKi7",
#           "widthPx": 3008,
#           "heightPx": 3008,
#           "authorAttributions": [
#             {
#               "displayName": "Paolo Mazzoni",
#               "uri": "https://maps.google.com/maps/contrib/114421506459150145050",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocLzBQO0Hxd_Ge4RMufMLgNrZzN9hyr_FwXd0XSHhNXxvPSCrA=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places&image_key=!1e10!2sCIHM0ogKEICAgICqnMvxpAE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICqnMvxpAE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         }
#       ],
#       "justifications": [
#         {}
#       ]
#     }
#   ],
#   "searchUri": "https://www.google.com/maps/search/Giardini+Margherita"
# }

# %% [markdown]
# Return only needed fields: for example location, which contains lat & lon

# %%
import os
import requests
import json

# Example request to Places API - Text Search restricted to Bologna
query = "Giardini Margherita"
url = "https://places.googleapis.com/v1/places:searchText"

headers = {
    "Content-Type": "application/json",
    "X-Goog-Api-Key": API_KEY_GMP,
    'X-Goog-FieldMask' : 'places'   # many fields available, use '*' to get all
}

#useful: location contains lat and lon

# Bologna coordinates
bologna_lat = 44.4949
bologna_lng = 11.3426
radius_meters = 5000  # 5km radius

payload = {
    "textQuery": query,
    "locationBias": {
        "circle": {
            "center": {
                "latitude": bologna_lat,
                "longitude": bologna_lng
            },
            "radius": radius_meters
        }
    },
    "maxResultCount": 5  # Limit to 5 results
}

response = requests.post(url, headers=headers, json=payload)
data = response.json()

print("Status Code:", response.status_code)
print(f"\nSearching for '{query}' in Bologna (radius: {radius_meters}m)")
print(f"\nNumber of results: {len(data.get('places', []))}")
print("\nResponse:")
print(json.dumps(data, indent=2))
print("="*60)
print(data.get('places', [])[0].get('location', {}))
# Out:
# Status Code: 200
#
# Searching for 'Giardini Margherita' in Bologna (radius: 5000m)
#
# Number of results: 1
#
# Response:
# {
#   "places": [
#     {
#       "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0",
#       "id": "ChIJLwKOhMXUf0cRiLrCD6oTfS0",
#       "types": [
#         "hiking_area",
#         "tourist_attraction",
#         "sports_activity_location",
#         "park",
#         "point_of_interest",
#         "establishment"
#       ],
#       "nationalPhoneNumber": "051 203040",
#       "internationalPhoneNumber": "+39 051 203040",
#       "formattedAddress": "Viale Giovanni Gozzadini, 40136 Bologna BO, Italy",
#       "addressComponents": [
#         {
#           "longText": "Viale Giovanni Gozzadini",
#           "shortText": "Viale Giovanni Gozzadini",
#           "types": [
#             "route"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Bologna",
#           "shortText": "Bologna",
#           "types": [
#             "locality",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Bologna",
#           "shortText": "Bologna",
#           "types": [
#             "administrative_area_level_3",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Citt\u00e0 Metropolitana di Bologna",
#           "shortText": "BO",
#           "types": [
#             "administrative_area_level_2",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Emilia-Romagna",
#           "shortText": "Emilia-Romagna",
#           "types": [
#             "administrative_area_level_1",
#             "political"
#           ],
#           "languageCode": "it"
#         },
#         {
#           "longText": "Italy",
#           "shortText": "IT",
#           "types": [
#             "country",
#             "political"
#           ],
#           "languageCode": "en"
#         },
#         {
#           "longText": "40136",
#           "shortText": "40136",
#           "types": [
#             "postal_code"
#           ],
#           "languageCode": "en-US"
#         }
#       ],
#       "plusCode": {
#         "globalCode": "8FPHF9M2+3X",
#         "compoundCode": "F9M2+3X Bologna, Metropolitan City of Bologna, Italy"
#       },
#       "location": {
#         "latitude": 44.4827156,
#         "longitude": 11.3524117
#       },
#       "viewport": {
#         "low": {
#           "latitude": 44.48259271970851,
#           "longitude": 11.348590399999999
#         },
#         "high": {
#           "latitude": 44.4852906802915,
#           "longitude": 11.352411700000001
#         }
#       },
#       "rating": 4.6,
#       "googleMapsUri": "https://maps.google.com/?cid=3277797724925377160&g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#       "websiteUri": "http://www.comune.bologna.it/",
#       "regularOpeningHours": {
#         "openNow": true,
#         "periods": [
#           {
#             "open": {
#               "day": 0,
#               "hour": 0,
#               "minute": 0
#             }
#           }
#         ],
#         "weekdayDescriptions": [
#           "Monday: Open 24 hours",
#           "Tuesday: Open 24 hours",
#           "Wednesday: Open 24 hours",
#           "Thursday: Open 24 hours",
#           "Friday: Open 24 hours",
#           "Saturday: Open 24 hours",
#           "Sunday: Open 24 hours"
#         ]
#       },
#       "utcOffsetMinutes": 60,
#       "adrFormatAddress": "<span class=\"street-address\">Viale Giovanni Gozzadini</span>, <span class=\"postal-code\">40136</span> <span class=\"locality\">Bologna</span> <span class=\"region\">BO</span>, <span class=\"country-name\">Italy</span>",
#       "businessStatus": "OPERATIONAL",
#       "userRatingCount": 17288,
#       "iconMaskBaseUri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/tree_pinlet",
#       "iconBackgroundColor": "#4DB546",
#       "displayName": {
#         "text": "Giardini Margherita",
#         "languageCode": "en"
#       },
#       "primaryTypeDisplayName": {
#         "text": "Park",
#         "languageCode": "en-US"
#       },
#       "currentOpeningHours": {
#         "openNow": true,
#         "periods": [
#           {
#             "open": {
#               "day": 2,
#               "hour": 0,
#               "minute": 0,
#               "truncated": true,
#               "date": {
#                 "year": 2025,
#                 "month": 10,
#                 "day": 28
#               }
#             },
#             "close": {
#               "day": 1,
#               "hour": 23,
#               "minute": 59,
#               "truncated": true,
#               "date": {
#                 "year": 2025,
#                 "month": 11,
#                 "day": 3
#               }
#             }
#           }
#         ],
#         "weekdayDescriptions": [
#           "Monday: Open 24 hours",
#           "Tuesday: Open 24 hours",
#           "Wednesday: Open 24 hours",
#           "Thursday: Open 24 hours",
#           "Friday: Open 24 hours",
#           "Saturday: Open 24 hours",
#           "Sunday: Open 24 hours"
#         ]
#       },
#       "primaryType": "park",
#       "shortFormattedAddress": "Viale Giovanni Gozzadini, Bologna",
#       "editorialSummary": {
#         "text": "Popular public park with lots of trees, a lake & lawns, plus a jogging path & play areas for kids.",
#         "languageCode": "en"
#       },
#       "reviews": [
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/ChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE",
#           "relativePublishTimeDescription": "5 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Free of charge, easy access, designated areas for many choices from play grounds for kids to badminton for adults. Biking is allowed, too.\nGrab your picnic basket and spend the day here.\nOr bring your book and enjoy the resreshments/pastey at the caffea inside the park.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Free of charge, easy access, designated areas for many choices from play grounds for kids to badminton for adults. Biking is allowed, too.\nGrab your picnic basket and spend the day here.\nOr bring your book and enjoy the resreshments/pastey at the caffea inside the park.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Zuhal",
#             "uri": "https://www.google.com/maps/contrib/117843459985379991032/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWSs1QQ9P4X5_D0vCwFwIInIqTUffw7UZOM_BhqGnjSqTy3Dnpn=s128-c0x00000000-cc-rp-mo-ba4"
#           },
#           "publishTime": "2025-05-03T10:30:48.565848Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VJQ0FnTUNZcXVLNUVREAE!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB",
#           "relativePublishTimeDescription": "3 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Giardini Margherita is Bologna\u2019s most beloved park\u2014a peaceful, green escape perfect for relaxing, walking, or picnicking. With tree-lined paths, a small lake, caf\u00e9s, and play areas, it\u2019s popular with locals and visitors alike. Ideal for a break from the city\u2019s bustle, especially on sunny days. Great for solo travelers, families, or anyone wanting a breath of fresh air in a beautiful setting.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Giardini Margherita is Bologna\u2019s most beloved park\u2014a peaceful, green escape perfect for relaxing, walking, or picnicking. With tree-lined paths, a small lake, caf\u00e9s, and play areas, it\u2019s popular with locals and visitors alike. Ideal for a break from the city\u2019s bustle, especially on sunny days. Great for solo travelers, families, or anyone wanting a breath of fresh air in a beautiful setting.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Dani Baal",
#             "uri": "https://www.google.com/maps/contrib/103357020897930875043/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXd5F4_0jTgLXfmVTKm-2qvHv52-mDsO2tP9IWzdgV09PasJeSo=s128-c0x00000000-cc-rp-mo-ba7"
#           },
#           "publishTime": "2025-07-28T12:37:34.868920783Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2xSS05GVmtNR2xCTjJOSmVUQnlaa05rU1ZCQmJVRRAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/ChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB",
#           "relativePublishTimeDescription": "7 months ago",
#           "rating": 4,
#           "text": {
#             "text": "Beautiful green space easily accessible from the center of Bologna.  Some playgrounds, remote working space, walkways great for kids to ride bicycles on and some playgrounds. There are a few cafe\u2019s and bars as well and a very small go kart course with electric go karts and pedal karts.  It\u2019s a gem in this city and a must visit on a nice day.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Beautiful green space easily accessible from the center of Bologna.  Some playgrounds, remote working space, walkways great for kids to ride bicycles on and some playgrounds. There are a few cafe\u2019s and bars as well and a very small go kart course with electric go karts and pedal karts.  It\u2019s a gem in this city and a must visit on a nice day.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Aldo Pinotti",
#             "uri": "https://www.google.com/maps/contrib/101428219914666686008/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVcPEKbbFMj1FaxARFYvyiVYEGsWZBBiDVb8Ub98FPERNqYWwgEyw=s128-c0x00000000-cc-rp-mo-ba3"
#           },
#           "publishTime": "2025-03-24T15:48:07.497659Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChdDSUhNMG9nS0VJQ0FnTUR3X0licTRnRRAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB",
#           "relativePublishTimeDescription": "2 weeks ago",
#           "rating": 5,
#           "text": {
#             "text": "Very nice park with a lovely picnic / bar area at the back, near the botanical area.",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "Very nice park with a lovely picnic / bar area at the back, near the botanical area.",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Holly Pope",
#             "uri": "https://www.google.com/maps/contrib/111127058743800932797/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWZOw83XmvpAxB6atDufAr8WzVQ0NMaWaPUrxUti9wkeVncdQK1=s128-c0x00000000-cc-rp-mo-ba3"
#           },
#           "publishTime": "2025-10-11T12:52:40.557526010Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT21od1RqY3hjVkpsVGpWTldIWjNkbkJaYjNJeVVYYxAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/reviews/Ci9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB",
#           "relativePublishTimeDescription": "a week ago",
#           "rating": 5,
#           "text": {
#             "text": "One of the city's many green spaces. Beautiful and quiet!",
#             "languageCode": "en"
#           },
#           "originalText": {
#             "text": "One of the city's many green spaces. Beautiful and quiet!",
#             "languageCode": "en"
#           },
#           "authorAttribution": {
#             "displayName": "Desart Ajazi",
#             "uri": "https://www.google.com/maps/contrib/116110492896188753454/reviews",
#             "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVz6_AmSIYggCVaxgOqjgePmbiRDdj3I_c0wYfPXmsqsHGbcUe0Cw=s128-c0x00000000-cc-rp-mo-ba2"
#           },
#           "publishTime": "2025-10-16T21:03:11.109817558Z",
#           "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB&d=17924085&t=1",
#           "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2pSS2FFeFdMWGxyYTBkUmFHNXVaalF3VkhwU1FYYxAB!2m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         }
#       ],
#       "photos": [
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU7RyCBHZg80tvKNDUc8W3V-4Fina_x6L_W58DY659BbmjUd5rkGvP1_luy_ry9T-yG5j1wyr3MOTA39yu2hfqJBQ_5Tzcl4IFggYDYQFqOoGxANcy2Gu6dR8RRXn-htF3uMgtbOozslT9lBTk7TsWufU0MQsL1NmcYhGUZqSb4xOnwS9ScMElFyQxJ7c5JqQJYULg7YYSzZ0X9eITdAJfgSHzRbm22jBJsryMJvrl33b6YH7v-VS8oX7gjxNJgcMPCKQtJ0SZoB32IPk_QBjgxwNy2g06azCa4euyOw2CmMpWI6RALD5hHKPL8mouanT6eje2J6_ebB0cP-RYxvz6F5pgGu_0Vecm6-qTGA0a-CcoxMezJHz-1CMld9cIZqaEyysIRothJl2-fo8qO8mTwTfPRiWPw-rmf7fThRGgf7uEk2",
#           "widthPx": 3024,
#           "heightPx": 4032,
#           "authorAttributions": [
#             {
#               "displayName": "Phanendra das",
#               "uri": "https://maps.google.com/maps/contrib/116022813752209071834",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVunoPhApjuMp4Jzb0pegqb8AXkpXP-YalBn3EIe8u5aRFM022k=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgID7-vrO1QE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgID7-vrO1QE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU7_I6-YP7V6nGN-w7k4JnNp2VDNnHpBeXY4UJTC4D-py8D4Ehdesisq6sm6CuTlhtU3TMDp5wDNpEUetwlbPKCXj3H5_tQvhjVhlH6aCyMlJGi96ziHzq9Zbh2HrdSLQiqZUj7uo8MFYT_NvhVhNJZOtrCJE5qj-JWLftMX75UjFhgKUdyfu-NGYZyTM74bkBGrZJKSqY9elvWJzp64Hjo564acJxCxxXBZ6UE3VCWEY7sFyjqpMcE6cjxM-z_5G89zG1zS0OH1akm2kfw5ghrWw0R6MEqm9qFxAbP1cm2c9AFVT3Q7Eigkh6jne13dygW1AkaOOAZuu55TPn-xPTFDXuVIYiNoHLBXkJac6ZDtJpkVKQxXmezuvCSfCuLsXhQED0ruHscbkoKrou84EyUPIz68AlMioJ89TCpBJt_cwiDW",
#           "widthPx": 3600,
#           "heightPx": 4800,
#           "authorAttributions": [
#             {
#               "displayName": "Giorgio Fanigliulo",
#               "uri": "https://maps.google.com/maps/contrib/117481865498945288789",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocLkuf7-zukIxOywXFuHoa37kpEoKqtO38yaq0Zt1SF0SVWekA=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgID63fLgjwE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgID63fLgjwE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5sQxuzCc2OvuWDw3sMgk9sO97LRiiAbz3lfsXi0B8aphrh0lwB_D_IshFqXQ8N6ZAlILcc6PaYeudD8dPdOd94HuIH5SHqR2fWV2jYdqtD0eIsmrlMCwELnFFIMW234t5V7ql89ZyJRgM3q2AuPHLQ6i98uDk7XBa44c6npi-kqhmxMlFJpA6oUp3EVg1P-fofiCGSaqvm7fusTe01LWIgaVUBvYyjmzMahlhB5lWFD3MB1ngu1HG0o-dkZ3ezrjT3IKHU0l93R39GjWIru-gHaFTn1m7xwxy4-Iit87C6m5Q-BnFExB9qN_cItwVnH8Fis4jqyzJFLaqy1iq7xIc06yEAOcXxV1-e0hNCKEN8P0Viv4AHAxcrAlnNphakGYr9lkzr_D86gHxb3Hhk9BKU8Of8Ph76WM70WvUxyquvfw",
#           "widthPx": 3456,
#           "heightPx": 4608,
#           "authorAttributions": [
#             {
#               "displayName": "Giorgio Scarabelli",
#               "uri": "https://maps.google.com/maps/contrib/117147474204335919716",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVOKqJAVuxnwSYNOyRbCRTPzAgexBsZCf0oCkbNhdlYgABi9eG7=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEJyj89nwnPORCw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEJyj89nwnPORCw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5F4aAM-VZ9ENpdY6_2T0JCbkNV_gNoOMHUiU9T7mHxzxcE7_3jROVmS1djp0DOKOI72Ly72GjamSEfRvL27IcVAHtBltEd4QIW2qlQK--RGA8hkvbzsLzSzPBoUpiJgKSbqRwZtl_0iY3V6wzQGHhw29Iwdy9Y7AybKFYvgUEjqW3w8jzAFPtmV-eDWFnfqEaHrzfAiz8R4k1iBFZKwzmKv250zxC12M7Fqarb7RqS3zkprbZL70yhbKXJ39U0IqGP9rWqSi3CdKhq0K4io52cy-K01PkxfLx9qT-5eEdNXrPQFJ897koe2YJ2QXLic3R9AHFAFtuNHnJbI1X56gzSySrNKFgGyD9q6hmlUzsiDDjFOc5yJ1HMigJpxe7M0HwTCW_vUOC1GOdc7USF-ZK2hQfnjOmpApzOL74z4KMDjuQO",
#           "widthPx": 4032,
#           "heightPx": 3024,
#           "authorAttributions": [
#             {
#               "displayName": "Diana B",
#               "uri": "https://maps.google.com/maps/contrib/114064809743683456601",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVfheGMKzOKVjl0o1d2cjMqF-PTjdtooKQHpOJBhdXO4ln1cdYj=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICO3ZndwQE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICO3ZndwQE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU5zbZUEidg3dtG_AqrZ5H6QsxDL_Ev1YNalJOOLsdRlgvL2rYtRWwdElSyuVNLieqYU4uE-T9iLHrS1Sn25CgX0WV1ZJYt3j5pR8OmQHPW6RnnQeZ9_JQRG95rXMGCHAPKZLEGI71w9t0HaL2veMliZ99J1y4cxm90Z8r6EmQ-VqfZmoUkVz2x5eg_-64wXpU_o_W7y7DeFIejmoxpeNOt13yyIffaucg6ju6S68MRXZE7Z8YObAE5Fj-RM0cxXJjrDwmEBL66cn5ujEyE8wG4bwuPnLsg21MzdNjlpTpJPL8rbmP2ztsF9-Di3OfyollaEw_etk9h5vcqb0fw9aOY8fw4_KG3LpEpRy5zhwxKMTGsS67QisL66csD0DfsDEwDt4lrpJGZyQq5y3kxgelRLIcUkEectBwQ-IyTEmOs6tw",
#           "widthPx": 3000,
#           "heightPx": 4000,
#           "authorAttributions": [
#             {
#               "displayName": "Stefano Merighi",
#               "uri": "https://maps.google.com/maps/contrib/100902344886524646680",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVlok2JP0fUlKE37CfPP2q8qmjNDFhzV7i4-QQANRrvEK3BTZlYiA=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICmv_uRAQ&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICmv_uRAQ!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU4JQh8uh8CMItXs7eKry5DywMHCGi8tlWRC4jRqCJuL_n1tYRLc7RJIjXT0bCvHyNmWZjeklFrUjjxO-604Qf7EHnYfTQIXoJntJfCi2LuNXJ5lv5irWetIegG5ZMNH5gy65Zzq5DsV_8Tg6xSBXNz0nS1ojep-zQtHfQvJPh37ODlq4pNIRPzO3XVmSt9IIWf-m6lVAHWluBbtx9d2zqVpygSdVmY3BP82yX1_VV7gGlQupcxCwHOTp6lYE5N5tyLBbN9Sw-6KNi8JjIbTez1CTIzoReZYxleAz2ugJkWc_6jMhnE-biMbycwJVDOgFmg62teS0TvY16pbrJhs32lsYGhB-DbqwXfJZcUNkTScgDWX8sJIo1f-bKU32L6pZsNFxpGYiIMIdVvuhENmQno5yZikr0vEOGs7zIm8q7g",
#           "widthPx": 2272,
#           "heightPx": 1836,
#           "authorAttributions": [
#             {
#               "displayName": "Marco Mongitore",
#               "uri": "https://maps.google.com/maps/contrib/117247794346755004430",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocIenO4PrC7jbH9298glrWmPQRGsPnI2BnA0H3nAssp0ujjqlkfV=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDcj-22Hw&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDcj-22Hw!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU4a1G5cwU8uoqjgN3iwvExiCoS9FitVT_8cUwi04qBYoM69SWNOV0LYUhNe3cS62Qy0FVIRg4O8UWXXoGBJ81RTjFoqIv92cwOdCNt2beIh-bUVg_OdZFJyKdYsfcbxVbXqp3UfQNHvHSqawhqyGcWDCfGM7-33wqGWdR_q4TyAzrvlebDKCHcoSu6mxPc2DWyUvs-gyzXxjHp2oRlmhp4eKpIOpzr_SqIRVUVQ4GBerJBjqwOSc60bDZuqd0Ffu9Av-IEmUInJPJAC5pdCp7_xNWzepoW1w6fcreWIwcdQ0O6sz5PFleIHGxOyn-_4OWoDlnqRvahm7knwEwn21HXtK--SFrnnDXjIj8UY8CWRHSP5nCbI0UfyekoQ17iRC0jFDa_FEDjKPP3VFBVbus7uOMB9IHCWZ3tUDdu1rCsp4uiD",
#           "widthPx": 4000,
#           "heightPx": 3000,
#           "authorAttributions": [
#             {
#               "displayName": "Cristina",
#               "uri": "https://maps.google.com/maps/contrib/109109969557698215870",
#               "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocI0_XUNiyglPjHsgBgMQk5FYUxrzN_OnKCNTNvXG_p0nEXYKQ=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgICKgfiM9AE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgICKgfiM9AE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU4EZ3qsMaYDO7Du5WfMYTpqf35xMu2a6IS64Fz22-P7N52neVPs2uWHntb19Br-zNjO-uCbgGSaJ0kSX84zXuGfTy8Yx4dwMJAUDjN8YR3M6eSxzDJrbAhD7b9StAgFh5QRgtNNg_Iz97hlhGnOmHnj8ADfs9gl_QfZwa9_XilVwwfJQl3kTcQfHDqbQ1xEn3HJuqFvdPMYqOWYERzRsESLMHgc0EKXs996l1Ihse9i0m7XUwUQpq4zFSxtGY-z7ZBO6HNMIiZGIDjg_5KlXrNqvlDepHAU-4B9Or0D71i8dV3qeZx1b7Aq7bQyqHnYCXgP8pdXCP3U2Rpr3SoCXBlPY2uvWVa16Y9ZScpBkoqYMoC7qckB4TdKQQkrNDYJtD6cx8a1Z-9ZeHpJ9W2740ZGzEHqrAMhwOimluerIzQ",
#           "widthPx": 3968,
#           "heightPx": 2976,
#           "authorAttributions": [
#             {
#               "displayName": "massimo forni",
#               "uri": "https://maps.google.com/maps/contrib/104350402342410590076",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWoJQaKQ7ujCnhtx6izg3Z-on_EccHRbc5hGnDni2IY3i9Y62h6=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDqvr-_Vg&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDqvr-_Vg!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU52y0NqTgktwjJS5Yp6kxP0RNrZxtdKfa5T91oFEdXTywNWFPfNVfpdpeV93GN7zUA5ISYWtsI8m-7srWY67_yy2Et0-yqQkJZ5Uq7yHz-fCHqZ27qb9YsJ2yY_4BUIk4oPFaE4YiubXqfJyFCiAJ8_XTOn69FfHwlk0m53PqPdFaZvle_Wr5arciOxI-GLgldIwGd67dwSE4JwekaNedY6vEWKcn0YNH-Vm3B3IqwI3RC-Lw9EEG7N9I1pdMZKJCBGVLxFqARmWX5BbMY-r2Ww_o1kCw3uWB3QIlKP4SBn1w0MGBOqoEWIxaf40pXpMJSxcZllUBp7ha07nX5Zhz6er7vPmv6FVka00bOO3TcPGrHPJzSjIr3QzVxqHsI8RGe-3MDDnqsLfTSd3hwVz7fIAxcj3Zr5AQ1VH_TwNFRNz7VP",
#           "widthPx": 3648,
#           "heightPx": 2736,
#           "authorAttributions": [
#             {
#               "displayName": "Marco Monti",
#               "uri": "https://maps.google.com/maps/contrib/117527048640464687964",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXaUVUApnk1gR10KDu36WgSAQvFub2qap2N4LSukdcu1eDRoZw3=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIC2joXNuQE&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIC2joXNuQE!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         },
#         {
#           "name": "places/ChIJLwKOhMXUf0cRiLrCD6oTfS0/photos/AWn5SU7H1_dvNRRwC5ZioPF8VI-3iG01zK0evUg20w9vDd1gGncSWPsBAhgNJFIFUkIRvn-CHd0VMaUMHZDHhp0gHFtiUTXoCSV6hIN_KjvUs4-AsSiaSizndjv2FnV7akR7PcI_Ih1aIXNh9vFY4aszBDwr7A6DrCt9QdZg-qVF0ePeAbNJUYS0LJvnUHge2eIi-vkjOUCI0at8vV4J4rdYa4QcxQJXgtuM_w8tdxt7DSsyZQDjh6-rkoVeDAj2s2RYb1ODCqVYOBQs41GswWx2hNyg6AfKTFz-YK_U2TCmo7uRIkGV8PFinWxMrjVLTDvqYSA-yQPLZajFmzgko9eP7nTBpldC5TzAGPdBwojmzOo-PbOsZ7lRrlYeX0ifZ-G1nk8g_k0j7fpbrAQwjvadKW6pKX2LnEoplqA4pvEA9r17_Q",
#           "widthPx": 4608,
#           "heightPx": 3456,
#           "authorAttributions": [
#             {
#               "displayName": "Mars Gofabeatz",
#               "uri": "https://maps.google.com/maps/contrib/116262144135072295136",
#               "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXBp-dEsKqjaOUNJt7wR525pL5f-3GZ0SrNNr86qEY0vSTgs1B-Vw=s100-p-k-no-mo"
#             }
#           ],
#           "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDRlK7CNA&hl=en-US",
#           "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDRlK7CNA!2e10!4m2!3m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88"
#         }
#       ],
#       "goodForChildren": true,
#       "allowsDogs": true,
#       "paymentOptions": {
#         "acceptsCreditCards": true,
#         "acceptsDebitCards": true,
#         "acceptsCashOnly": false
#       },
#       "accessibilityOptions": {
#         "wheelchairAccessibleParking": true,
#         "wheelchairAccessibleEntrance": true
#       },
#       "addressDescriptor": {
#         "landmarks": [
#           {
#             "name": "places/ChIJ8-EjLcTUf0cRHy_epY_lpPI",
#             "placeId": "ChIJ8-EjLcTUf0cRHy_epY_lpPI",
#             "displayName": {
#               "text": "Carrefour Express Porta Castiglione Store",
#               "languageCode": "en"
#             },
#             "types": [
#               "establishment",
#               "food",
#               "grocery_or_supermarket",
#               "health",
#               "point_of_interest",
#               "store",
#               "supermarket"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 31.259172,
#             "travelDistanceMeters": 32.876442
#           },
#           {
#             "name": "places/ChIJ396r0sXUf0cRtx-IP709mG8",
#             "placeId": "ChIJ396r0sXUf0cRtx-IP709mG8",
#             "displayName": {
#               "text": "Farmacia Dr. Max",
#               "languageCode": "it"
#             },
#             "types": [
#               "establishment",
#               "health",
#               "pharmacy",
#               "point_of_interest",
#               "store"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 29.39594,
#             "travelDistanceMeters": 15.978893
#           },
#           {
#             "name": "places/ChIJQ8QHycXUf0cRdnAeMobf1SM",
#             "placeId": "ChIJQ8QHycXUf0cRdnAeMobf1SM",
#             "displayName": {
#               "text": "Chiesa di Santa Maria della Misericordia",
#               "languageCode": "en"
#             },
#             "types": [
#               "church",
#               "establishment",
#               "place_of_worship",
#               "point_of_interest"
#             ],
#             "spatialRelationship": "DOWN_THE_ROAD",
#             "straightLineDistanceMeters": 77.96733,
#             "travelDistanceMeters": 71.19292
#           },
#           {
#             "name": "places/ChIJfxhFC8XUf0cR0Xo9dUoTA6s",
#             "placeId": "ChIJfxhFC8XUf0cR0Xo9dUoTA6s",
#             "displayName": {
#               "text": "Serre dei Giardini Margherita",
#               "languageCode": "en"
#             },
#             "types": [
#               "bar",
#               "establishment",
#               "food",
#               "point_of_interest",
#               "restaurant",
#               "school"
#             ],
#             "straightLineDistanceMeters": 216.12418,
#             "travelDistanceMeters": 231.01735
#           },
#           {
#             "name": "places/ChIJPf2OzsXUf0cRhB7p5uqjLII",
#             "placeId": "ChIJPf2OzsXUf0cRhB7p5uqjLII",
#             "displayName": {
#               "text": "B&B Al Parco Giardini Margherita Sconti Rizzoli e Villa Regina",
#               "languageCode": "en"
#             },
#             "types": [
#               "establishment",
#               "lodging",
#               "point_of_interest"
#             ],
#             "spatialRelationship": "ACROSS_THE_ROAD",
#             "straightLineDistanceMeters": 22.453997,
#             "travelDistanceMeters": 20.678474
#           }
#         ],
#         "areas": [
#           {
#             "name": "places/ChIJLwKOhMXUf0cRSwyJnq_IU64",
#             "placeId": "ChIJLwKOhMXUf0cRSwyJnq_IU64",
#             "displayName": {
#               "text": "Giardini Margherita",
#               "languageCode": "en"
#             },
#             "containment": "NEAR"
#           },
#           {
#             "name": "places/ChIJn_75kpXUf0cRlcgftj_FyYI",
#             "placeId": "ChIJn_75kpXUf0cRlcgftj_FyYI",
#             "displayName": {
#               "text": "Old Town",
#               "languageCode": "en"
#             },
#             "containment": "OUTSKIRTS"
#           }
#         ]
#       },
#       "googleMapsLinks": {
#         "directionsUri": "https://www.google.com/maps/dir//''/data=!4m7!4m6!1m1!4e2!1m2!1m1!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!3e0?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "placeUri": "https://maps.google.com/?cid=3277797724925377160&g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "writeAReviewUri": "https://www.google.com/maps/place//data=!4m3!3m2!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!12e1?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "reviewsUri": "https://www.google.com/maps/place//data=!4m4!3m3!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!9m1!1b1?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#         "photosUri": "https://www.google.com/maps/place//data=!4m3!3m2!1s0x477fd4c5848e022f:0x2d7d13aa0fc2ba88!10e5?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA"
#       },
#       "timeZone": {
#         "id": "Europe/Rome"
#       },
#       "postalAddress": {
#         "regionCode": "IT",
#         "languageCode": "en-US",
#         "postalCode": "40136",
#         "administrativeArea": "Metropolitan City of Bologna",
#         "locality": "Bologna",
#         "addressLines": [
#           "Viale Giovanni Gozzadini"
#         ]
#       }
#     }
#   ]
# }
# ============================================================
# {'latitude': 44.4827156, 'longitude': 11.3524117}

# %%
import os
import requests

# Street View Static API URL
url = "https://maps.googleapis.com/maps/api/streetview"

# Use Piazza Maggiore coordinates (city center - has Street View coverage)
lat = 44.4949
lng = 11.3426

params = {
    "location": f"{lat},{lng}",  # Required: lat,lng coordinates
    "size": "640x640",            # Required: image size (max 640x640)
    "heading": 0,                 # Optional: camera direction in degrees (0-360)
    "pitch": 0,                   # Optional: vertical angle (-90 to 90, 0 = level)
    "fov": 90,                    # Optional: zoom level (10-120, higher = zoomed in)
    "key": API_KEY_GMP
}

response = requests.get(url, params=params)

print("Status Code:", response.status_code)
if response.status_code == 200:
    # Save the image
    with open("street_view_test.jpg", "wb") as f:
        f.write(response.content)
    print("Image saved as 'street_view_test.jpg'")
else:
    print(f"Error: {response.text}")
# Out:
# Status Code: 200
# Image saved as 'street_view_test.jpg'

# %% [markdown]
# ## Build the pipeline
#
# We will write a function that samples `N` points around the radius `R` starting from a fixed location `center`.
#
# It will need to retry because we may encounter locations that do not have street views associated; we will implement this later on.

# %%
import random
import math

def sample_points_in_radius(center : tuple[float, float], radius : float, N : int) -> list[tuple[float, float]]:
    """
    Sample N points in a circle of radius R centered at center.

    Args:
        center: tuple of float, the center of the circle (lat, lon)
        radius: float, the radius of the circle in meters
        N: int, the number of points to sample

    Returns:
        list of tuples of float, the sampled points (lat, lon)
    """
    center_lat, center_lon = center
    points = []
    
    for _ in range(N):
        # Generate random angle and distance
        angle = random.uniform(0, 2 * math.pi)
        # Use square root for uniform distribution in circle
        distance = math.sqrt(random.uniform(0, 1)) * radius
        
        # Convert meters to approximate lat/lon offset
        # Rough approximation: 1 degree lat ≈ 111,000m, 1 degree lon ≈ 111,000m * cos(lat)
        lat_offset = distance / 111000
        lon_offset = distance / (111000 * math.cos(math.radians(center_lat)))
        
        # Calculate new coordinates
        new_lat = center_lat + lat_offset * math.cos(angle)
        new_lon = center_lon + lon_offset * math.sin(angle)
        
        points.append((new_lat, new_lon))
    
    return points

# %%
# Test the function
bologna_center = (44.4949, 11.3426)  # Piazza Maggiore
radius_meters = 1000  # 1km radius
n_points = 5

sampled_points = sample_points_in_radius(bologna_center, radius_meters, n_points)

print(f"Center: {bologna_center}")
print(f"Radius: {radius_meters}m")
print(f"Sampled {len(sampled_points)} points:")
for i, (lat, lon) in enumerate(sampled_points):
    print(f"  {i+1}: ({lat:.6f}, {lon:.6f})")
# Out:
# Center: (44.4949, 11.3426)
# Radius: 1000m
# Sampled 5 points:
#   1: (44.490777, 11.334075)
#   2: (44.498317, 11.346206)
#   3: (44.502797, 11.347025)
#   4: (44.495270, 11.349881)
#   5: (44.487481, 11.337039)

# %%
# Street View coverage validation
import os
import requests

API_KEY_GMP = os.getenv("GOOGLE_API_KEY")

# Funzione di Validazione con Street View Metadata API (Richiede l'API_KEY_GMP globale)
def validate_streetview_coverage(lat: float, lng: float):
    """
    Usa Street View Metadata per verificare se esiste un panorama per la location.
    Restituisce (has_coverage: bool, date: Optional[str], pano_id: Optional[str]).
    """
    global API_KEY_GMP

    metadata_url = (
        "https://maps.googleapis.com/maps/api/streetview/metadata?"
        f"location={lat},{lng}&"
        f"key={API_KEY_GMP}"
    )

    try:
        response = requests.get(metadata_url, timeout=5)
        response.raise_for_status()
        data = response.json()

        if data.get('status') == 'OK':
            date = data.get('date', None)
            pano_id = data.get('pano_id', None)
            return True, date, pano_id
        else:
            return False, None, None

    except requests.RequestException:
        return False, None, None

# %%
# Sample only points with Street View coverage (with retries)
import time
from typing import List, Tuple


def sample_points_with_coverage(center: tuple[float, float], radius_m: float, n_points: int,
                                max_attempts: int = 200, request_pause_s: float = 0.0) -> list[tuple[float, float]]:
    """
    Sample points uniformly within radius and keep only those with Street View coverage.
    Stops when n_points are found or max_attempts reached.
    """
    valid_points: List[Tuple[float, float]] = []
    attempts = 0

    while len(valid_points) < n_points and attempts < max_attempts:
        lat, lon = sample_points_in_radius(center, radius_m, 1)[0]
        has_cov, _, _ = validate_streetview_coverage(lat, lon)
        if has_cov:
            valid_points.append((lat, lon))
        attempts += 1
        if request_pause_s:
            time.sleep(request_pause_s)

    return valid_points

# %%
# Use the coverage-aware sampler
bologna_center = (44.4949, 11.3426)
radius_meters = 1000
n_points = 5

max_attempts = 100  # stop if we can't find N within this many attempts
sampled_points = sample_points_with_coverage(bologna_center, radius_meters, n_points,
                                            max_attempts=max_attempts, request_pause_s=0.0)

print(f"Requested {n_points} points; collected {len(sampled_points)} with Street View coverage.")
for i, (lat, lon) in enumerate(sampled_points):
    print(f"  {i+1}: ({lat:.6f}, {lon:.6f})")

# %%
# Visualize with folium
import folium

# Create map centered on Bologna
m = folium.Map(location=bologna_center, zoom_start=13)

# Add the center point with a different marker
folium.Marker(
    bologna_center,
    popup='Center (Piazza Maggiore)',
    tooltip='Center',
    icon=folium.Icon(color='red', icon='flag')
).add_to(m)

# Add the sampled points
for i, (lat, lon) in enumerate(sampled_points):
    folium.Marker(
        [lat, lon],
        popup=f'Point {i+1}',
        tooltip=f'Point {i+1}',
        icon=folium.Icon(color='blue', icon='circle')
    ).add_to(m)

# Add a circle to show the radius
folium.Circle(
    location=bologna_center,
    radius=radius_meters,
    color='red',
    fill=False,
    weight=2,
    opacity=0.5
).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_baadfb25cbd256e9fe07c1bef387c3fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_baadfb25cbd256e9fe07c1bef387c3fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_baadfb25cbd256e9fe07c1bef387c3fb = L.map(
#                 &quot;map_baadfb25cbd256e9fe07c1bef387c3fb&quot;,
#                 {
#                     center: [44.4949, 11.3426],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ca80568a602001fe1f2efd9c871b5e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ca80568a602001fe1f2efd9c871b5e1.addTo(map_baadfb25cbd256e9fe07c1bef387c3fb);
#
#
#             var marker_de90be07279c59ef6ba3fba529b3a3aa = L.marker(
#                 [44.4949, 11.3426],
#                 {
# }
#             ).addTo(map_baadfb25cbd256e9fe07c1bef387c3fb);
#
#
#             var icon_6c2b20471668616d23944b52a9cbaf69 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d30c947c08f5a14b94a83996550fa632 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fe10a6f45b49a1fa3933ba57fc58d91 = $(`&lt;div id=&quot;html_9fe10a6f45b49a1fa3933ba57fc58d91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Center (Piazza Maggiore)&lt;/div&gt;`)[0];
#                 popup_d30c947c08f5a14b94a83996550fa632.setContent(html_9fe10a6f45b49a1fa3933ba57fc58d91);
#
#
#
#         marker_de90be07279c59ef6ba3fba529b3a3aa.bindPopup(popup_d30c947c08f5a14b94a83996550fa632)
#         ;
#
#
#
#
#             marker_de90be07279c59ef6ba3fba529b3a3aa.bindTooltip(
#                 `&lt;div&gt;
#                      Center
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_de90be07279c59ef6ba3fba529b3a3aa.setIcon(icon_6c2b20471668616d23944b52a9cbaf69);
#
#
#             var marker_29e9a22b55eb18cb2d16d6b541fe3848 = L.marker(
#                 [44.49077731129163, 11.334074642502554],
#                 {
# }
#             ).addTo(map_baadfb25cbd256e9fe07c1bef387c3fb);
#
#
#             var icon_c04bbb88077768744c4e921be0700b0e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;circle&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0a0db2363d1d4085149b59ae94c49453 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cac3c7fe2ab65f86160c3c48f0f06f56 = $(`&lt;div id=&quot;html_cac3c7fe2ab65f86160c3c48f0f06f56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 1&lt;/div&gt;`)[0];
#                 popup_0a0db2363d1d4085149b59ae94c49453.setContent(html_cac3c7fe2ab65f86160c3c48f0f06f56);
#
#
#
#         marker_29e9a22b55eb18cb2d16d6b541fe3848.bindPopup(popup_0a0db2363d1d4085149b59ae94c49453)
#         ;
#
#
#
#
#             marker_29e9a22b55eb18cb2d16d6b541fe3848.bindTooltip(
#                 `&lt;div&gt;
#                      Point 1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_29e9a22b55eb18cb2d16d6b541fe3848.setIcon(icon_c04bbb88077768744c4e921be0700b0e);
#
#
#             var marker_a7cb532f095a87ec838014ffc289bce4 = L.marker(
#                 [44.49831696091402, 11.34620613911444],
#                 {
# }
#             ).addTo(map_baadfb25cbd256e9fe07c1bef387c3fb);
#
#
#             var icon_d00ba34f4db69a0e6a283d86c81c977a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;circle&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7fb844117052f46891a00c172027d263 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_957b710d6ad3d8e820849666b10025ec = $(`&lt;div id=&quot;html_957b710d6ad3d8e820849666b10025ec&quot; style=&quot;width: 100.0%;

# %%
# Build Street View URL entries and save to CSV (URLs without API key)
import os
import pandas as pd

# Configuration
size = "640x640"
fov = 90
headings = [0, 90, 180, 270]
pitches = [-45, 0, 45]
include_key_in_csv = False  # avoid exposing API key in the CSV

streetview_base = "https://maps.googleapis.com/maps/api/streetview"

rows = []
for point_idx, (lat, lon) in enumerate(sampled_points):
    for heading in headings:
        for pitch in pitches:
            params = {
                "size": size,
                "location": f"{lat},{lon}",
                "heading": heading,
                "pitch": pitch,
                "fov": fov,
            }
            # URL without the key (safe to store/share)
            url_no_key = (
                f"{streetview_base}?size={params['size']}&location={params['location']}"
                f"&heading={params['heading']}&pitch={params['pitch']}&fov={params['fov']}"
            )
            # Template with placeholder for key (for agents that can inject it)
            url_with_placeholder = url_no_key + "&key={API_KEY}"
            # Optionally materialize with your key (not recommended to persist)
            url_with_key = (
                url_no_key + f"&key={API_KEY_GMP}" if include_key_in_csv else None
            )

            rows.append({
                "point_index": point_idx,
                "lat": lat,
                "lon": lon,
                "heading": heading,
                "pitch": pitch,
                "fov": fov,
                "size": size,
                "url_template": url_with_placeholder,
                "url_no_key": url_no_key,
                "url_with_key": url_with_key,
            })

sv_df = pd.DataFrame(rows)
print(f"Generated {len(sv_df)} Street View entries for {len(sampled_points)} points.")
sv_df.head()
# Out:
# Generated 60 Street View entries for 5 points.
#    point_index        lat        lon  heading  pitch  fov     size  \
# 0            0  44.490777  11.334075        0    -45   90  640x640
# 1            0  44.490777  11.334075        0      0   90  640x640
# 2            0  44.490777  11.334075        0     45   90  640x640
# 3            0  44.490777  11.334075       90    -45   90  640x640
# 4            0  44.490777  11.334075       90      0   90  640x640
#
#                                         url_template  \
# 0  https://maps.googleapis.com/maps/api/streetvie...
# 1  https://maps.googleapis.com/maps/api/streetvie...
# 2  https://maps.googleapis.com/maps/api/streetvie...
# 3  https://maps.googleapis.com/maps/api/streetvie...
# 4  https://maps.googleapis.com/maps/api/streetvie...
#
#                                           url_no_key url_with_key
# 0  https://maps.googleapis.com/maps/api/streetvie...         None
# 1  https://maps.googleapis.com/maps/api/streetvie...         None
# 2  https://maps.googleapis.com/maps/api/streetvie...         None
# 3  https://maps.googleapis.com/maps/api/streetvie...         None
# 4  https://maps.googleapis.com/maps/api/streetvie...         None

# %%
# Save to CSV
out_csv = "streetview_samples.csv"
sv_df.to_csv(out_csv, index=False)
print(f"Saved {len(sv_df)} rows to {out_csv}")
# Out:
# Saved 60 rows to streetview_samples.csv

# %%
# Add layer column (ground/horizon/sky) and point_id, then save layered CSV

def classify_layer(pitch: float) -> str:
    if pitch <= -30:
        return "ground"
    if pitch >= 30:
        return "sky"
    return "horizon"

sv_df["layer"] = sv_df["pitch"].apply(classify_layer)
sv_df["point_id"] = sv_df["point_index"]

# Reorder columns for readability
cols = [
    "point_id", "point_index", "lat", "lon", "layer",
    "heading", "pitch", "fov", "size",
    "url_no_key", "url_template", "url_with_key",
]
sv_df = sv_df[cols]

layered_csv = "streetview_samples_layered.csv"
sv_df.to_csv(layered_csv, index=False)
print(f"Saved layered CSV with {len(sv_df)} rows to {layered_csv}")
sv_df.head(10)
# Out:
# Saved layered CSV with 60 rows to streetview_samples_layered.csv
#    point_id  point_index        lat        lon    layer  heading  pitch  fov  \
# 0         0            0  44.490777  11.334075   ground        0    -45   90
# 1         0            0  44.490777  11.334075  horizon        0      0   90
# 2         0            0  44.490777  11.334075      sky        0     45   90
# 3         0            0  44.490777  11.334075   ground       90    -45   90
# 4         0            0  44.490777  11.334075  horizon       90      0   90
# 5         0            0  44.490777  11.334075      sky       90     45   90
# 6         0            0  44.490777  11.334075   ground      180    -45   90
# 7         0            0  44.490777  11.334075  horizon      180      0   90
# 8         0            0  44.490777  11.334075      sky      180     45   90
# 9         0            0  44.490777  11.334075   ground      270    -45   90
#
#       size                                         url_no_key  \
# 0  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 1  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 2  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 3  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 4  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 5  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 6  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 7  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 8  640x640  https://maps.googleapis.com/maps/api/streetvie...
# 9  640x640  https://maps.googleapis.com/maps/api/streetvie...
#
#                                         url_template url_with_key
# 0  https://maps.googleapis.com/maps/api/streetvie...         None
# 1  https://maps.googleapis.com/maps/api/streetvie...         None
# 2  https://maps.googleapis.com/maps/api/streetvie...         None
# 3  https://maps.googleapis.com/maps/api/streetvie...         None
# 4  https://maps.googleapis.com/maps/api/streetvie...         None
# 5  https://maps.googleapis.com/maps/api/streetvie...         None
# 6  https://maps.googleapis.com/maps/api/streetvie...         None
# 7  https://maps.googleapis.com/maps/api/streetvie...         None
# 8  https://maps.googleapis.com/maps/api/streetvie...         None
# 9  https://maps.googleapis.com/maps/api/streetvie...         None
